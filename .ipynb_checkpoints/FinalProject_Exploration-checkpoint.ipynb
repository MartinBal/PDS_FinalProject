# %% [markdown]
# # Final project
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %%
import pickle
import os
from collections import Counter
import json
import datetime as dt
import twitter
import sqlite3

# %%
Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /home/martin/anaconda3/lib/python3.6/site-packages

# %% [markdown]
# ## Authorizing an application to access Twitter account data

# %%
auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# ## Retrieving trends

# %%
WORLD_WOE_ID = 1
FR_WOE_ID = 23424819 #FRANCE

# %%
LOCAL_WOE_ID=615702 #PARIS
#12597156 #Seine St Denis
#55863588 #SAINT-OUEN
#615702 #PARIS

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
fr_trends = twitter_api.trends.place(_id=FR_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %% [markdown]
# ## Computing the intersection of two sets of trends

# %%
#%%timeit
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['fr'] = set([trend['name'] 
                     for trend in fr_trends[0]['trends']]) 

trends_set['Paris'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','fr','Paris']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# North Korea,#VzlaTomaLasCalles,#kimbilir,#SerFelizEh,Fora Globo,David Price,Loyalty,#Smackoff,#VenezuelaSeRespeta,#قصه_قصيره,#VandeMataramDebate,#هاذي_السعوديه,#FridayFeeling,#YSiVolvieraASerNiño,ミサイル,#VendaManillasYHagaseRico,#ساعه_استجابه,#VamosPorEllas,Helsinki,Arcade Fire,#BeingBonang,Christy Clark,#SextaDetremuraSDV,#KDFKeepOffElections,#PlantASong,Dony de Nuccio,Ersin Çelik,#HazPatriaDenunciaAUnCorrupto,#DepuisQueJeSuisSurTwitter,#MensajealaNacion,#IfICreatedARobot,#28Jul,#تثبيت_تقاعد_العسكر,#TerimGelsinAslanKükresin,#BuenViernes,#IfChocolateDidNotExist,#امطار_الطايف,#BetterTogetherCA,#SaygısızAtv,#doremi,#Chiquititas20anos,#FlashbackFriday,#1DeŞunuYazayım,#AmizadesDoFFC,#ElPlanPerfectoIncluye,#3YearsOfTheShawnMendesEP,Long Island,Charlie Gard,#ENGvSA,#ÖzgürlükHemenŞimdi
# ('----------', 'fr')
# #TOURSHAC,#Chasseursdappart,#SRCAB,Everything Now,North Korea,John G. Morris,#AffaireGregory,#NOSDR,#reserveParlementaire,Semedo,#HungarianGP,#SysAdminDay,#USOASNL,#Hambourg,#OGLCS,Thiago Silva,Christophe Barbier,Michel Onfray,#NuitsDesEtoiles,#PlaystationPlus,#JeudiConfession,#VendrediLecture,#Helsinki,Catherine Deneuve,Kalulu,La Corée du Nord,Mammana,#DepuisQueJeSuisSurTwitter,#LRDS,#OMKVO,#TFCOSASUNA,#FCSMFBBP,Ségolène Royal,#CNFCACA,#ASMPSG,McCain,#4MP1LDM,Danone,#SB29LBC,#FCGBVFC,Estelle,#VAFCGFCA,#NYANSAPOFest,#jujitsu,#AskVictoria,Joke,#RERA,#3YearsOfTheShawnMendesEP,Germain,#Amical
# ('----------', 'Paris')
# #TOURSHAC,#Chasseursdappart,#SRCAB,Everything Now,North Korea,John G. Morris,#AffaireGregory,#DirectAN,#NOSDR,#HungarianGP,Semedo,#USOASNL,#Hambourg,#OGLCS,Thiago Silva,Christophe Barbier,Michel Onfray,#NuitsDesEtoiles,#PlaystationPlus,#JeudiConfession,#VendrediLecture,#PFCCF63,#Helsinki,Catherine Deneuve,Kalulu,La Corée du Nord,Mammana,#DepuisQueJeSuisSurTwitter,#LRDS,#OMKVO,#TFCOSASUNA,#FCSMFBBP,Ségolène Royal,#CNFCACA,#ASMPSG,McCain,#4MP1LDM,Danone,#SB29LBC,#FCGBVFC,Estelle,#VAFCGFCA,#NYANSAPOFest,#jujitsu,#AskVictoria,Joke,#RERA,#3YearsOfTheShawnMendesEP,Germain,#Amical

# %%
print(( '='*10,'intersection of world and France'))
print((trends_set['world'].intersection(trends_set['fr'])))

print(('='*10,'intersection of fr and France'))
print((trends_set['Paris'].intersection(trends_set['fr'])))
# Out:
# ('==========', 'intersection of world and France')
# {'#3YearsOfTheShawnMendesEP', '#DepuisQueJeSuisSurTwitter', 'North Korea'}
# ('==========', 'intersection of fr and France')
# {'#TOURSHAC', '#Chasseursdappart', '#SRCAB', 'Everything Now', 'North Korea', 'John G. Morris', '#AffaireGregory', '#NOSDR', '#HungarianGP', 'Semedo', '#USOASNL', '#Hambourg', '#Amical', '#OGLCS', 'Thiago Silva', 'Christophe Barbier', 'Michel Onfray', '#NuitsDesEtoiles', '#PlaystationPlus', '#JeudiConfession', '#VendrediLecture', '#Helsinki', 'Catherine Deneuve', 'Kalulu', 'La Corée du Nord', 'Mammana', '#DepuisQueJeSuisSurTwitter', '#LRDS', '#OMKVO', '#TFCOSASUNA', '#FCSMFBBP', 'Ségolène Royal', '#CNFCACA', '#ASMPSG', 'McCain', '#4MP1LDM', 'Danone', '#SB29LBC', 'Estelle', '#VAFCGFCA', '#NYANSAPOFest', '#jujitsu', '#AskVictoria', 'Joke', '#RERA', '#3YearsOfTheShawnMendesEP', 'Germain', '#FCGBVFC'}

# %% [markdown]
# ## Collecting search results

# %%
q = '#neonicotinoides' 
nb = 100
lg='fr'
#result_type='recent'#mixed recent popular


# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

#https://dev.twitter.com/rest/public/timelines

#search_results = twitter_api.search.tweets(q=q, count=number, lang=lang, result_type=result_type)

#statuses = search_results['statuses']

# %% [markdown]
# #Seach all the tweets in 1 week (max per search is 100, older access = 1 week)
# search_results = twitter_api.search.tweets(q=q, count=nb,  result_type='recent')
# statuses = search_results['statuses']
# l_nw_st=100
#
# while l_nw_st==100 or l_st>=10000:
#     mi=statuses[-1]['id']-1
#     print(mi)
#     search_results = twitter_api.search.tweets(q=q, count=nb,  result_type='recent', max_id=mi)
#     nw_st=search_results['statuses']
#     l_nw_st=len(nw_st)
#     print (l_nw_st)
#     statuses.extend(nw_st)
#     l_st=len(statuses)
#     print(l_st)
# #print(statuses[-1])
# #for i in range[0,10]:

# %%
with open('./statuses.json', 'r') as fichier:
    statuses=json.loads(fichier.read())

# %%
#refresh the last tweets
l_nw_st=100
while l_nw_st==100:
    si=statuses[0]['id']
    search_results = twitter_api.search.tweets(q=q, count=nb,  result_type='recent', since_id=si)
    nw_st=search_results['statuses']
    l_nw_st=len(nw_st)
    nw_st.extend(statuses)
    statuses=nw_st
    l_st=len(statuses)
    print(l_st)
# Out:
# 1229
# 1229

# %%
now=dt.datetime.today()
date=str(now.year).zfill(4)+str(now.month).zfill(2)+str(now.day).zfill(2)+str(now.hour).zfill(2)

# %%
with open('./statuses_'+date+'.json', 'w') as fichier:
    json.dump(statuses, fichier, sort_keys=True, indent=4,
              ensure_ascii=False)

# %%
with open('./statuses.json', 'w') as fichier:
    json.dump(statuses, fichier, sort_keys=True, indent=4,
              ensure_ascii=False)

# %%
statuses[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jul 28 17:05:11 +0000 2017',
#  'entities': {'hashtags': [{'indices': [95, 111], 'text': 'neonicotinoides'}],
#   'symbols': [],
#   'urls': [{'display_url': 'polony.tv/focus/les-chan…',
#     'expanded_url': 'https://polony.tv/focus/les-chantiers-de-monsieur-hulot',
#     'indices': [113, 136],
#     'url': 'https://t.co/z1IMWfOGCK'}],
#   'user_mentions': [{'id': 837123698,
#     'id_str': '837123698',
#     'indices': [3, 11],
#     'name': 'Natacha Polony',
#     'screen_name': 'NPolony'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 890981471875420161,
#  'id_str': '890981471875420161',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'fr',
#  'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 187,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Jun 26 10:02:02 +0000 2017',
#   'entities': {'hashtags': [{'indices': [82, 98], 'text': 'neonicotinoides'}],
#    'symbols': [],
#    'urls': [{'display_url': 'polony.tv/focus/les-chan…',
#      'expanded_url': 'https://polony.tv/focus/les-chantiers-de-monsieur-hulot',
#      'indices': [100, 123],
#      'url': 'https://t.co/z1IMWfOGCK'}],
#    'user_mentions': [{'id': 818864954141003780,
#      'id_str': '818864954141003780',
#      'indices': [128, 138],
#      'name': 'Polony Tv',
#      'screen_name': 'Polony_tv'}]},
#   'favorite_count': 216,
#   'favorited': False,
#   'geo': None,
#   'id': 879278571524673536,
#   'id_str': '879278571524673536',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'fr',
#   'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 187,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "Nous le disions: il y a l'affichage et il y a les enjeux concrets face aux lobbys #neonicotinoides  https://t.co/z1IMWfOGCK via @Polony_tv",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Sep 21 06:10:15 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Journaliste, essayiste. @Polony_tv, @LCI, Les Terriens du dimanche.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 8,
#    'follow_request_sent': False,
#    'followers_count': 105632,
#    'following': False,
#    'friends_count': 302,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 837123698,
#    'id_str': '837123698',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'fr',
#    'listed_count': 808,
#    'location': '',
#    'name': 'Natacha Polony',
#    'notifications': False,
#    'profile_background_color': 'FAFAFA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/837123698/1498825610',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/880483638663663617/WiD3SL9m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880483638663663617/WiD3SL9m_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'NPolony',
#    'statuses_count': 2074,
#    'time_zone': 'Athens',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 10800,
#    'verified': True}},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': "RT @NPolony: Nous le disions: il y a l'affichage et il y a les enjeux concrets face aux lobbys #neonicotinoides  https://t.co/z1IMWfOGCK vi…",
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Oct 30 18:45:12 +0000 2012',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'RCN',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 232,
#   'follow_request_sent': False,
#   'followers_count': 120,
#   'following': False,
#   'friends_count': 369,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 915241236,
#   'id_str': '915241236',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'fr',
#   'listed_count': 0,
#   'location': '',
#   'name': 'Pascal',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/915241236/1500569669',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/888079670905884672/DMydwbif_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/888079670905884672/DMydwbif_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'pascal_pm',
#   'statuses_count': 375,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %% [markdown]
# #TW
# tw_k=['contributors','coordinates','created_at']
#
# #TWHT
# #HT
# ht_k['indices','text']
#
# #TWUM
# #US
# us_k['id','name','screen_name']
# #UM
# um_k

# %% [markdown]
# #TW
# {#'contributors',
#  'id',
#  'coordinates',
#  'created_at',#s['created_at']
#      #'entities',
#      #'extended_entities',
#  'favorite_count',
#  #'favorited',
#  #'geo',
#  #'id_str',
#      #'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#      #'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  #'in_reply_to_user_id_str',
#  ?'is_quote_status',
#  'lang',
#  ?'metadata',
#  'place',
#  'possibly_sensitive',
#      #'quoted_status',
#  'quoted_status_id',
#  #'quoted_status_id_str',
#  'retweet_count',
#  'retweeted',
# #'retweeted_status'['id']
#      #'retweeted_status',
#  'source',
#  'text',
#  #'truncated',
# #'user'['id']
#      #'user'}

# %%
keys_st=set()
for s in statuses:
    skeys_st=set(s.keys())
    keys_st.update(skeys_st)
keys_st
# Out:
# {'contributors',
#  'coordinates',
#  'created_at',
#  'entities',
#  'extended_entities',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'metadata',
#  'place',
#  'possibly_sensitive',
#  'quoted_status',
#  'quoted_status_id',
#  'quoted_status_id_str',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'source',
#  'text',
#  'truncated',
#  'user'}

# %%
conn = sqlite3.connect('test.db')

# %%
c = conn.cursor()

# Create table
c.execute('''CREATE TABLE stocks
             (date text, trans text, symbol text, qty real, price real)''')

# Insert a row of data
c.execute("INSERT INTO stocks VALUES ('2006-01-05','BUY','RHAT',100,35.14)")

# Save (commit) the changes
conn.commit()

# We can also close the connection if we are done with it.
# Just be sure any changes have been committed or they will be lost.
conn.close()
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 71))
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-20-4fcd81769805> in <module>()
#       3 # Create table
#       4 c.execute('''CREATE TABLE stocks
# ----> 5              (date text, trans text, symbol text, qty real, price real)''')
#       6
#       7 # Insert a row of data
#
# OperationalError: table stocks already exists

# %%
[statuses[0][k] for k in keys_st]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-8ce1f07dcde5> in <module>()
# ----> 1 [statuses[0][k] for k in keys_st]
#
# <ipython-input-21-8ce1f07dcde5> in <listcomp>(.0)
# ----> 1 [statuses[0][k] for k in keys_st]
#
# KeyError: 'extended_entities'

# %%
[s['text'] for s in statuses[:10]]
# Out:
# ["RT @NPolony: Nous le disions: il y a l'affichage et il y a les enjeux concrets face aux lobbys #neonicotinoides  https://t.co/z1IMWfOGCK vi…",
#  'RT @Polony_tv: "Les plus lucides se diront que #Macron avait promis de ne pas revenir sur cette interdiction des #neonicotinoides" ➤https:/…',
#  'RT @Polony_tv: Retrouvez la revue de presse de cette semaine par @NPolony ➤ https://t.co/fijynKtKlV #neonicotinoides #CongresVersailles #FM…',
#  "RT @LaFakeAgricole: Alternatives aux #neonicotinoides :l'Anses autorise Froome,un #insecticide 100 % naturel,qui fait aussi #herbicide et a…",
#  "Alternatives aux #neonicotinoides :l'Anses autorise Froome,un #insecticide 100 % naturel,qui fait aussi #herbicide… https://t.co/P0dCNrScMg",
#  'RT @MichelsJoost: Mijn bijen zijn bijna klaar voor de Nederlandse lente... En graag zonder #neonicotinoides, beste boeren. https://t.co/BzH…',
#  'RT @ApiEcologica: En fin... https://t.co/zCK2jp7qXc \n#abejas #apicultura #ColonyCollapseDisorder #neonicotinoides #acaricidas #pesticidas',
#  'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…',
#  'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…',
#  'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/BSlUs7lqJ6 #pétition #néonicotinoïdes']

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %% [markdown]
# all_text = []
# filtered_statuses = []
# for s in statuses:
#     if not s["text"] in all_text:
#         filtered_statuses.append(s)
#         all_text.append(s["text"])
# statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 1229

# %%
[(s["user"]["screen_name"],s['retweet_count'],s["text"]) for s in statuses if not 'retweeted_status' in s]
# Out:
# [('LaFakeAgricole',
#   1,
#   "Alternatives aux #neonicotinoides :l'Anses autorise Froome,un #insecticide 100 % naturel,qui fait aussi #herbicide… https://t.co/P0dCNrScMg"),
#  ('MPeala',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/BSlUs7lqJ6 #pétition #néonicotinoïdes'),
#  ('Referenceappro',
#   0,
#   "Néonicotinoïdes : alternatives connues dès l'automne\nhttps://t.co/OCTMZPyUS6 @Anses_fr @Referenceappro #neonicotinoides  #Phyto"),
#  ('mag_vegetable',
#   2,
#   'Les ventes de néonicotinoïdes en hausse https://t.co/lfq0ZwY5gB #gilles-lanio #neonicotinoides #unaf'),
#  ('29aatea', 1, '#Neonicotinoides #abeilles #Ukraine https://t.co/feqCITtmfF'),
#  ('PietersEdwige',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/L9UZgJCCf4 #pétition #néonicotinoïdes'),
#  ('ApiEcologica',
#   5,
#   'En fin... https://t.co/zCK2jp7qXc \n#abejas #apicultura #ColonyCollapseDisorder #neonicotinoides #acaricidas #pesticidas'),
#  ('aurelienbadet',
#   0,
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/1Rb823Chms #abeilles #pétition'),
#  ('thi_loup',
#   0,
#   "Les débats scientifiques à l'ANSES sont difficile pour les impacts des #neonicotinoides bataille sur les externalités..."),
#  ('nath_35',
#   0,
#   'https://t.co/KCxSbsaZI5 via @AssoPollinis "l\'interdiction des #néonicotinoïdes en France: attention danger!"'),
#  ('RemDumDum',
#   2,
#   '- y a t il des alternatives aux #neonicotinoides ?\n- ANSES : Réponse début 2018 (à 01:35:00)\n- MOI : NON !\nhttps://t.co/RNnB3N3Hi1'),
#  ('thi_loup',
#   1,
#   "Une evaluation globale des biocides est en cours incluant les #neonicotinoides (à la maison) pour mesurer l'exposition"),
#  ('thi_loup',
#   1,
#   "Une saisine santé humaine des #neonicotinoides sera aussi rendue : c'est médicaments, biocides et les pesticides. Global"),
#  ('thi_loup',
#   1,
#   "La responsable avoue qu'elle n'est pas certaine que nous pourrons répondre un jour à l'effet des #néonicotinoides par usages"),
#  ('thi_loup',
#   1,
#   "Sur les #neonicotinoides : le collège d'experts ANSES est bien composé d'agronomes et de chercheurs pour les alternatives"),
#  ('thi_loup',
#   9,
#   'Audition de Roger Genet pour @Anses_fr #neonicotinoides #pesticides #glyphosate #nanoparticules https://t.co/KyN4fmubrS'),
#  ('M_Orphelin',
#   11,
#   '#BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères… https://t.co/umPp9RnTPn'),
#  ('Prudhomme2017',
#   0,
#   "@Anses_fr rendra un avis sur les #neonicotinoïdes  à partir de l'automne, complété début 2018... et le #PrincipeDePrecaution ?"),
#  ('b_abba',
#   10,
#   'Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides… https://t.co/idXJchv3xd'),
#  ('rodrigueaHDF',
#   0,
#   "#En2740ilyaura des gens dont le métier sera pollinisateur de fleurs car y aura plus d'abeilles pour le faire. Merci les #neonicotinoides"),
#  ('M_Orphelin',
#   5,
#   'Audition DG @Anses_fr Roger Genet commDD #directAN. Au menu : #pesticides #néonicotinoïdes… https://t.co/2nrgWCYZPH'),
#  ('FrancoisFree',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/8HtX9ixAFV #pétition #néonicotinoïdes'),
#  ('29aatea',
#   0,
#   '« + mortelle » pour les abeilles ? #néonicotinoïdes ne méritent pas l’étiquette https://t.co/IeOiHCCfdD  via… https://t.co/NqRmHSAIJE'),
#  ('madyguy1',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/zNxnqa313y #pétition #néonicotinoïdes'),
#  ('mirjossbom',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/ON1gtWK4dX #pétition #néonicotinoïdes'),
#  ('RidingMyWorld',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/jgAvpUPD9V #pétition #néonicotinoïdes'),
#  ('pmeyssonnier',
#   0,
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/lMNrF8a0P4 #abeilles #pétition'),
#  ('FFAP_Apipro',
#   4,
#   "Sans parler de la #pollution des eaux par les #néonicotinoïdes dont bien peu de monde parle et dont l'État se moque… https://t.co/svECdzxjU3"),
#  ('paddylille',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/RZ9KOWSSdS #pétition #néonicotinoïdes'),
#  ('DEROOSEJacques',
#   0,
#   'Interdiction des #néonicotinoïdes en France : attention danger ! via @AssoPollinis \nhttps://t.co/kPMJVrGXna'),
#  ('rafelvng',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/10RFST9vZb #pétition #néonicotinoïdes'),
#  ('GillesMaillet',
#   0,
#   'La #Commission #européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/HbVapPtTsa #abeilles #pétition'),
#  ('1toul',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/L3NMb4OxjA #pétition #néonicotinoïdes'),
#  ('Enkorplus',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/WIlQga4JOr #pétition #néonicotinoïdes'),
#  ('jepensedonc3',
#   1,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/MlawEvCew2 #pétition #néonicotinoïdes'),
#  ('marielenbenede',
#   3,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/NHgB8RYoqJ #pétition #néonicotinoïdes'),
#  ('RosalieBaumert',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/fwdiZK2q9b #pétition #néonicotinoïdes'),
#  ('marenascar',
#   0,
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/IMgONl6E3D #abeilles #pétition'),
#  ('edujom',
#   1,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/IM9pT3y5A9 #pétition #néonicotinoïdes'),
#  ('MargueriteJm',
#   1,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/fvY4xpULap #pétition #néonicotinoïdes'),
#  ('ecu92',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/zWXQX6kKs6 #pétition #néonicotinoïdes'),
#  ('marcillat8',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/m7X3DBaU6z #pétition #néonicotinoïdes'),
#  ('jepensedonc3',
#   0,
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/ynfV3efAU7 #abeilles #pétition'),
#  ('CatMaymard',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/WZvy51Ew0f #pétition #néonicotinoïdes RT svp #green'),
#  ('CdricV',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/z7hTatfjeI #pétition #néonicotinoïdes'),
#  ('mrabeman',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/6TBqhpxrTx #pétition #néonicotinoïdes'),
#  ('liogerard91',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/yWob51YiNB #pétition #néonicotinoïdes'),
#  ('lharmonie3',
#   0,
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/ODJprf4Syr #abeilles #pétition'),
#  ('filnoir',
#   7,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/A7pC1dENK4 #pétition #néonicotinoïdes'),
#  ('claudypersonne',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/XLS4RANvc9 #pétition #néonicotinoïdes'),
#  ('Ifanelix',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/mpRdbVS71I #pétition #néonicotinoïdes'),
#  ('Necropaul',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/sztgqdgUpV #pétition #néonicotinoïdes'),
#  ('CubryJeanPierre',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/LGPBx22nkq #pétition #néonicotinoïdes'),
#  ('labbef',
#   0,
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/VWV7TvBMRt #abeilles #pétition'),
#  ('Capital_Scandal',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/CCh3RPAyHA #pétition #néonicotinoïdes'),
#  ('louiebfree',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/tesPmPGLcu #pétition #néonicotinoïdes'),
#  ('PereMalo',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/n6BKY7x6B0 #pétition #néonicotinoïdes'),
#  ('drapeau_rouge',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/riEvsk2zMB #pétition #néonicotinoïdes'),
#  ('leoxymoron',
#   0,
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/VTDJE16Woa #abeilles #pétition'),
#  ('NLlinsoumise',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/vTJriucgbi #pétition #néonicotinoïdes'),
#  ('Linwelyn',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/E4682EYJiQ #pétition #néonicotinoïdes'),
#  ('PoussyIV',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/kVBbvgZCbE #pétition #néonicotinoïdes'),
#  ('mhhoodoo',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/je4kkDuxC2 #pétition #néonicotinoïdes'),
#  ('loic_delage',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/tvz4SHYGMU #pétition #néonicotinoïdes'),
#  ('Amandine_GB',
#   0,
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/LsH8R9Qyh4 #abeilles #pétition'),
#  ('anyesway',
#   18,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('CPNBRABANT',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/K2Z86dCfMh #pétition #néonicotinoïdes'),
#  ('deci0',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/wPQaCXUvkV #pétition #néonicotinoïdes'),
#  ('nonalausterite',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/5zaiZiQwh1 #pétition #néonicotinoïdes'),
#  ('ravelje',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/Y9VHKfFDt4 #pétition #néonicotinoïdes'),
#  ('franca64120',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/TND4QXUpj2 #pétition #néonicotinoïdes'),
#  ('IgorleChat',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/SsjAYi5MMW #pétition #néonicotinoïdes'),
#  ('NChevesson',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/aU6xpSpNz1 #pétition #néonicotinoïdes'),
#  ('MichelSain',
#   0,
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/MdGYQOIp2n #abeilles #pétition'),
#  ('a_robin10',
#   2,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/PCgxznpXIg #pétition #néonicotinoïdes'),
#  ('AliasLautre',
#   1,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/YAR4ljKzhJ #pétition #néonicotinoïdes'),
#  ('__Anais1996',
#   1,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/ul3rEd0bnC #pétition #néonicotinoïdes'),
#  ('StephFulgence',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/hQhZa8Ecdl #pétition #néonicotinoïdes'),
#  ('alternat5',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/0OWScE0pJa #pétition #néonicotinoïdes'),
#  ('Stephen_Mark_',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/FTbS2At3Um #pétition #néonicotinoïdes'),
#  ('LEGASTELOIS',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/vX86iy9OKp #pétition #néonicotinoïdes'),
#  ('jc_lomba',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/UKCS9PRcEd #pétition #néonicotinoïdes'),
#  ('IsadoraNizard',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/COTuQm8tci #pétition #néonicotinoïdes'),
#  ('jepensedonc3',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/cvmIuxHpr0 #pétition #néonicotinoïdes'),
#  ('be_leclercq',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/yPivFaOqDC #pétition #néonicotinoïdes'),
#  ('clnjmp',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/FG66qvR9MF #pétition #néonicotinoïdes'),
#  ('Randysud',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/gq4NGJ6qTg #pétition #néonicotinoïdes'),
#  ('benjam_caron',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/BXYTUdGODg #pétition #néonicotinoïdes'),
#  ('CorreaVillalobo',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/IqFaUkSkfo #pétition #néonicotinoïdes'),
#  ('thi_loup',
#   0,
#   '@ConversationUK L\'auteur défend les #neonicotinoides "un rôle vital pour la production alimentaire" et "une réduction des usages aériens"'),
#  ('thi_loup',
#   0,
#   'Auteur étude #neonicotinoides : notre recherche a montre des effets mais il est encore utile https://t.co/s0XswGL4TY via @ConversationUK'),
#  ('ChrisCathrine',
#   0,
#   '#neonicotinoides study author hits back at critics pointing out need to acknowledge there is a problem to address it https://t.co/yj4ZVxdQUu'),
#  ('beegardenmalaga',
#   0,
#   '#SOSabejas #Glifosato #glyphosate #Neonicotinoides #Neonics https://t.co/g377odQ9sI'),
#  ('JaviCepero',
#   2,
#   'Publicado en Science, no son las opiniones de 4 "ecologistas antisistema". #neonicotinoides  #bees #abejas https://t.co/nvI54xcEi2'),
#  ('LFerreirim',
#   1,
#   '"No me gusta que me llamen mentiroso" dice el autor del estudio sobre los #neonicotinoides https://t.co/vlEVCrWzT6 #SOSabejas #abejas'),
#  ('RemDumDum',
#   0,
#   '@LoCapel Les #neonicotinoides ont apporté des solutions, et permis d interdire les carbanates et le lindane.'),
#  ('agronomesQc',
#   1,
#   '#Pesticides : À lire. #néonicotinoïdes #neonics #pollinisateur https://t.co/LMU7cxNMJv'),
#  ('TheUniPlanet',
#   0,
#   'Exposição a #neonicotinóides resulta na morte prematura da abelha rainha e obreiras #abelhas https://t.co/qI49Hl7Exd'),
#  ('thi_loup',
#   1,
#   "Abeilles et #néonicotinoïdes\xa0: ce n'est toujours pas clair\xa0! https://t.co/xR1APHuHJf"),
#  ('brunocrussol',
#   25,
#   "Devant les atermoiements du #gouvernement sur les interdictions des #néonicotinoïdes, les #apiculteurs s'inquiètent… https://t.co/23vNWTVNj0"),
#  ('DYv62',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/EB1XFIT0V5 #pétition #néonicotinoïdes'),
#  ('777Ouroboros',
#   0,
#   '@gouvernementFR : #neonicotinoides #PNPP #Pesticides #épandages https://t.co/MPQmOpOQEl https://t.co/RnFjsjZY3e'),
#  ('777Ouroboros',
#   1,
#   "#neonicotinoides et #épandages aériens de pesticides : l'irresponsabilité écologique en marche du gouvernement… https://t.co/sd34XvJgLl"),
#  ('xavierlouyDLF',
#   1,
#   'Y compris les multinationales allemandes ? #Monsanto #Bayer #Lobby #Chimie 😡 #Néonicotinoïdes 🐝 https://t.co/jf4TmhAiGE'),
#  ('CarballoCecilia',
#   2,
#   '.@saradrio .@LFerreirim #neonicotinoides https://t.co/X67ObxSz3Z'),
#  ('SyngentaFrance',
#   3,
#   "Une étude s/ les néonics fait des éclats https://t.co/Qrf2DvDiRQ #Néonicotinoïdes #critique de l'information #Article scientifique #Abeilles"),
#  ('Phhennebert',
#   0,
#   'Guerre de communication entre pro et anti #Néonicotinoïdes https://t.co/yRoTW62jne'),
#  ('alexcarre49',
#   15,
#   "#Neonicotinoides \nSi @lemondefr avait de bons #Journalistes\n#Scientifiques voici l'article qu'ils auraient pu écrir… https://t.co/9nVlxYwWvK"),
#  ('LFerreirim',
#   1,
#   '#Neonicotinoides Emails muestran como Bayer y Syngenta querían conocer la info antes de su publicación https://t.co/njFpwsBRWL #SOSabejas'),
#  ('CREAF_ecologia',
#   12,
#   'Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles… https://t.co/a6A98OWC4z'),
#  ('DEROOSEJacques',
#   0,
#   '#Pesticides à base de #neonicotinoides : @PatrickLeHyaric interroge la Commission européenne – Patrick Le Hyaric \nhttps://t.co/BIvgHGp4Ee'),
#  ('Vetitude',
#   0,
#   '#Néonicotinoïdes, les #pesticides tueurs d’ #abeilles https://t.co/qohZ13BIKk via @SciencePresse https://t.co/wbmR1GcbaC'),
#  ('jowbox',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/kfV87kjdC6 #pétition #néonicotinoïdes'),
#  ('EricAndrieuEU',
#   8,
#   '44% des enseignes en infraction. Plutôt que de tergiverser sur les #néonicotinoides, le gvt @EPhilippePM devrait fa… https://t.co/frgkiq7ZFf'),
#  ('idainature',
#   0,
#   '“Los #neonicotinoides dañan las #abejas”, afirma un extenso estudio paneuropeo https://t.co/mTeF0XJzDJ'),
#  ('nbl78',
#   0,
#   '#Néonicotinoïdes, les #pesticides tueurs d’ #abeilles https://t.co/i6rSE1wXXu via @SciencePresse https://t.co/yz2pjqhtUC'),
#  ('fbellier',
#   0,
#   '#neonicotinoides @EmmanuelMacron aka Jupiter a capitulé sans même livrer bataille pour les Français. ^^ #fake'),
#  ('xavierlouyDLF',
#   1,
#   'Ça se vérifie déjà : Big Pharma et #Vaccins / Chimie et #Neonicotinoïdes / #Banques et taxe #Traders / Medef et… https://t.co/45AUb6a3qW'),
#  ('PatrickLeHyaric',
#   5,
#   "Les abeilles, c'est la vie !\nL'Interview intégrale de L'Humanité sur les #néonicotinoïdes et le #JEFTA ici :… https://t.co/s2aoSYWLvZ"),
#  ('PatrickLeHyaric',
#   3,
#   'Nouvelle vidéo : Interview de @humanite_fr sur les #pesticides à base de #neonicotinoides et le #JEFTA \nhttps://t.co/by0Hdti49k'),
#  ('edu_wildlife',
#   0,
#   'Birding and bee-spotting in farmland around Little Crosby. Saw more on the walk through housing estate on the way!… https://t.co/bYzyTC5T7E'),
#  ('Apiculture84',
#   0,
#   'Deux études à grande échelle confirment les dégâts des #néonicotinoïdes sur les #abeilles : ils diminuent la... https://t.co/ewkAAtDV0B'),
#  ('apivital',
#   0,
#   "L'apiculteur accusant les #néonicotinoïdes de tuer ses abeilles doit prouver qu'il a bien traité le parasite #Varroa https://t.co/5ZxWVvQfMw"),
#  ('vbaralle',
#   0,
#   '#Pesticides : deux études confirment la nocivité des néonicotinoïdes\nhttps://t.co/BTUurMD4Iq\n#Neonicotinoides… https://t.co/4We5zrs5aV'),
#  ('CarlosPovedaC',
#   1,
#   '#Colapso de #abejas, tremendo lío #CCD #Pesticidas #Neonicotinoides https://t.co/OakvckU1Ic vía @elespectador'),
#  ('fartpit',
#   0,
#   "Confidor kills Bees. Stop buying it from stores who really don't give a damn but first thing stop using the rubbish #bees #neonicotinoides"),
#  ('FredInterstice',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/APC85LghSz #pétition #néonicotinoïdes'),
#  ('pilzpizza',
#   0,
#   'Massenhaft Klee im Freibad - nicht eine einzige Biene. Danke, @Bayer &amp; Co. #neonicotinoides https://t.co/8eAfaPMEV2'),
#  ('biperbapore',
#   0,
#   '#Enmarche oui mais #EnMarcheArriere taxe financiere #neonicotinoides #perturbateursendocriniens travailleur détaché https://t.co/dhO4FTJ93B'),
#  ('_miss_ives_',
#   6,
#   'Comment sauver les insectes pollinisateurs de l’extinction ? https://t.co/3RaMWDhrJo\n\n#Pesticides #abeilles #neonicotinoides @N_Hulot'),
#  ('Ludovic_Loustau',
#   1,
#   'Pollinisation par les abeilles récolte par le jardinier dans #LaHuertaDeLudo une culture #écologique non aux… https://t.co/Ig6UKIV7Qy'),
#  ('PolepolePat',
#   0,
#   '#Néonicotinoïdes, les #pesticides tueurs d’#abeilles. @Isaburgun présente les #recherches. https://t.co/Zq7waNNnPq\nVia @SciencePresse'),
#  ('tdp591',
#   0,
#   '@StTRAVERT #néonicotinoïdes  @AssoPollinis https://t.co/IXfE09GtrS 😠😠😠😠😠😠'),
#  ('Emmanimals',
#   0,
#   '#UIPP #Pesticides #Néonicotinoïdes #FNSEA #pollution #agriculture #santé #poison #pollution \n\nhttps://t.co/IZV2W2ybGR'),
#  ('KnowYourLeaker',
#   0,
#   'Insecticides : Travert Admet Un Retour En Arrière (pls RT↺❤️) ️️ https://t.co/sB9TYKSeJk #néonicotinoïdes #pesticid'),
#  ('YanThoinet',
#   1,
#   'Deux nouvelles études confirment la toxicité des #néonicotinoïdes sur les #abeilles https://t.co/gCWhI719dc #Agriculture #Pollinisation'),
#  ('Valerie75020',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/twTFXI9X5A #pétition #néonicotinoïdes'),
#  ('jeuxopla',
#   0,
#   "Reception du bat d'un jeu sur commande... D'actualité ! @MRJC_com #neonicotinoides #nicolashulot #agriculture… https://t.co/yDJF8SSygT"),
#  ('alexcarre49',
#   0,
#   '@ChrisRBarbey @thi_loup @N_Hulot Une lecture scientifique des études #Neonicotinoides conduit à un tout autre disco… https://t.co/c6xZpEhEDq'),
#  ('alexcarre49',
#   0,
#   "@ChrisRBarbey @thi_loup En fait la nationalité des apiculteurs a significativmnt + d'impact que les… https://t.co/WThonaY7YQ"),
#  ('sebrioux',
#   0,
#   'Deux études confirment la nocivité des insecticides #néonicotinoïdes pour les #abeilles https://t.co/hTLkLQaf6p #Science #Environnement'),
#  ('DrFishmarketing',
#   2,
#   'Headlining the environment and energy section of @conversationuk with #neonicotinoides research from @CEHScienceNews https://t.co/PTvV43ehjr'),
#  ('nathd_150',
#   0,
#   'Laissez-nous tranquille!!!  #néonicotinoïdes🐝🐝🐞🦋 https://t.co/v8nNMDkNOo'),
#  ('NliteNinc',
#   0,
#   "@PopSci u can help save #bees by plantin flowers https://t.co/rckoIWrabq\n\nNO U CAN'T\n\nU R masking the real problem:… https://t.co/GmM5Ticr50"),
#  ('njyr',
#   0,
#   'Finally some reasonable coverage on #neonicotinoides on @BBCRadio4 inside science. Balanced and had some depth.'),
#  ('ParkSlopeGossip',
#   0,
#   'Very disappointed to see @HomeDepot still using #neonicotinoides I remember they were suppose 2 pull them. Buy loca… https://t.co/20MNLRGrEZ'),
#  ('mondoBioDiverso',
#   0,
#   'Ma i #neonicotinoides fanno male alle api o no? I dati di questo articolo smentiscono le conclusioni @renatosartini https://t.co/MrKTGQhrPp'),
#  ('tgouault',
#   0,
#   "S'il pouvait signer l'arrêt de mort des #neonicotinoides ! Sauvons les abeilles ! https://t.co/zez7Z0Ewc8"),
#  ('JensFunancials',
#   0,
#   "Syngenta exec interview hurts my ears 👹 Independent report that isn't in their commercial interests is refuted. #neonicotinoides"),
#  ('Maat_Vienna',
#   0,
#   '#glyphosate #neonicotinoides\n\nPesticides really are decimating #honeybee pollinators by killing workers and queens… https://t.co/rCFxalPzNI'),
#  ('CaramelParsley',
#   0,
#   '#oyster farmers request to use #neonicotinoides in aquatic #environment https://t.co/juf7u6nRQx #toxic #imadacloprid #oceans #ecosystems'),
#  ('xavierlouyDLF',
#   0,
#   '@Deboutlf06 @lemondefr @dupontaignan Et ceux qui bossent pour le Reich du #néolibéralisme, vous les classez où ?… https://t.co/Pyx5pFRX5h'),
#  ('LFerreirim',
#   4,
#   'Los #neonicotinoides en los tribunales de Canadá por matar a las abejas #SOSabejas https://t.co/Ldu1oXo1t0'),
#  ('GCerez',
#   5,
#   'À 6 ans, @Olivier_API31 construit sa 1ère ruche. À 27 ans, il défend les abeilles contre les #néonicotinoïdes https://t.co/J4uh7IxegS'),
#  ('FFAP_Apipro',
#   2,
#   "#MakeFranceGreenAgain c'est interdire au plus vite les #néonicotinoïdes et les #pesticides tueurs d'#abeilles pour… https://t.co/K480dVkgxA"),
#  ('martapahissa',
#   0,
#   'Diu @CREAF_ecologia cal #agriculturaecologica pq #abelles disminueixen i #pesticides com #neonicotinoides són causa https://t.co/fZcTkClq3o'),
#  ('NickdeCusa',
#   1,
#   "quels sont 6 couacs du gouvernement sur le sujet des #neonicotinoïdes tueurs d'#abeilles ? https://t.co/K2QBiFrLzT Via @Contrepoints"),
#  ('citedeleconomie',
#   6,
#   '#Biodiversité En savoir + sur les #neonicotinoides en 2 #dataviz &amp; 2 vidéos https://t.co/zomMRYvf3A… https://t.co/2bsU9qTWfT'),
#  ('apivital',
#   0,
#   "Les conclusions de l'étude pan-européenne sur la toxicité des #néonicotinoïdes pour les abeilles sont très contesté… https://t.co/7tuZc7woy8"),
#  ('RegBaschung',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/wiBTYSGkd3 #pétition #néonicotinoïdes'),
#  ('alematraz',
#   0,
#   '#pollinators #Pesticides #neonicotinoides https://t.co/5wWwcz0tvm'),
#  ('zenflowerbeauty',
#   0,
#   '23% more bees🐝🐝🐝 #died #lost #queen #science #stopped #cleaning #hives #no #direction #neonicotinoides #poor #bees \nhttps://t.co/gKbDIeO2l5'),
#  ('RichardBouigue',
#   7,
#   'Apres le cafouillage sur les #neonicotinoides, la reculade sur les #perturbateursendocriniens, @N_Hulot très attend… https://t.co/JqcwdkMzcV'),
#  ('xavierlouyDLF',
#   2,
#   '@fmomboisse @JunckerEU "Nous sommes ridicules" serait plus juste. L\' #UE coûte cher aux citoyens et ne protège que… https://t.co/dvx6lwVAXL'),
#  ('EDarier',
#   0,
#   'Qui a tué la reine? #pesticide #neonicotinoides #abeille  https://t.co/Lv6vzOfaEk https://t.co/mykd5LVZeJ'),
#  ('ichtus765',
#   0,
#   '@radioclassique @delphinebatho @delphinebatho....Grosse déception ! vous espérez encore 1 poste ou quoi? Pas la pei… https://t.co/tOYDbOtdh2'),
#  ('apivital',
#   3,
#   'Les abeilles peuvent détoxifier nicotine ou #néonicotinoïdes si elles sont bien nourries (énergie) et en bonne santé https://t.co/I6mdr5Nhji'),
#  ('Charmag_Dessin',
#   1,
#   '#CodeDuTravail #laRepubliqueEnMarche #neonicotinoides\nhttps://t.co/bJzJD32dSD https://t.co/6Zko0svrs4'),
#  ('GirardiMedioAmb',
#   6,
#   'La exposición crónica a los #neonicotinoides reduce la salud de las #abejas cerca de cultivos de #choclo #sosabejas… https://t.co/eszF2yiUi3'),
#  ('GirardiMedioAmb',
#   1,
#   'Patrimonio natural en riesgo! #Abejas salvajes/nativas son más vulnerables a los #neonicotinoides que las domésticas https://t.co/7KmdmgntDt'),
#  ('Stellane',
#   0,
#   'Deux études à grande échelle confirment les dégâts des néonicotinoïdes sur les abeilles https://t.co/NzOAKU58wX #Néonicotinoïdes'),
#  ('CREAF_ecologia',
#   3,
#   '#abelles #neonicotinoides #pesticides @vcoan207 https://t.co/uPUWQDrmOl'),
#  ('design_question',
#   0,
#   '#neonicotinoides Professori uusista tutkimustuloksista torjunta-aineiden haitoista pölyttäjille: "Lisää paineita tä… https://t.co/RqDiZCSCJJ'),
#  ('Gomecello',
#   0,
#   'Los #neonicotinoides son incluso más perjudiciales de lo que se creía para los insectos, especialmente abejas. https://t.co/ly9dUgiW1C'),
#  ('VRoziere',
#   4,
#   "Le coup était passé près pour les #néonicotinoïdes, pour les #PerturbateursEndocriniens ça n'a pas loupé ! Bon appé… https://t.co/fa8d2JVojq"),
#  ('behybe',
#   0,
#   '#revuedepresse #polonytv #neonicotinoides #CongresVersaille #FMIC #Nestlé https://t.co/DtUFw4NU7x'),
#  ('CarreJardiniers',
#   1,
#   'Spécialiste des #neonicotinoides ? \nPrenez la parole sur notre #blog : https://t.co/EBu04UpdWC! \n\n+ d’infos en MP 🐝 https://t.co/D9iDVTvQ76'),
#  ('rajotteg',
#   0,
#   'Les #pesticides #néonicotinoïdes sont bel et bien nocifs pour les #abeilles https://t.co/tz7F5e3QGB #santé #biodiversité #néonics'),
#  ('KateMobij',
#   1,
#   '🔴 voilà ce qui arrive aux oiseaux après avoir avalé ds semences traitées au #neonicotinoides @greenpeacefr @N_Hulot  https://t.co/4JPM50mzns'),
#  ('EricAndrieuEU',
#   38,
#   "Après les #neonicotinoides, le gvt s'illustre en votant la proposition controversée de la @EU_Commission sur les… https://t.co/kShYAcsobs"),
#  ('GanceVerite',
#   1,
#   '#Bayer a accidentellement financé une étude qui montre que les #pesticides tuent les #abeilles... https://t.co/bJIgCEUmOM … #néonicotinoïdes'),
#  ('apivital',
#   4,
#   "Si la colonie d'abeilles est parasitée #Varroa, ses butineuses récoltent du nectar avec nicotine ou #néonicotinoïdes https://t.co/0M7bTlDxJA"),
#  ('science_actus',
#   0,
#   '8 min #Actu #Science #Oiseau en rythme #Abeilles et #néonicotinoïdes #Olm ou #protée #Débrisspatiaux… https://t.co/CFjqullfzR'),
#  ('citedessciences',
#   0,
#   '🎬 8 min\n#Actu #Science \n➡️ #Oiseau en rythme \n➡️ #Abeilles et #néonicotinoïdes\n➡️ #Olm ou #protée\n➡️… https://t.co/2gzFEgPMWu'),
#  ('JPSentucq',
#   0,
#   'Déclin des #abeilles : les #pesticides #néonicotinoïdes à nouveau accusés https://t.co/xeez6rHtMR'),
#  ('f_fusterfabra',
#   0,
#   'Medioambiente: Confirmado: los #neonicotinoides están matando a las #abejas  @lavanguardia https://t.co/gEs2JwR3zh #interesescreados'),
#  ('QuebecScience',
#   3,
#   'Les #néonicotinoides sont bel et bien nocifs pour les pollinisateurs et les #abeilles domestiques, selon 2 études… https://t.co/k5VcjYIuxQ'),
#  ('beret_vert',
#   0,
#   "@beestoufly @Scquickk L'arnaque serait que seule la France soit soumise à l'interdiction des #neonicotinoides… https://t.co/OnEIybzudT"),
#  ('redapicolachile',
#   5,
#   'Estudio Europeo demuestra que los #Neonicotinoides afectan gravemente a las Abejas https://t.co/zhcmvwsZHJ… https://t.co/hAyYD6s535'),
#  ('pace38000',
#   0,
#   "@dajotheo @RemDumDum @29aatea ben bien sûr ! ouf ! J'aimerai que @RemDumDum lisent les articles démontrant la nociv… https://t.co/ArnxpySzrk"),
#  ('palaisdecouvert',
#   3,
#   '#Néonicotinoïdes : réel #danger pour les #abeilles \n#biodiversité\nhttps://t.co/BHxnIGZ0NZ https://t.co/4Dn0smaUrE'),
#  ('citedessciences',
#   4,
#   '#Néonicotinoïdes : réel #danger pour les #abeilles\n\n#biodiversité\nhttps://t.co/cpdNln40s0 https://t.co/uUxHLD1GYy'),
#  ('berblanc2',
#   6,
#   '26/6 Le ministre de l’#Agriculture, @StTRAVERT de porc veut réautoriser les #néonicotinoïdes. Ah, oui @EmmanuelMacron aime les #abeilles !'),
#  ('ScienceActu',
#   0,
#   '#Néonicotinoïdes : réel #danger pour les #abeilles \n#biodiversité\nhttps://t.co/39BIeMsfLo https://t.co/DnpqsSgBq1'),
#  ('blackgull',
#   0,
#   'Hard to kick habit when bored on a nest #neonicotinoides https://t.co/bIY4876oNo'),
#  ('Madison_vert',
#   0,
#   '2 études confirment que les #néonicotinoïdes nuisent aux #abeilles https://t.co/6bKV29jkEr #biodiversité'),
#  ('leveil2017',
#   5,
#   '#Bayer a accidentellement financé une étude qui montre que les #pesticides tuent les #abeilles...… https://t.co/Y7WAHvI4RS'),
#  ('AgenceSymbiotik',
#   0,
#   "2 études d'ampleur incriminent les #néonicotinoïdes dans le déclin des #abeilles : https://t.co/grMklL8Ynr… https://t.co/SqvvsBjdmu"),
#  ('thi_loup',
#   3,
#   "#Néonicotinoïdes  et abeilles\xa0: encore de la «\xa0science com'\xa0» à but politique https://t.co/MDDzc5LWAE"),
#  ('ErwanWeymeersch',
#   0,
#   '"Imaginez un éleveur perdre 30% de ses agneaux" https://t.co/55QmQixXUj @LaurenceAbeille #agriculture #pesticides #néonicotinoïdes'),
#  ('29aatea',
#   2,
#   "Néonicotinoïdes et abeilles\xa0: encore de la «\xa0science com'\xa0» à but politique https://t.co/lQT86Ufqrs #Néonicotinoïdes"),
#  ('Fred_is_raide',
#   0,
#   "@EURACTIV_FR @AssoPollinis Bon, surtout ca a l'air bien inutile comme décision. #neonicotinoides #abeilles https://t.co/np4cH94DU7"),
#  ('consoglobe',
#   7,
#   '#Pesticides : deux études confirment la nocivité des #neonicotinoides https://t.co/qzgl1yyxBF https://t.co/FEWLMOi9xE'),
#  ('AugustinDeback',
#   0,
#   "Deux nouvelles études sur l'impact des #néonicotinoïdes... https://t.co/6m2TuAU7Ku"),
#  ('VolontePaysanne',
#   0,
#   '#Néonicotinoïdes : «des alternatives doivent être disponibles» [point de vue] via @VolontéPaysanne https://t.co/DeoL7pjaeI'),
#  ('fukushima_actu',
#   0,
#   '#NoNuke #AntinNucléaire news is out! https://t.co/ILKFc1RwsZ Stories via @wotinfonl @FuturNoNuclear @After_Fukushima #néonicotinoïdes'),
#  ('nixhorizon',
#   0,
#   'Results finally in: #neonicotinoides reduce capacity of #bees to establish new populations https://t.co/MGRIb3qeSD'),
#  ('PCDoctor_Kam',
#   0,
#   'RT @dw_environment: A study confirms that pesticides are killing the #bees. #neonicotinoides https://t.co/M1bHu6u04J https://t.co/Lj2bG279zC'),
#  ('Labour4Animals',
#   15,
#   '#Countryfile report LARGE-SCALE study on impact of #neonicotinoides by 🐝@CEHScienceNews shows +/-25% decline in Bee… https://t.co/T1YzUgHkzx'),
#  ('shillorganics',
#   0,
#   "Planting nectar-rich flowers on boundaries of crops that use #neonicotinoides doesn't sound like a fair trade-off to me #ChooseOrganic 😭🐝"),
#  ('M_Z_Harrison',
#   9,
#   'Good, clear, unambiguous message on #neonicotinoides from Countryfile there. They harm bees.'),
#  ('science_actus',
#   0,
#   '8 min #Actu #Science #Oiseau en rythme #Abeilles et #néonicotinoïdes #Olm ou #protée #Débrisspatiaux… https://t.co/O9j10OGDAT'),
#  ('UniverscienceTV',
#   2,
#   '🎬 8 min\n#Actu #Science \n➡️ #Oiseau en rythme \n➡️ #Abeilles et #néonicotinoïdes\n➡️ #Olm ou #protée\n➡️… https://t.co/6AW87ftx1O'),
#  ('x_CousinHub',
#   6,
#   "La #cravate pendant qu'on présentait comme #intox l'information d'un ministre de la République. #Travert #neonicotinoides #CeuxQuiNeSontRien"),
#  ('olivierestiez',
#   1,
#   'Deux études financées par #Bayer et #Syngenta concluent au danger des #néonicotinoïdes pour les #abeilles 🐝 ! https://t.co/xQlkrtnimE'),
#  ('MadameVarda',
#   1,
#   "nommée pdte #fondationHulot @AudreyPulvar dit stop aux #néonicotinoïdes mais ne parle pas d'épandages https://t.co/gTqRERMXTR… #ecoFeministe"),
#  ('jmleluc',
#   4,
#   'TRÈS bon déroulé des "couacs" #neonicotinoides : "Il est temps...qu\'on ne commente pas les travaux en cours, et....… https://t.co/uwHMzxlbiK'),
#  ('LuneauAurelie',
#   1,
#   '#Neonicotinoides, Travert-#Hulot, quels arbitrages possibles ? Auj 16-17h ds #DCAeffets sur @franceculture… https://t.co/gb4i47CFDy'),
#  ('RadioTeleSuisse',
#   3,
#   "Les #néonicotinoïdes , des tueurs d'abeilles ? Les ravages des insecticides sur la #biodiversité dans le #19h30RTS… https://t.co/DMJJVEKOGZ"),
#  ('alematraz',
#   0,
#   '#pollinators #bees #neonicotinoides #polinizadores #abejas #riesgosambientales https://t.co/V8XfG17GFe'),
#  ('m_cambon',
#   4,
#   'Cette semaine dans la @TerreDauph \n#Hulot #Travert #neonicotinoides https://t.co/fwRAqbokIW'),
#  ('m_cambon',
#   11,
#   'Cette semaine dans les @LesAffiches38 \n#neonicotinoides #picnic https://t.co/U6Z9vSbcI8'),
#  ('ptitoursblanc',
#   0,
#   'oh oui je la sent ..fondre tout près de nos orifices et ceci sans douleur ..\n\n#pesticide #neonicotinoides https://t.co/42uLfMWaAt'),
#  ('v_virtu',
#   1,
#   'Deux études à grande échelle confirment les #Dégâts des #Néonicotinoïdes sur les #Abeilles\nhttps://t.co/depunm2vMn'),
#  ('thi_loup',
#   1,
#   '#Néonicotinoïdes et couacs gouvernementaux\xa0: où sont les agriculteurs\xa0? https://t.co/bBcfmhT4Jn'),
#  ('apivital',
#   6,
#   "Les pertes hivernales sont attribuées aux #néonicotinoïdes sans évaluation de l'état sanitaire (#Varroa + virus DWV… https://t.co/skcKqg1VUi"),
#  ('apiberica',
#   2,
#   'Confirmado: los #neonicotinoides están matando a las #abejas  @lavanguardia https://t.co/vrQRV6oQir'),
#  ('apivital',
#   0,
#   "@Olivier_LG @Slate Pertes hivernales de colonies d'abeilles attribuées aux #néonicotinoïdes, sans évaluation  sanitaire: #Varroa + virus DWV"),
#  ('apivital',
#   0,
#   "Selon une étude récente, 2 #néonicotinoides ont causé des pertes d'abeilles en Hongrie. Pas de dégâts en Allemagne ! https://t.co/zQU7fVCzRP"),
#  ('jojobles',
#   0,
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/GvIxqt9tb9 #pétition #néonicotinoïdes'),
#  ('ptitoursblanc',
#   0,
#   "pour qui as tu le plus d'affection? toi ?tes gosses ?\npeace\n\n#nature #neonicotinoides #abeilles @N_Hulot… https://t.co/6FF2rWObuU"),
#  ('voedselanders',
#   14,
#   'Voor #bijen is 1 gram Imidacloprid net zo giftig als 7 kilo DDT ..... #neonicotinoides https://t.co/DKYfajuMVV'),
#  ('thierrybeaucamp',
#   0,
#   '#Bees #Abeilles #Néonicotinoïdes 👎🏻 https://t.co/KrZ7r0Tgpb'),
#  ('RemDumDum',
#   18,
#   "L'étude Landmark montre que les pesticides #neonicotinoides améliorent la santé des abeilles \n\nhttps://t.co/PxQf4jYX20"),
#  ('RemDumDum',
#   55,
#   "Est-ce que les #neonicotinoides sont des tueurs d'#abeilles ?\n\nLes médias disent Oui !\nLes données disent Non ! \n\nhttps://t.co/PxQf4jYX20"),
#  ('RemDumDum',
#   4,
#   '@pace38000 sauf que la nicotine est T+\nhttps://t.co/RWdBWnPpL6\n\net les #neonicotinoides Xn \n\nhttps://t.co/xUgPCtrH1p'),
#  ('laurapopedenman',
#   0,
#   '@sciam @leslie_nemo loss of #insect eating #songbirds #swallows may well be linked to #neonicotinoides -study on this b useful \n@CBCQuirks'),
#  ('jmleluc',
#   7,
#   '#Néonicotinoïdes : Ce n’est que le début d’un débat sur le fond... https://t.co/km597WEZVG via @pfphyto https://t.co/U7qJOjvtRX'),
#  ('LeSexDansLaCite',
#   0,
#   'RT @Polony_tv Retrouvez la revue de presse de cette semaine par @NPolony ➤ https://t.co/rG0IxCptoF #neonicotinoides  https://t.co/576Ct9NBJy'),
#  ('FlavienMoreau',
#   1,
#   "Ces élus qui préfèrent écouter les lobbies plutôt que les scientifiques:  https://t.co/r29SWeF6KT (12'45) @jean_bizet #neonicotinoides"),
#  ('palaisdecouvert',
#   2,
#   '🎬 8 min\n#Actu #Science \n➡️ #Oiseau en rythme \n➡️ #Abeilles et #néonicotinoïdes\n➡️ #Olm ou #protée\n➡️… https://t.co/4aWXYr0vYm'),
#  ('Sophiecuisine',
#   0,
#   'The latest The cuisine Daily @Sophiecuisine! https://t.co/jeh2L2hOuz Thanks to @recettesduqc @NanieBears @Tiuscha #glace #néonicotinoïdes'),
#  ('marcottlyse',
#   0,
#   'La nocivité du #pesticide «tueur d’abeilles» confirmée\nLes #néonicotinoïdes réduisent le taux de survie des... https://t.co/coaB4XjfLy'),
#  ('io_r_us',
#   0,
#   "@Slate Isn't the entire purpose of science and research to make complicated data structures and comprehensible ? St… https://t.co/RkL0eZZexK"),
#  ('ginachron',
#   4,
#   'Study shows Pesticides damage #bee survival. #neonicotinoides \nhttps://t.co/5rDAxSISVk MT'),
#  ('dingerjoe',
#   0,
#   '#Abeilles : deux études choc confirment la nocivité des #néonicotinoïdes ◾ Geo.fr https://t.co/pdoucOENWb'),
#  ('VictorBledor',
#   2,
#   '#Néonicotinoïdes : un buzz bien orchestré https://t.co/uNXrkA5puZ #fdsea28 via @FDSEA28'),
#  ('Vetitude',
#   4,
#   'Deux études à grande échelle confirment les dégâts des #néonicotinoïdes sur les #abeilles https://t.co/85YxyotTwm https://t.co/aF4gb0zJ7p'),
#  ('Polony_tv',
#   65,
#   'Retrouvez la revue de presse de cette semaine par @NPolony ➤ https://t.co/fijynKtKlV #neonicotinoides… https://t.co/5u3JHG4hl3'),
#  ('2Maria6925',
#   2,
#   'Pétition pour la protection des pollinisateurs : POLLINIS #abeilles #neonicotinoides #environnement #ecologie\n https://t.co/u4fPrBDsHc'),
#  ('balxHa',
#   1,
#   "études traitent de l ' utilisation de néonicotinoides  sur colza, mais  pas d ' utilisation de #neonicotinoides  su… https://t.co/lgXyqG8OWk"),
#  ('QuestoyQueLotro',
#   0,
#   'El pesticida que mata a las abejas del mundo\nhttps://t.co/X8nogj5lUF\n\n#neonicotinoides\n#NuevoLaredo\n#Ecologia\n#Apicultura\n#Yucatán\n#Colima'),
#  ('balxHa',
#   0,
#   "@FranceAgricole pas d ' utilisation de #neonicotinoides  sur colza en France"),
#  ('upr59',
#   1,
#   "Retour sur le couac gouvernemental autour des #néonicotinoïdes.\nL'UPR a un programme cohérent sur ce sujet. Nous... https://t.co/XU5u9WHxpL")]

# %%
[(s["user"]["screen_name"],s["text"]) for s in statuses]
# Out:
# [('pascal_pm',
#   "RT @NPolony: Nous le disions: il y a l'affichage et il y a les enjeux concrets face aux lobbys #neonicotinoides  https://t.co/z1IMWfOGCK vi…"),
#  ('pascal_pm',
#   'RT @Polony_tv: "Les plus lucides se diront que #Macron avait promis de ne pas revenir sur cette interdiction des #neonicotinoides" ➤https:/…'),
#  ('pascal_pm',
#   'RT @Polony_tv: Retrouvez la revue de presse de cette semaine par @NPolony ➤ https://t.co/fijynKtKlV #neonicotinoides #CongresVersailles #FM…'),
#  ('julienbrab',
#   "RT @LaFakeAgricole: Alternatives aux #neonicotinoides :l'Anses autorise Froome,un #insecticide 100 % naturel,qui fait aussi #herbicide et a…"),
#  ('LaFakeAgricole',
#   "Alternatives aux #neonicotinoides :l'Anses autorise Froome,un #insecticide 100 % naturel,qui fait aussi #herbicide… https://t.co/P0dCNrScMg"),
#  ('Klompsoares',
#   'RT @MichelsJoost: Mijn bijen zijn bijna klaar voor de Nederlandse lente... En graag zonder #neonicotinoides, beste boeren. https://t.co/BzH…'),
#  ('elBetoReyna',
#   'RT @ApiEcologica: En fin... https://t.co/zCK2jp7qXc \n#abejas #apicultura #ColonyCollapseDisorder #neonicotinoides #acaricidas #pesticidas'),
#  ('PnjeaOueme',
#   'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…'),
#  ('cedfry',
#   'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…'),
#  ('MPeala',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/BSlUs7lqJ6 #pétition #néonicotinoïdes'),
#  ('pguerret',
#   'RT @mag_vegetable: Les ventes de néonicotinoïdes en hausse https://t.co/lfq0ZwY5gB #gilles-lanio #neonicotinoides #unaf'),
#  ('Referenceappro',
#   "Néonicotinoïdes : alternatives connues dès l'automne\nhttps://t.co/OCTMZPyUS6 @Anses_fr @Referenceappro #neonicotinoides  #Phyto"),
#  ('al_beatrice',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('ContactM2i',
#   'RT @mag_vegetable: Les ventes de néonicotinoïdes en hausse https://t.co/lfq0ZwY5gB #gilles-lanio #neonicotinoides #unaf'),
#  ('mag_vegetable',
#   'Les ventes de néonicotinoïdes en hausse https://t.co/lfq0ZwY5gB #gilles-lanio #neonicotinoides #unaf'),
#  ('GrupoBienComun',
#   'RT @ApiEcologica: En fin... https://t.co/zCK2jp7qXc \n#abejas #apicultura #ColonyCollapseDisorder #neonicotinoides #acaricidas #pesticidas'),
#  ('earlchamignon',
#   'RT @RemDumDum: - y a t il des alternatives aux #neonicotinoides ?\n- ANSES : Réponse début 2018 (à 01:35:00)\n- MOI : NON !\nhttps://t.co/RNnB…'),
#  ('MarcAntoinePass',
#   'RT @LaFakeAgricole: #neonicotinoides : l’interdiction sera décidée à Pierre-Feuille-Ciseaux en 3 points gagnant entre N.Hulot, S.Travert et…'),
#  ('alain_co',
#   'RT @29aatea: #Neonicotinoides #abeilles #Ukraine https://t.co/feqCITtmfF'),
#  ('29aatea', '#Neonicotinoides #abeilles #Ukraine https://t.co/feqCITtmfF'),
#  ('valtxu',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('COSTESLionelEr',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('MddHyvert',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('MddHyvert',
#   'RT @M_Orphelin: Audition DG @Anses_fr Roger Genet commDD #directAN. Au menu : #pesticides #néonicotinoïdes #perturbateursendocriniens #glyp…'),
#  ('PietersEdwige',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/L9UZgJCCf4 #pétition #néonicotinoïdes'),
#  ('RogerGenet',
#   'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…'),
#  ('starwarsapicult',
#   'RT @ApiEcologica: En fin... https://t.co/zCK2jp7qXc \n#abejas #apicultura #ColonyCollapseDisorder #neonicotinoides #acaricidas #pesticidas'),
#  ('silviofratini',
#   'RT @ApiEcologica: En fin... https://t.co/zCK2jp7qXc \n#abejas #apicultura #ColonyCollapseDisorder #neonicotinoides #acaricidas #pesticidas'),
#  ('ApiEcologica',
#   'En fin... https://t.co/zCK2jp7qXc \n#abejas #apicultura #ColonyCollapseDisorder #neonicotinoides #acaricidas #pesticidas'),
#  ('ghislodi',
#   'RT @thi_loup: Audition de Roger Genet pour @Anses_fr #neonicotinoides #pesticides #glyphosate #nanoparticules https://t.co/KyN4fmubrS'),
#  ('aurelienbadet',
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/1Rb823Chms #abeilles #pétition'),
#  ('JFouriau',
#   'RT @thi_loup: Audition de Roger Genet pour @Anses_fr #neonicotinoides #pesticides #glyphosate #nanoparticules https://t.co/KyN4fmubrS'),
#  ('29aatea',
#   'RT @RemDumDum: - y a t il des alternatives aux #neonicotinoides ?\n- ANSES : Réponse début 2018 (à 01:35:00)\n- MOI : NON !\nhttps://t.co/RNnB…'),
#  ('thi_loup',
#   "Les débats scientifiques à l'ANSES sont difficile pour les impacts des #neonicotinoides bataille sur les externalités..."),
#  ('nath_35',
#   'https://t.co/KCxSbsaZI5 via @AssoPollinis "l\'interdiction des #néonicotinoïdes en France: attention danger!"'),
#  ('RemDumDum',
#   '- y a t il des alternatives aux #neonicotinoides ?\n- ANSES : Réponse début 2018 (à 01:35:00)\n- MOI : NON !\nhttps://t.co/RNnB3N3Hi1'),
#  ('G_Haar',
#   'RT @thi_loup: Audition de Roger Genet pour @Anses_fr #neonicotinoides #pesticides #glyphosate #nanoparticules https://t.co/KyN4fmubrS'),
#  ('thi_loup',
#   "RT @thi_loup: Une evaluation globale des biocides est en cours incluant les #neonicotinoides (à la maison) pour mesurer l'exposition"),
#  ('thi_loup',
#   "RT @thi_loup: Une saisine santé humaine des #neonicotinoides sera aussi rendue : c'est médicaments, biocides et les pesticides. Global"),
#  ('thi_loup',
#   "Une evaluation globale des biocides est en cours incluant les #neonicotinoides (à la maison) pour mesurer l'exposition"),
#  ('thi_loup',
#   "Une saisine santé humaine des #neonicotinoides sera aussi rendue : c'est médicaments, biocides et les pesticides. Global"),
#  ('protegevosbiens',
#   'RT @Tweety_doc: Cette étude illustre de façon incontestable la relation entre insecticides #néonicotinoïdes et déclin des butineurs https:/…'),
#  ('blogd1sceptique',
#   'RT @thi_loup: Audition de Roger Genet pour @Anses_fr #neonicotinoides #pesticides #glyphosate #nanoparticules https://t.co/KyN4fmubrS'),
#  ('thi_loup',
#   "RT @thi_loup: La responsable avoue qu'elle n'est pas certaine que nous pourrons répondre un jour à l'effet des #néonicotinoides par usages"),
#  ('thi_loup',
#   "La responsable avoue qu'elle n'est pas certaine que nous pourrons répondre un jour à l'effet des #néonicotinoides par usages"),
#  ('thi_loup',
#   "RT @thi_loup: Sur les #neonicotinoides : le collège d'experts ANSES est bien composé d'agronomes et de chercheurs pour les alternatives"),
#  ('thi_loup',
#   "Sur les #neonicotinoides : le collège d'experts ANSES est bien composé d'agronomes et de chercheurs pour les alternatives"),
#  ('protegevosbiens',
#   'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…'),
#  ('thi_loup',
#   'RT @thi_loup: Audition de Roger Genet pour @Anses_fr #neonicotinoides #pesticides #glyphosate #nanoparticules https://t.co/KyN4fmubrS'),
#  ('fabricemucci',
#   'RT @thi_loup: Audition de Roger Genet pour @Anses_fr #neonicotinoides #pesticides #glyphosate #nanoparticules https://t.co/KyN4fmubrS'),
#  ('imullerquoy',
#   'RT @thi_loup: Audition de Roger Genet pour @Anses_fr #neonicotinoides #pesticides #glyphosate #nanoparticules https://t.co/KyN4fmubrS'),
#  ('nordsud6213',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('thi_loup',
#   'Audition de Roger Genet pour @Anses_fr #neonicotinoides #pesticides #glyphosate #nanoparticules https://t.co/KyN4fmubrS'),
#  ('thi_loup',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('OIL_MEN',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('CeyracSylvie',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('DouxRaisin',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('PBoudailliez',
#   'RT @M_Orphelin: #BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères semaines…'),
#  ('M_Orphelin',
#   '#BonneNouvelle: résultats eval ANSES #néonicotinoïdes et alternatives dispo dès sept2017 pr #céréales &amp;#vin, 1ères… https://t.co/umPp9RnTPn'),
#  ('philippe_lucet',
#   'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…'),
#  ('per2916',
#   "RT @_acouvreur: ➡️Je suis Agri et Apiculteur\n➡️J'utilise #néonicotinoïdes sur blé betterave\n➡️Je protège mes 🐝contre #nosémose et #varroa\n✅…"),
#  ('Prudhomme2017',
#   "@Anses_fr rendra un avis sur les #neonicotinoïdes  à partir de l'automne, complété début 2018... et le #PrincipeDePrecaution ?"),
#  ('WatchCoop',
#   'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…'),
#  ('TristanFRg',
#   'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…'),
#  ('thi_loup',
#   'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…'),
#  ('phil5211',
#   'RT @b_abba: Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides #phytosanitaires qualité #e…'),
#  ('b_abba',
#   'Audition de @RogerGenet DG de l @Anses_fr en #ComDDAT Questions impacts et risques #neonicotinoides… https://t.co/idXJchv3xd'),
#  ('rodrigueaHDF',
#   "#En2740ilyaura des gens dont le métier sera pollinisateur de fleurs car y aura plus d'abeilles pour le faire. Merci les #neonicotinoides"),
#  ('fanch_mrl',
#   'RT @M_Orphelin: Audition DG @Anses_fr Roger Genet commDD #directAN. Au menu : #pesticides #néonicotinoïdes #perturbateursendocriniens #glyp…'),
#  ('mauny63',
#   'RT @M_Orphelin: Audition DG @Anses_fr Roger Genet commDD #directAN. Au menu : #pesticides #néonicotinoïdes #perturbateursendocriniens #glyp…'),
#  ('M_Orphelin',
#   'Audition DG @Anses_fr Roger Genet commDD #directAN. Au menu : #pesticides #néonicotinoïdes… https://t.co/2nrgWCYZPH'),
#  ('boycottons692',
#   'RT @Tweety_doc: Cette étude illustre de façon incontestable la relation entre insecticides #néonicotinoïdes et déclin des butineurs https:/…'),
#  ('CamilleTantale',
#   'RT @Tweety_doc: Cette étude illustre de façon incontestable la relation entre insecticides #néonicotinoïdes et déclin des butineurs https:/…'),
#  ('Yggdras77224625',
#   'RT @Tweety_doc: Cette étude illustre de façon incontestable la relation entre insecticides #néonicotinoïdes et déclin des butineurs https:/…'),
#  ('Cyprien2402',
#   'RT @Tweety_doc: Cette étude illustre de façon incontestable la relation entre insecticides #néonicotinoïdes et déclin des butineurs https:/…'),
#  ('LoudL',
#   'RT @Tweety_doc: Cette étude illustre de façon incontestable la relation entre insecticides #néonicotinoïdes et déclin des butineurs https:/…'),
#  ('inner_force',
#   'RT @Tweety_doc: Cette étude illustre de façon incontestable la relation entre insecticides #néonicotinoïdes et déclin des butineurs https:/…'),
#  ('FrancoisFree',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/8HtX9ixAFV #pétition #néonicotinoïdes'),
#  ('AcatIdf',
#   'RT @MarieDelebassee: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/9Yomdupl6E #pétition #néonicotinoïdes'),
#  ('29aatea',
#   '« + mortelle » pour les abeilles ? #néonicotinoïdes ne méritent pas l’étiquette https://t.co/IeOiHCCfdD  via… https://t.co/NqRmHSAIJE'),
#  ('madyguy1',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/zNxnqa313y #pétition #néonicotinoïdes'),
#  ('mirjossbom',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/ON1gtWK4dX #pétition #néonicotinoïdes'),
#  ('RidingMyWorld',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/jgAvpUPD9V #pétition #néonicotinoïdes'),
#  ('pmeyssonnier',
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/lMNrF8a0P4 #abeilles #pétition'),
#  ('Bioiledefrance',
#   'RT @UNAFapiculture: Deux études à grande échelle confirment les dégâts des #néonicotinoïdes sur les abeilles #StopNeonics #BeeCoherent  htt…'),
#  ('AugePays',
#   "RT @FFAP_Apipro: Sans parler de la #pollution des eaux par les #néonicotinoïdes dont bien peu de monde parle et dont l'État se moque https:…"),
#  ('CindyAdolphe',
#   "RT @FFAP_Apipro: Sans parler de la #pollution des eaux par les #néonicotinoïdes dont bien peu de monde parle et dont l'État se moque https:…"),
#  ('clmbls',
#   "RT @FFAP_Apipro: Sans parler de la #pollution des eaux par les #néonicotinoïdes dont bien peu de monde parle et dont l'État se moque https:…"),
#  ('Arnaud_Schwartz',
#   "RT @FFAP_Apipro: Sans parler de la #pollution des eaux par les #néonicotinoïdes dont bien peu de monde parle et dont l'État se moque https:…"),
#  ('balxHa',
#   "RT @alexcarre49: #Neonicotinoides \nSi @lemondefr avait de bons #Journalistes\n#Scientifiques voici l'article qu'ils auraient pu écrire\nhttps…"),
#  ('FFAP_Apipro',
#   "Sans parler de la #pollution des eaux par les #néonicotinoïdes dont bien peu de monde parle et dont l'État se moque… https://t.co/svECdzxjU3"),
#  ('Chtilaurent62',
#   'RT @DomJDom: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/wZT4rIGZX8 #pétition #néonicotinoïdes'),
#  ('CloeStLaurent',
#   'RT @beestoufly: Tu la sens la grosse arnaque #Hulot ?\n#Neonicotinoïdes \n#Pesticides https://t.co/nJkcMZbAbD'),
#  ('ladyjessparis',
#   'RT @Polony_tv: "Les plus lucides se diront que #Macron avait promis de ne pas revenir sur cette interdiction des #neonicotinoides" ➤https:/…'),
#  ('ladyjessparis',
#   'RT @Polony_tv: Retrouvez la revue de presse de cette semaine par @NPolony ➤ https://t.co/fijynKtKlV #neonicotinoides #CongresVersailles #FM…'),
#  ('paddylille',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/RZ9KOWSSdS #pétition #néonicotinoïdes'),
#  ('FrancoisArnoux',
#   "RT @RemDumDum: Est-ce que les #neonicotinoides sont des tueurs d'#abeilles ?\n\nLes médias disent Oui !\nLes données disent Non ! \n\nhttps://t.…"),
#  ('FrancoisArnoux',
#   "RT @_acouvreur: ➡️Je suis Agri et Apiculteur\n➡️J'utilise #néonicotinoïdes sur blé betterave\n➡️Je protège mes 🐝contre #nosémose et #varroa\n✅…"),
#  ('MichelGoelo',
#   'RT @marielenbenede: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/NHgB8RYoqJ #pétition #néonicotinoïdes'),
#  ('DEROOSEJacques',
#   'Interdiction des #néonicotinoïdes en France : attention danger ! via @AssoPollinis \nhttps://t.co/kPMJVrGXna'),
#  ('rafelvng',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/10RFST9vZb #pétition #néonicotinoïdes'),
#  ('GillesMaillet',
#   'La #Commission #européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/HbVapPtTsa #abeilles #pétition'),
#  ('1toul',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/L3NMb4OxjA #pétition #néonicotinoïdes'),
#  ('Orgukt',
#   'RT @marielenbenede: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/NHgB8RYoqJ #pétition #néonicotinoïdes'),
#  ('Brioso38',
#   'RT @jepensedonc3: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/MlawEvCew2 #pétition #néonicotinoïdes'),
#  ('Enkorplus',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/WIlQga4JOr #pétition #néonicotinoïdes'),
#  ('jepensedonc3',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/MlawEvCew2 #pétition #néonicotinoïdes'),
#  ('Zibouloulous',
#   'RT @marielenbenede: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/NHgB8RYoqJ #pétition #néonicotinoïdes'),
#  ('marielenbenede',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/NHgB8RYoqJ #pétition #néonicotinoïdes'),
#  ('marielenbenede',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('BerlinInsoumise',
#   'RT @IndianaJones_2: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/TpnDCFCaY7 #pétition #néonicotinoïdes'),
#  ('Kloupinait',
#   'RT @beestoufly: Tu la sens la grosse arnaque #Hulot ?\n#Neonicotinoïdes \n#Pesticides https://t.co/nJkcMZbAbD'),
#  ('__Anais1996',
#   'RT @__Anais1996: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/ul3rEd0bnC #pétition #néonicotinoïdes'),
#  ('RosalieBaumert',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/fwdiZK2q9b #pétition #néonicotinoïdes'),
#  ('So_Nia_K',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('marenascar',
#   'RT @edujom: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/IM9pT3y5A9 #pétition #néonicotinoïdes'),
#  ('marenascar',
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/IMgONl6E3D #abeilles #pétition'),
#  ('Lea_Clmrn',
#   'RT @beestoufly: Tu la sens la grosse arnaque #Hulot ?\n#Neonicotinoïdes \n#Pesticides https://t.co/nJkcMZbAbD'),
#  ('edujom',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/IM9pT3y5A9 #pétition #néonicotinoïdes'),
#  ('Nathayla',
#   'RT @MargueriteJm: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/fvY4xpULap #pétition #néonicotinoïdes'),
#  ('MargueriteJm',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/fvY4xpULap #pétition #néonicotinoïdes'),
#  ('ecu92',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/zWXQX6kKs6 #pétition #néonicotinoïdes'),
#  ('marcillat8',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/m7X3DBaU6z #pétition #néonicotinoïdes'),
#  ('jepensedonc3',
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/ynfV3efAU7 #abeilles #pétition'),
#  ('CatMaymard',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/WZvy51Ew0f #pétition #néonicotinoïdes RT svp #green'),
#  ('tamperence',
#   'RT @IndianaJones_2: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/TpnDCFCaY7 #pétition #néonicotinoïdes'),
#  ('hugh6659',
#   'RT @filnoir: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/A7pC1dENK4 #pétition #néonicotinoïdes'),
#  ('rachdemont',
#   'RT @IndianaJones_2: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/TpnDCFCaY7 #pétition #néonicotinoïdes'),
#  ('CdricV',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/z7hTatfjeI #pétition #néonicotinoïdes'),
#  ('clairvoyant_le',
#   'RT @IndianaJones_2: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/TpnDCFCaY7 #pétition #néonicotinoïdes'),
#  ('Bidule9313',
#   'RT @IndianaJones_2: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/TpnDCFCaY7 #pétition #néonicotinoïdes'),
#  ('Jn_Bllt',
#   'RT @IndianaJones_2: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/TpnDCFCaY7 #pétition #néonicotinoïdes'),
#  ('mrabeman',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/6TBqhpxrTx #pétition #néonicotinoïdes'),
#  ('mmia2',
#   'RT @filnoir: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/A7pC1dENK4 #pétition #néonicotinoïdes'),
#  ('0_MoonGirl_0',
#   'RT @filnoir: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/A7pC1dENK4 #pétition #néonicotinoïdes'),
#  ('MylGorre',
#   'RT @filnoir: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/A7pC1dENK4 #pétition #néonicotinoïdes'),
#  ('MerlineMel',
#   'RT @filnoir: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/A7pC1dENK4 #pétition #néonicotinoïdes'),
#  ('liogerard91',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/yWob51YiNB #pétition #néonicotinoïdes'),
#  ('lharmonie3',
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/ODJprf4Syr #abeilles #pétition'),
#  ('filnoir',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/A7pC1dENK4 #pétition #néonicotinoïdes'),
#  ('claudypersonne',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/XLS4RANvc9 #pétition #néonicotinoïdes'),
#  ('filnoir',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('Ifanelix',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/mpRdbVS71I #pétition #néonicotinoïdes'),
#  ('Necropaul',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/sztgqdgUpV #pétition #néonicotinoïdes'),
#  ('Yggdras77224625',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('gabrielamard',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('CubryJeanPierre',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/LGPBx22nkq #pétition #néonicotinoïdes'),
#  ('labbef',
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/VWV7TvBMRt #abeilles #pétition'),
#  ('Capital_Scandal',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/CCh3RPAyHA #pétition #néonicotinoïdes'),
#  ('cloudin_bluesky',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('LepoutreQuentin',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('TijucaSophie',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('skouarnanOriant',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('Andresia_M',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('louiebfree',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/tesPmPGLcu #pétition #néonicotinoïdes'),
#  ('Lushe_Ren_Ren',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('Z_gote',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('YAJANUASICUT',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('CdricLameignere',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('julienbayou',
#   'RT @anyesway: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('PereMalo',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/n6BKY7x6B0 #pétition #néonicotinoïdes'),
#  ('drapeau_rouge',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/riEvsk2zMB #pétition #néonicotinoïdes'),
#  ('leoxymoron',
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/VTDJE16Woa #abeilles #pétition'),
#  ('les_fees_nature',
#   'RT @ecolosenat: #Pesticides #neonicotinoides Communiqué de @JLabbeSenat https://t.co/6vn8ColMZY'),
#  ('NLlinsoumise',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/vTJriucgbi #pétition #néonicotinoïdes'),
#  ('Linwelyn',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/E4682EYJiQ #pétition #néonicotinoïdes'),
#  ('PoussyIV',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/kVBbvgZCbE #pétition #néonicotinoïdes'),
#  ('mhhoodoo',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/je4kkDuxC2 #pétition #néonicotinoïdes'),
#  ('loic_delage',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/tvz4SHYGMU #pétition #néonicotinoïdes'),
#  ('Amandine_GB',
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/LsH8R9Qyh4 #abeilles #pétition'),
#  ('anyesway',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/X5OLUVjrJh #pétition #néonicotinoïdes'),
#  ('CPNBRABANT',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/K2Z86dCfMh #pétition #néonicotinoïdes'),
#  ('r3JUxnWe5YwiqST',
#   'RT @frOOmis54: Il est possible de vivre sans #neonicotinoides.\nIl est impossible de vivre sans les abeilles.\nFaut-il vraiment faire un comp…'),
#  ('deci0',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/wPQaCXUvkV #pétition #néonicotinoïdes'),
#  ('nonalausterite',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/5zaiZiQwh1 #pétition #néonicotinoïdes'),
#  ('ravelje',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/Y9VHKfFDt4 #pétition #néonicotinoïdes'),
#  ('franca64120',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/TND4QXUpj2 #pétition #néonicotinoïdes'),
#  ('IgorleChat',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/SsjAYi5MMW #pétition #néonicotinoïdes'),
#  ('NChevesson',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/aU6xpSpNz1 #pétition #néonicotinoïdes'),
#  ('coraliecarmi',
#   'RT @AliasLautre: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/YAR4ljKzhJ #pétition #néonicotinoïdes'),
#  ('MichelSain',
#   'La Commission européenne planche sur une interdiction totale des #néonicotinoïdes ! https://t.co/MdGYQOIp2n #abeilles #pétition'),
#  ('BidaultVero1',
#   'RT @a_robin10: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/PCgxznpXIg #pétition #néonicotinoïdes'),
#  ('a_robin10',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/PCgxznpXIg #pétition #néonicotinoïdes'),
#  ('AliasLautre',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/YAR4ljKzhJ #pétition #néonicotinoïdes'),
#  ('__Anais1996',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/ul3rEd0bnC #pétition #néonicotinoïdes'),
#  ('StephFulgence',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/hQhZa8Ecdl #pétition #néonicotinoïdes'),
#  ('alternat5',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/0OWScE0pJa #pétition #néonicotinoïdes'),
#  ('Stephen_Mark_',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/FTbS2At3Um #pétition #néonicotinoïdes'),
#  ('LEGASTELOIS',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/vX86iy9OKp #pétition #néonicotinoïdes'),
#  ('jc_lomba',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/UKCS9PRcEd #pétition #néonicotinoïdes'),
#  ('IsadoraNizard',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/COTuQm8tci #pétition #néonicotinoïdes'),
#  ('jepensedonc3',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/cvmIuxHpr0 #pétition #néonicotinoïdes'),
#  ('be_leclercq',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/yPivFaOqDC #pétition #néonicotinoïdes'),
#  ('maldini_albert',
#   "RT @UNAFapiculture: #Néonicotinoïdes &gt;&gt; Chiffres révélés par l'UNAF : en France, les ventes en hausse de 4% malgré l'interdiction UE https:…"),
#  ('swm320tl',
#   'RT @DomJDom: Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/wZT4rIGZX8 #pétition #néonicotinoïdes'),
#  ('clnjmp',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/FG66qvR9MF #pétition #néonicotinoïdes'),
#  ('Randysud',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/gq4NGJ6qTg #pétition #néonicotinoïdes'),
#  ('benjam_caron',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/BXYTUdGODg #pétition #néonicotinoïdes'),
#  ('CorreaVillalobo',
#   'Nous n’avons jamais été aussi près de sauver les #abeilles en Europe https://t.co/IqFaUkSkfo #pétition #néonicotinoïdes'),
#  ('M_Gottsacker',
#   'RT @klaus_schilder: Falter ade? Wir brauchen endlich ein Verbot von #neonicotinoides und anderen Agrargiften in der #EU - #BaySanto https:/…'),
#  ('thi_loup',
#   '@ConversationUK L\'auteur défend les #neonicotinoides "un rôle vital pour la production alimentaire" et "une réduction des usages aériens"'),
#  ('thi_loup',
#   'Auteur étude #neonicotinoides : notre recherche a montre des effets mais il est encore utile https://t.co/s0XswGL4TY via @ConversationUK'),
#  ('ChrisCathrine',
#   '#neonicotinoides study author hits back at critics pointing out need to acknowledge there is a problem to address it https://t.co/yj4ZVxdQUu'),
#  ('beegardenmalaga',
#   '#SOSabejas #Glifosato #glyphosate #Neonicotinoides #Neonics https://t.co/g377odQ9sI'),
#  ('LuLaG_G',
#   'RT @JaviCepero: Publicado en Science, no son las opiniones de 4 "ecologistas antisistema". #neonicotinoides  #bees #abejas https://t.co/nvI…'),
#  ('urbanapicultura',
#   'RT @JaviCepero: Publicado en Science, no son las opiniones de 4 "ecologistas antisistema". #neonicotinoides  #bees #abejas https://t.co/nvI…'),
#  ('JaviCepero',
#   'Publicado en Science, no son las opiniones de 4 "ecologistas antisistema". #neonicotinoides  #bees #abejas https://t.co/nvI54xcEi2'),
#  ('Klompsoares',
#   'RT @MichelsJoost: Mijn bijen zijn bijna klaar voor de Nederlandse lente... En graag zonder #neonicotinoides, beste boeren. https://t.co/BzH…'),
#  ('starwarsapicult',
#   'RT @LFerreirim: "No me gusta que me llamen mentiroso" dice el autor del estudio sobre los #neonicotinoides https://t.co/vlEVCrWzT6 #SOSabej…'),
#  ('LFerreirim',
#   '"No me gusta que me llamen mentiroso" dice el autor del estudio sobre los #neonicotinoides https://t.co/vlEVCrWzT6 #SOSabejas #abejas'),
#  ('RemDumDum',
#   '@LoCapel Les #neonicotinoides ont apporté des solutions, et permis d interdire les carbanates et le lindane.'),
#  ('YanThoinet',
#   'RT @LFerreirim: #Neonicotinoides Emails muestran como Bayer y Syngenta querían conocer la info antes de su publicación https://t.co/njFpwsB…'),
#  ('LFerreirim',
#   '#Neonicotinoides Emails muestran como Bayer y Syngenta querían conocer la info antes de su publicación https://t.co/njFpwsBRWL #SOSabejas'),
#  ('DLC988',
#   'RT @xavierlouyDLF: Ça se vérifie déjà : Big Pharma et #Vaccins / Chimie et #Neonicotinoïdes / #Banques et taxe #Traders / Medef et #LoiTrav…'),
#  ('Carlangues',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('HeelLeClech',
#   'RT @xavierlouyDLF: Ça se vérifie déjà : Big Pharma et #Vaccins / Chimie et #Neonicotinoïdes / #Banques et taxe #Traders / Medef et #LoiTrav…'),
#  ('annalysa17',
#   'RT @PatrickLeHyaric: Nouvelle vidéo : Interview de @humanite_fr sur les #pesticides à base de #neonicotinoides et le #JEFTA \nhttps://t.co/b…'),
#  ('carolinacarava8',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('gemma_altarriba',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('GNOsonaICHN',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('Ines_Vivas',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('JanickCoroller',
#   "RT @PatrickLeHyaric: Les abeilles, c'est la vie !\nL'Interview intégrale de L'Humanité sur les #néonicotinoïdes et le #JEFTA ici : https://t…"),
#  ('ColauRos',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('ClinomicsLife',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('SHNB_BSHN',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('tbaupuig',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('LifeMedacc',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('pallarsibruce',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('CopeMallorca',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#  ('yupyop',
#   'RT @CREAF_ecologia: Les poblacions d’abelles estan disminuint, i #pesticides com els #neonicotinoides en són una causa directa #abelles htt…'),
#   'RT @voedselanders: Voor #bijen is 1 gram Imidacloprid net zo giftig als 7 kilo DDT ..... #neonicotinoides https://t.co/DKYfajuMVV'),
#  ('AseedEurope',
#   'RT @voedselanders: Voor #bijen is 1 gram Imidacloprid net zo giftig als 7 kilo DDT ..... #neonicotinoides https://t.co/DKYfajuMVV'),
#  ('voedselanders',
#   'Voor #bijen is 1 gram Imidacloprid net zo giftig als 7 kilo DDT ..... #neonicotinoides https://t.co/DKYfajuMVV'),
#  ('BelzMichel',
#   "RT @_acouvreur: ➡️Je suis Agri et Apiculteur\n➡️J'utilise #néonicotinoïdes sur blé betterave\n➡️Je protège mes 🐝contre #nosémose et #varroa\n✅…"),
#  ('ArtToine',
#   "RT @JLMelenchon: Il faut interdire pour de bon les pesticides néonicotinoïdes tueurs d'abeilles. \n#Pesticides #Néonicotinoïdes #Abeilles ht…"),
#  ('vandenbusschel',
#   "RT @_acouvreur: ➡️Je suis Agri et Apiculteur\n➡️J'utilise #néonicotinoïdes sur blé betterave\n➡️Je protège mes 🐝contre #nosémose et #varroa\n✅…"),
#  ('ColetteDesch80',
#   'RT @Polony_tv: Retrouvez la revue de presse de cette semaine par @NPolony ➤ https://t.co/fijynKtKlV #neonicotinoides #CongresVersailles #FM…'),
#  ...]

# %%
[('-'*10 + s["user"]["screen_name"]+'-'*10,s["entities"]["hashtags"]) for s in statuses 
    if not s["text"][:4]=='RT @']
# Out:
# [('----------LaFakeAgricole----------',
#   [{'indices': [17, 33], 'text': 'neonicotinoides'},
#    {'indices': [62, 74], 'text': 'insecticide'},
#    {'indices': [104, 114], 'text': 'herbicide'}]),
#  ('----------MPeala----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------Referenceappro----------',
#   [{'indices': [103, 119], 'text': 'neonicotinoides'},
#    {'indices': [121, 127], 'text': 'Phyto'}]),
#  ('----------mag_vegetable----------',
#   [{'indices': [64, 71], 'text': 'gilles'},
#    {'indices': [78, 94], 'text': 'neonicotinoides'},
#    {'indices': [95, 100], 'text': 'unaf'}]),
#  ('----------29aatea----------',
#   [{'indices': [0, 16], 'text': 'Neonicotinoides'},
#    {'indices': [17, 26], 'text': 'abeilles'},
#    {'indices': [27, 35], 'text': 'Ukraine'}]),
#  ('----------PietersEdwige----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------ApiEcologica----------',
#   [{'indices': [35, 42], 'text': 'abejas'},
#    {'indices': [43, 54], 'text': 'apicultura'},
#    {'indices': [55, 78], 'text': 'ColonyCollapseDisorder'},
#    {'indices': [79, 95], 'text': 'neonicotinoides'},
#    {'indices': [96, 107], 'text': 'acaricidas'},
#    {'indices': [108, 119], 'text': 'pesticidas'}]),
#  ('----------aurelienbadet----------',
#   [{'indices': [65, 81], 'text': 'néonicotinoïdes'},
#    {'indices': [108, 117], 'text': 'abeilles'},
#    {'indices': [118, 127], 'text': 'pétition'}]),
#  ('----------thi_loup----------',
#   [{'indices': [71, 87], 'text': 'neonicotinoides'}]),
#  ('----------nath_35----------',
#   [{'indices': [62, 78], 'text': 'néonicotinoïdes'}]),
#  ('----------RemDumDum----------',
#   [{'indices': [32, 48], 'text': 'neonicotinoides'}]),
#  ('----------thi_loup----------',
#   [{'indices': [62, 78], 'text': 'neonicotinoides'}]),
#  ('----------thi_loup----------',
#   [{'indices': [30, 46], 'text': 'neonicotinoides'}]),
#  ('----------thi_loup----------',
#   [{'indices': [97, 113], 'text': 'néonicotinoides'}]),
#  ('----------thi_loup----------',
#   [{'indices': [8, 24], 'text': 'neonicotinoides'}]),
#  ('----------thi_loup----------',
#   [{'indices': [39, 55], 'text': 'neonicotinoides'},
#    {'indices': [56, 67], 'text': 'pesticides'},
#    {'indices': [68, 79], 'text': 'glyphosate'},
#    {'indices': [80, 95], 'text': 'nanoparticules'}]),
#  ('----------M_Orphelin----------',
#   [{'indices': [0, 14], 'text': 'BonneNouvelle'},
#    {'indices': [37, 53], 'text': 'néonicotinoïdes'},
#    {'indices': [92, 101], 'text': 'céréales'}]),
#  ('----------Prudhomme2017----------',
#   [{'indices': [33, 49], 'text': 'neonicotinoïdes'},
#    {'indices': [103, 124], 'text': 'PrincipeDePrecaution'}]),
#  ('----------b_abba----------',
#   [{'indices': [45, 53], 'text': 'ComDDAT'},
#    {'indices': [83, 99], 'text': 'neonicotinoides'}]),
#  ('----------rodrigueaHDF----------',
#   [{'indices': [0, 14], 'text': 'En2740ilyaura'},
#    {'indices': [120, 136], 'text': 'neonicotinoides'}]),
#  ('----------M_Orphelin----------',
#   [{'indices': [41, 50], 'text': 'directAN'},
#    {'indices': [62, 73], 'text': 'pesticides'},
#    {'indices': [74, 90], 'text': 'néonicotinoïdes'}]),
#  ('----------FrancoisFree----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------29aatea----------',
#   [{'indices': [35, 51], 'text': 'néonicotinoïdes'}]),
#  ('----------madyguy1----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------mirjossbom----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------RidingMyWorld----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------pmeyssonnier----------',
#   [{'indices': [65, 81], 'text': 'néonicotinoïdes'},
#    {'indices': [108, 117], 'text': 'abeilles'},
#    {'indices': [118, 127], 'text': 'pétition'}]),
#  ('----------FFAP_Apipro----------',
#   [{'indices': [18, 28], 'text': 'pollution'},
#    {'indices': [46, 62], 'text': 'néonicotinoïdes'}]),
#  ('----------paddylille----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------DEROOSEJacques----------',
#   [{'indices': [17, 33], 'text': 'néonicotinoïdes'}]),
#  ('----------rafelvng----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------GillesMaillet----------',
#   [{'indices': [3, 14], 'text': 'Commission'},
#    {'indices': [15, 26], 'text': 'européenne'},
#    {'indices': [67, 83], 'text': 'néonicotinoïdes'},
#    {'indices': [110, 119], 'text': 'abeilles'},
#    {'indices': [120, 129], 'text': 'pétition'}]),
#  ('----------1toul----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------Enkorplus----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------jepensedonc3----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------marielenbenede----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------RosalieBaumert----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------marenascar----------',
#   [{'indices': [65, 81], 'text': 'néonicotinoïdes'},
#    {'indices': [108, 117], 'text': 'abeilles'},
#    {'indices': [118, 127], 'text': 'pétition'}]),
#  ('----------edujom----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------MargueriteJm----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------ecu92----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------marcillat8----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------jepensedonc3----------',
#   [{'indices': [65, 81], 'text': 'néonicotinoïdes'},
#    {'indices': [108, 117], 'text': 'abeilles'},
#    {'indices': [118, 127], 'text': 'pétition'}]),
#  ('----------CatMaymard----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'},
#    {'indices': [127, 133], 'text': 'green'}]),
#  ('----------CdricV----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------mrabeman----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------liogerard91----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------lharmonie3----------',
#   [{'indices': [65, 81], 'text': 'néonicotinoïdes'},
#    {'indices': [108, 117], 'text': 'abeilles'},
#    {'indices': [118, 127], 'text': 'pétition'}]),
#  ('----------filnoir----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------claudypersonne----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------Ifanelix----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------Necropaul----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------CubryJeanPierre----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------labbef----------',
#   [{'indices': [65, 81], 'text': 'néonicotinoïdes'},
#    {'indices': [108, 117], 'text': 'abeilles'},
#    {'indices': [118, 127], 'text': 'pétition'}]),
#  ('----------Capital_Scandal----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------louiebfree----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------PereMalo----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------drapeau_rouge----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------leoxymoron----------',
#   [{'indices': [65, 81], 'text': 'néonicotinoïdes'},
#    {'indices': [108, 117], 'text': 'abeilles'},
#    {'indices': [118, 127], 'text': 'pétition'}]),
#  ('----------NLlinsoumise----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------Linwelyn----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------PoussyIV----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------mhhoodoo----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------loic_delage----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------Amandine_GB----------',
#   [{'indices': [65, 81], 'text': 'néonicotinoïdes'},
#    {'indices': [108, 117], 'text': 'abeilles'},
#    {'indices': [118, 127], 'text': 'pétition'}]),
#  ('----------anyesway----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------CPNBRABANT----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------deci0----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------nonalausterite----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------ravelje----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------franca64120----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------IgorleChat----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------NChevesson----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------MichelSain----------',
#   [{'indices': [65, 81], 'text': 'néonicotinoïdes'},
#    {'indices': [108, 117], 'text': 'abeilles'},
#    {'indices': [118, 127], 'text': 'pétition'}]),
#  ('----------a_robin10----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------AliasLautre----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------__Anais1996----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------StephFulgence----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------alternat5----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------Stephen_Mark_----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------LEGASTELOIS----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------jc_lomba----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------IsadoraNizard----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------jepensedonc3----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------be_leclercq----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------clnjmp----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------Randysud----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------benjam_caron----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------CorreaVillalobo----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------thi_loup----------',
#   [{'indices': [36, 52], 'text': 'neonicotinoides'}]),
#  ('----------thi_loup----------',
#   [{'indices': [13, 29], 'text': 'neonicotinoides'}]),
#  ('----------ChrisCathrine----------',
#   [{'indices': [0, 16], 'text': 'neonicotinoides'}]),
#  ('----------beegardenmalaga----------',
#   [{'indices': [0, 10], 'text': 'SOSabejas'},
#    {'indices': [11, 21], 'text': 'Glifosato'},
#    {'indices': [22, 33], 'text': 'glyphosate'},
#    {'indices': [34, 50], 'text': 'Neonicotinoides'},
#    {'indices': [51, 59], 'text': 'Neonics'}]),
#  ('----------JaviCepero----------',
#   [{'indices': [75, 91], 'text': 'neonicotinoides'},
#    {'indices': [93, 98], 'text': 'bees'},
#    {'indices': [99, 106], 'text': 'abejas'}]),
#  ('----------LFerreirim----------',
#   [{'indices': [74, 90], 'text': 'neonicotinoides'},
#    {'indices': [115, 125], 'text': 'SOSabejas'},
#    {'indices': [126, 133], 'text': 'abejas'}]),
#  ('----------RemDumDum----------',
#   [{'indices': [13, 29], 'text': 'neonicotinoides'}]),
#  ('----------agronomesQc----------',
#   [{'indices': [0, 11], 'text': 'Pesticides'},
#    {'indices': [22, 38], 'text': 'néonicotinoïdes'},
#    {'indices': [39, 47], 'text': 'neonics'},
#    {'indices': [48, 62], 'text': 'pollinisateur'}]),
#  ('----------TheUniPlanet----------',
#   [{'indices': [12, 28], 'text': 'neonicotinóides'},
#    {'indices': [84, 92], 'text': 'abelhas'}]),
#  ('----------thi_loup----------',
#   [{'indices': [12, 28], 'text': 'néonicotinoïdes'}]),
#  ('----------brunocrussol----------',
#   [{'indices': [28, 41], 'text': 'gouvernement'},
#    {'indices': [68, 84], 'text': 'néonicotinoïdes'},
#    {'indices': [90, 102], 'text': 'apiculteurs'}]),
#  ('----------DYv62----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------777Ouroboros----------',
#   [{'indices': [18, 34], 'text': 'neonicotinoides'},
#    {'indices': [35, 40], 'text': 'PNPP'},
#    {'indices': [41, 52], 'text': 'Pesticides'},
#    {'indices': [53, 63], 'text': 'épandages'}]),
#  ('----------777Ouroboros----------',
#   [{'indices': [0, 16], 'text': 'neonicotinoides'},
#    {'indices': [20, 30], 'text': 'épandages'}]),
#  ('----------xavierlouyDLF----------',
#   [{'indices': [43, 52], 'text': 'Monsanto'},
#    {'indices': [53, 59], 'text': 'Bayer'},
#    {'indices': [60, 66], 'text': 'Lobby'},
#    {'indices': [67, 74], 'text': 'Chimie'},
#    {'indices': [77, 93], 'text': 'Néonicotinoïdes'}]),
#  ('----------CarballoCecilia----------',
#   [{'indices': [24, 40], 'text': 'neonicotinoides'}]),
#  ('----------SyngentaFrance----------',
#   [{'indices': [65, 81], 'text': 'Néonicotinoïdes'},
#    {'indices': [82, 91], 'text': 'critique'},
#    {'indices': [109, 117], 'text': 'Article'},
#    {'indices': [131, 140], 'text': 'Abeilles'}]),
#  ('----------Phhennebert----------',
#   [{'indices': [42, 58], 'text': 'Néonicotinoïdes'}]),
#  ('----------alexcarre49----------',
#   [{'indices': [0, 16], 'text': 'Neonicotinoides'},
#    {'indices': [46, 59], 'text': 'Journalistes'},
#    {'indices': [60, 74], 'text': 'Scientifiques'}]),
#  ('----------LFerreirim----------',
#   [{'indices': [0, 16], 'text': 'Neonicotinoides'},
#    {'indices': [127, 137], 'text': 'SOSabejas'}]),
#  ('----------CREAF_ecologia----------',
#   [{'indices': [45, 56], 'text': 'pesticides'},
#    {'indices': [65, 81], 'text': 'neonicotinoides'},
#    {'indices': [107, 115], 'text': 'abelles'}]),
#  ('----------DEROOSEJacques----------',
#   [{'indices': [0, 11], 'text': 'Pesticides'},
#    {'indices': [22, 38], 'text': 'neonicotinoides'}]),
#  ('----------Vetitude----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'},
#    {'indices': [22, 33], 'text': 'pesticides'},
#    {'indices': [44, 53], 'text': 'abeilles'}]),
#  ('----------jowbox----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------EricAndrieuEU----------',
#   [{'indices': [67, 83], 'text': 'néonicotinoides'}]),
#  ('----------idainature----------',
#   [{'indices': [5, 21], 'text': 'neonicotinoides'},
#    {'indices': [32, 39], 'text': 'abejas'}]),
#  ('----------nbl78----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'},
#    {'indices': [22, 33], 'text': 'pesticides'},
#    {'indices': [44, 53], 'text': 'abeilles'}]),
#  ('----------fbellier----------',
#   [{'indices': [0, 16], 'text': 'neonicotinoides'},
#    {'indices': [104, 109], 'text': 'fake'}]),
#  ('----------xavierlouyDLF----------',
#   [{'indices': [35, 43], 'text': 'Vaccins'},
#    {'indices': [56, 72], 'text': 'Neonicotinoïdes'},
#    {'indices': [75, 83], 'text': 'Banques'},
#    {'indices': [92, 100], 'text': 'Traders'}]),
#  ('----------PatrickLeHyaric----------',
#   [{'indices': [73, 89], 'text': 'néonicotinoïdes'},
#    {'indices': [96, 102], 'text': 'JEFTA'}]),
#  ('----------PatrickLeHyaric----------',
#   [{'indices': [51, 62], 'text': 'pesticides'},
#    {'indices': [73, 89], 'text': 'neonicotinoides'},
#    {'indices': [96, 102], 'text': 'JEFTA'}]),
#  ('----------edu_wildlife----------', []),
#  ('----------Apiculture84----------',
#   [{'indices': [55, 71], 'text': 'néonicotinoïdes'},
#    {'indices': [80, 89], 'text': 'abeilles'}]),
#  ('----------apivital----------',
#   [{'indices': [26, 42], 'text': 'néonicotinoïdes'},
#    {'indices': [109, 116], 'text': 'Varroa'}]),
#  ('----------vbaralle----------',
#   [{'indices': [0, 11], 'text': 'Pesticides'},
#    {'indices': [93, 109], 'text': 'Neonicotinoides'}]),
#  ('----------CarlosPovedaC----------',
#   [{'indices': [0, 8], 'text': 'Colapso'},
#    {'indices': [12, 19], 'text': 'abejas'},
#    {'indices': [34, 38], 'text': 'CCD'},
#    {'indices': [39, 50], 'text': 'Pesticidas'},
#    {'indices': [51, 67], 'text': 'Neonicotinoides'}]),
#  ('----------fartpit----------',
#   [{'indices': [116, 121], 'text': 'bees'},
#    {'indices': [122, 138], 'text': 'neonicotinoides'}]),
#  ('----------FredInterstice----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------pilzpizza----------',
#   [{'indices': [79, 95], 'text': 'neonicotinoides'}]),
#  ('----------biperbapore----------',
#   [{'indices': [0, 9], 'text': 'Enmarche'},
#    {'indices': [19, 35], 'text': 'EnMarcheArriere'},
#    {'indices': [52, 68], 'text': 'neonicotinoides'},
#    {'indices': [69, 95], 'text': 'perturbateursendocriniens'}]),
#  ('----------_miss_ives_----------',
#   [{'indices': [86, 97], 'text': 'Pesticides'},
#    {'indices': [98, 107], 'text': 'abeilles'},
#    {'indices': [108, 124], 'text': 'neonicotinoides'}]),
#  ('----------Ludovic_Loustau----------',
#   [{'indices': [61, 76], 'text': 'LaHuertaDeLudo'},
#    {'indices': [89, 100], 'text': 'écologique'}]),
#  ('----------PolepolePat----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'},
#    {'indices': [22, 33], 'text': 'pesticides'},
#    {'indices': [43, 52], 'text': 'abeilles'},
#    {'indices': [78, 89], 'text': 'recherches'}]),
#  ('----------tdp591----------',
#   [{'indices': [11, 27], 'text': 'néonicotinoïdes'}]),
#  ('----------Emmanimals----------',
#   [{'indices': [0, 5], 'text': 'UIPP'},
#    {'indices': [6, 17], 'text': 'Pesticides'},
#    {'indices': [18, 34], 'text': 'Néonicotinoïdes'},
#    {'indices': [35, 41], 'text': 'FNSEA'},
#    {'indices': [42, 52], 'text': 'pollution'},
#    {'indices': [53, 65], 'text': 'agriculture'},
#    {'indices': [66, 72], 'text': 'santé'},
#    {'indices': [73, 80], 'text': 'poison'},
#    {'indices': [81, 91], 'text': 'pollution'}]),
#  ('----------KnowYourLeaker----------',
#   [{'indices': [89, 105], 'text': 'néonicotinoïdes'},
#    {'indices': [106, 115], 'text': 'pesticid'}]),
#  ('----------YanThoinet----------',
#   [{'indices': [49, 65], 'text': 'néonicotinoïdes'},
#    {'indices': [74, 83], 'text': 'abeilles'},
#    {'indices': [108, 120], 'text': 'Agriculture'},
#    {'indices': [121, 135], 'text': 'Pollinisation'}]),
#  ('----------Valerie75020----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------jeuxopla----------',
#   [{'indices': [66, 82], 'text': 'neonicotinoides'},
#    {'indices': [83, 96], 'text': 'nicolashulot'},
#    {'indices': [97, 109], 'text': 'agriculture'}]),
#  ('----------alexcarre49----------',
#   [{'indices': [69, 85], 'text': 'Neonicotinoides'}]),
#  ('----------alexcarre49----------', []),
#  ('----------sebrioux----------',
#   [{'indices': [52, 68], 'text': 'néonicotinoïdes'},
#    {'indices': [78, 87], 'text': 'abeilles'},
#    {'indices': [112, 120], 'text': 'Science'},
#    {'indices': [121, 135], 'text': 'Environnement'}]),
#  ('----------DrFishmarketing----------',
#   [{'indices': [70, 86], 'text': 'neonicotinoides'}]),
#  ('----------nathd_150----------',
#   [{'indices': [28, 44], 'text': 'néonicotinoïdes'}]),
#  ('----------NliteNinc----------', [{'indices': [24, 29], 'text': 'bees'}]),
#  ('----------njyr----------',
#   [{'indices': [36, 52], 'text': 'neonicotinoides'}]),
#  ('----------ParkSlopeGossip----------',
#   [{'indices': [48, 64], 'text': 'neonicotinoides'}]),
#  ('----------mondoBioDiverso----------',
#   [{'indices': [5, 21], 'text': 'neonicotinoides'}]),
#  ('----------tgouault----------',
#   [{'indices': [40, 56], 'text': 'neonicotinoides'}]),
#  ('----------JensFunancials----------',
#   [{'indices': [112, 128], 'text': 'neonicotinoides'}]),
#  ('----------Maat_Vienna----------',
#   [{'indices': [0, 11], 'text': 'glyphosate'},
#    {'indices': [12, 28], 'text': 'neonicotinoides'},
#    {'indices': [63, 72], 'text': 'honeybee'}]),
#  ('----------CaramelParsley----------',
#   [{'indices': [0, 7], 'text': 'oyster'},
#    {'indices': [31, 47], 'text': 'neonicotinoides'},
#    {'indices': [59, 71], 'text': 'environment'},
#    {'indices': [96, 102], 'text': 'toxic'},
#    {'indices': [103, 116], 'text': 'imadacloprid'},
#    {'indices': [117, 124], 'text': 'oceans'},
#    {'indices': [125, 136], 'text': 'ecosystems'}]),
#  ('----------xavierlouyDLF----------',
#   [{'indices': [74, 89], 'text': 'néolibéralisme'}]),
#  ('----------LFerreirim----------',
#   [{'indices': [4, 20], 'text': 'neonicotinoides'},
#    {'indices': [72, 82], 'text': 'SOSabejas'}]),
#  ('----------GCerez----------',
#   [{'indices': [93, 109], 'text': 'néonicotinoïdes'}]),
#  ('----------FFAP_Apipro----------',
#   [{'indices': [0, 21], 'text': 'MakeFranceGreenAgain'},
#    {'indices': [55, 71], 'text': 'néonicotinoïdes'},
#    {'indices': [79, 90], 'text': 'pesticides'},
#    {'indices': [100, 109], 'text': 'abeilles'}]),
#  ('----------martapahissa----------',
#   [{'indices': [24, 45], 'text': 'agriculturaecologica'},
#    {'indices': [49, 57], 'text': 'abelles'},
#    {'indices': [73, 84], 'text': 'pesticides'},
#    {'indices': [89, 105], 'text': 'neonicotinoides'}]),
#  ('----------NickdeCusa----------',
#   [{'indices': [53, 69], 'text': 'neonicotinoïdes'},
#    {'indices': [79, 88], 'text': 'abeilles'}]),
#  ('----------citedeleconomie----------',
#   [{'indices': [0, 13], 'text': 'Biodiversité'},
#    {'indices': [34, 50], 'text': 'neonicotinoides'},
#    {'indices': [56, 64], 'text': 'dataviz'}]),
#  ('----------apivital----------',
#   [{'indices': [62, 78], 'text': 'néonicotinoïdes'}]),
#  ('----------RegBaschung----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------alematraz----------',
#   [{'indices': [0, 12], 'text': 'pollinators'},
#    {'indices': [13, 24], 'text': 'Pesticides'},
#    {'indices': [25, 41], 'text': 'neonicotinoides'}]),
#  ('----------zenflowerbeauty----------',
#   [{'indices': [17, 22], 'text': 'died'},
#    {'indices': [23, 28], 'text': 'lost'},
#    {'indices': [29, 35], 'text': 'queen'},
#    {'indices': [36, 44], 'text': 'science'},
#    {'indices': [45, 53], 'text': 'stopped'},
#    {'indices': [54, 63], 'text': 'cleaning'},
#    {'indices': [64, 70], 'text': 'hives'},
#    {'indices': [71, 74], 'text': 'no'},
#    {'indices': [75, 85], 'text': 'direction'},
#    {'indices': [86, 102], 'text': 'neonicotinoides'},
#    {'indices': [103, 108], 'text': 'poor'},
#    {'indices': [109, 114], 'text': 'bees'}]),
#  ('----------RichardBouigue----------',
#   [{'indices': [29, 45], 'text': 'neonicotinoides'},
#    {'indices': [67, 93], 'text': 'perturbateursendocriniens'}]),
#  ('----------xavierlouyDLF----------', [{'indices': [69, 72], 'text': 'UE'}]),
#  ('----------EDarier----------',
#   [{'indices': [20, 30], 'text': 'pesticide'},
#    {'indices': [31, 47], 'text': 'neonicotinoides'},
#    {'indices': [48, 56], 'text': 'abeille'}]),
#  ('----------ichtus765----------', []),
#  ('----------apivital----------',
#   [{'indices': [44, 60], 'text': 'néonicotinoïdes'}]),
#  ('----------Charmag_Dessin----------',
#   [{'indices': [0, 14], 'text': 'CodeDuTravail'},
#    {'indices': [15, 36], 'text': 'laRepubliqueEnMarche'},
#    {'indices': [37, 53], 'text': 'neonicotinoides'}]),
#  ('----------GirardiMedioAmb----------',
#   [{'indices': [28, 44], 'text': 'neonicotinoides'},
#    {'indices': [68, 75], 'text': 'abejas'},
#    {'indices': [97, 104], 'text': 'choclo'},
#    {'indices': [105, 115], 'text': 'sosabejas'}]),
#  ('----------GirardiMedioAmb----------',
#   [{'indices': [30, 37], 'text': 'Abejas'},
#    {'indices': [81, 97], 'text': 'neonicotinoides'}]),
#  ('----------Stellane----------',
#   [{'indices': [112, 128], 'text': 'Néonicotinoïdes'}]),
#  ('----------CREAF_ecologia----------',
#   [{'indices': [0, 8], 'text': 'abelles'},
#    {'indices': [9, 25], 'text': 'neonicotinoides'},
#    {'indices': [26, 37], 'text': 'pesticides'}]),
#  ('----------design_question----------',
#   [{'indices': [0, 16], 'text': 'neonicotinoides'}]),
#  ('----------Gomecello----------',
#   [{'indices': [4, 20], 'text': 'neonicotinoides'}]),
#  ('----------VRoziere----------',
#   [{'indices': [34, 50], 'text': 'néonicotinoïdes'},
#    {'indices': [61, 87], 'text': 'PerturbateursEndocriniens'}]),
#  ('----------behybe----------',
#   [{'indices': [0, 14], 'text': 'revuedepresse'},
#    {'indices': [15, 24], 'text': 'polonytv'},
#    {'indices': [25, 41], 'text': 'neonicotinoides'},
#    {'indices': [42, 59], 'text': 'CongresVersaille'},
#    {'indices': [60, 65], 'text': 'FMIC'},
#    {'indices': [66, 73], 'text': 'Nestlé'}]),
#  ('----------CarreJardiniers----------',
#   [{'indices': [16, 32], 'text': 'neonicotinoides'},
#    {'indices': [63, 68], 'text': 'blog'}]),
#  ('----------rajotteg----------',
#   [{'indices': [4, 15], 'text': 'pesticides'},
#    {'indices': [16, 32], 'text': 'néonicotinoïdes'},
#    {'indices': [66, 75], 'text': 'abeilles'},
#    {'indices': [100, 106], 'text': 'santé'},
#    {'indices': [107, 120], 'text': 'biodiversité'},
#    {'indices': [121, 129], 'text': 'néonics'}]),
#  ('----------KateMobij----------',
#   [{'indices': [76, 92], 'text': 'neonicotinoides'}]),
#  ('----------EricAndrieuEU----------',
#   [{'indices': [10, 26], 'text': 'neonicotinoides'}]),
#  ('----------GanceVerite----------',
#   [{'indices': [0, 6], 'text': 'Bayer'},
#    {'indices': [63, 74], 'text': 'pesticides'},
#    {'indices': [85, 94], 'text': 'abeilles'},
#    {'indices': [124, 140], 'text': 'néonicotinoïdes'}]),
#  ('----------apivital----------',
#   [{'indices': [39, 46], 'text': 'Varroa'},
#    {'indices': [100, 116], 'text': 'néonicotinoïdes'}]),
#  ('----------science_actus----------',
#   [{'indices': [6, 11], 'text': 'Actu'},
#    {'indices': [12, 20], 'text': 'Science'},
#    {'indices': [21, 28], 'text': 'Oiseau'},
#    {'indices': [39, 48], 'text': 'Abeilles'},
#    {'indices': [52, 68], 'text': 'néonicotinoïdes'},
#    {'indices': [69, 73], 'text': 'Olm'},
#    {'indices': [77, 84], 'text': 'protée'},
#    {'indices': [85, 100], 'text': 'Débrisspatiaux'}]),
#  ('----------citedessciences----------',
#   [{'indices': [8, 13], 'text': 'Actu'},
#    {'indices': [14, 22], 'text': 'Science'},
#    {'indices': [27, 34], 'text': 'Oiseau'},
#    {'indices': [49, 58], 'text': 'Abeilles'},
#    {'indices': [62, 78], 'text': 'néonicotinoïdes'},
#    {'indices': [82, 86], 'text': 'Olm'},
#    {'indices': [90, 97], 'text': 'protée'}]),
#  ('----------JPSentucq----------',
#   [{'indices': [11, 20], 'text': 'abeilles'},
#    {'indices': [27, 38], 'text': 'pesticides'},
#    {'indices': [39, 55], 'text': 'néonicotinoïdes'}]),
#  ('----------f_fusterfabra----------',
#   [{'indices': [31, 47], 'text': 'neonicotinoides'},
#    {'indices': [68, 75], 'text': 'abejas'},
#    {'indices': [115, 132], 'text': 'interesescreados'}]),
#  ('----------QuebecScience----------',
#   [{'indices': [4, 20], 'text': 'néonicotinoides'},
#    {'indices': [76, 85], 'text': 'abeilles'}]),
#  ('----------beret_vert----------',
#   [{'indices': [93, 109], 'text': 'neonicotinoides'}]),
#  ('----------redapicolachile----------',
#   [{'indices': [34, 50], 'text': 'Neonicotinoides'}]),
#  ('----------pace38000----------', []),
#  ('----------palaisdecouvert----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'},
#    {'indices': [24, 31], 'text': 'danger'},
#    {'indices': [41, 50], 'text': 'abeilles'},
#    {'indices': [52, 65], 'text': 'biodiversité'}]),
#  ('----------citedessciences----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'},
#    {'indices': [24, 31], 'text': 'danger'},
#    {'indices': [41, 50], 'text': 'abeilles'},
#    {'indices': [52, 65], 'text': 'biodiversité'}]),
#  ('----------berblanc2----------',
#   [{'indices': [22, 34], 'text': 'Agriculture'},
#    {'indices': [76, 92], 'text': 'néonicotinoïdes'},
#    {'indices': [127, 136], 'text': 'abeilles'}]),
#  ('----------ScienceActu----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'},
#    {'indices': [24, 31], 'text': 'danger'},
#    {'indices': [41, 50], 'text': 'abeilles'},
#    {'indices': [52, 65], 'text': 'biodiversité'}]),
#  ('----------blackgull----------',
#   [{'indices': [40, 56], 'text': 'neonicotinoides'}]),
#  ('----------Madison_vert----------',
#   [{'indices': [28, 44], 'text': 'néonicotinoïdes'},
#    {'indices': [57, 66], 'text': 'abeilles'},
#    {'indices': [91, 104], 'text': 'biodiversité'}]),
#  ('----------leveil2017----------',
#   [{'indices': [0, 6], 'text': 'Bayer'},
#    {'indices': [63, 74], 'text': 'pesticides'},
#    {'indices': [85, 94], 'text': 'abeilles'}]),
#  ('----------AgenceSymbiotik----------',
#   [{'indices': [35, 51], 'text': 'néonicotinoïdes'},
#    {'indices': [71, 80], 'text': 'abeilles'}]),
#  ('----------thi_loup----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'}]),
#  ('----------ErwanWeymeersch----------',
#   [{'indices': [89, 101], 'text': 'agriculture'},
#    {'indices': [102, 113], 'text': 'pesticides'},
#    {'indices': [114, 130], 'text': 'néonicotinoïdes'}]),
#  ('----------29aatea----------',
#   [{'indices': [100, 116], 'text': 'Néonicotinoïdes'}]),
#  ('----------Fred_is_raide----------',
#   [{'indices': [80, 96], 'text': 'neonicotinoides'},
#    {'indices': [97, 106], 'text': 'abeilles'}]),
#  ('----------consoglobe----------',
#   [{'indices': [0, 11], 'text': 'Pesticides'},
#    {'indices': [53, 69], 'text': 'neonicotinoides'}]),
#  ('----------AugustinDeback----------',
#   [{'indices': [39, 55], 'text': 'néonicotinoïdes'}]),
#  ('----------VolontePaysanne----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'}]),
#  ('----------fukushima_actu----------',
#   [{'indices': [0, 7], 'text': 'NoNuke'},
#    {'indices': [8, 23], 'text': 'AntinNucléaire'},
#    {'indices': [117, 133], 'text': 'néonicotinoïdes'}]),
#  ('----------nixhorizon----------',
#   [{'indices': [20, 36], 'text': 'neonicotinoides'},
#    {'indices': [56, 61], 'text': 'bees'}]),
#  ('----------Labour4Animals----------',
#   [{'indices': [0, 12], 'text': 'Countryfile'},
#    {'indices': [51, 67], 'text': 'neonicotinoides'}]),
#  ('----------shillorganics----------',
#   [{'indices': [61, 77], 'text': 'neonicotinoides'},
#    {'indices': [120, 134], 'text': 'ChooseOrganic'}]),
#  ('----------M_Z_Harrison----------',
#   [{'indices': [36, 52], 'text': 'neonicotinoides'}]),
#  ('----------science_actus----------',
#   [{'indices': [6, 11], 'text': 'Actu'},
#    {'indices': [12, 20], 'text': 'Science'},
#    {'indices': [21, 28], 'text': 'Oiseau'},
#    {'indices': [39, 48], 'text': 'Abeilles'},
#    {'indices': [52, 68], 'text': 'néonicotinoïdes'},
#    {'indices': [69, 73], 'text': 'Olm'},
#    {'indices': [77, 84], 'text': 'protée'},
#    {'indices': [85, 100], 'text': 'Débrisspatiaux'}]),
#  ('----------UniverscienceTV----------',
#   [{'indices': [8, 13], 'text': 'Actu'},
#    {'indices': [14, 22], 'text': 'Science'},
#    {'indices': [27, 34], 'text': 'Oiseau'},
#    {'indices': [49, 58], 'text': 'Abeilles'},
#    {'indices': [62, 78], 'text': 'néonicotinoïdes'},
#    {'indices': [82, 86], 'text': 'Olm'},
#    {'indices': [90, 97], 'text': 'protée'}]),
#  ('----------x_CousinHub----------',
#   [{'indices': [3, 11], 'text': 'cravate'},
#    {'indices': [43, 49], 'text': 'intox'},
#    {'indices': [96, 104], 'text': 'Travert'},
#    {'indices': [105, 121], 'text': 'neonicotinoides'},
#    {'indices': [122, 140], 'text': 'CeuxQuiNeSontRien'}]),
#  ('----------olivierestiez----------',
#   [{'indices': [26, 32], 'text': 'Bayer'},
#    {'indices': [36, 45], 'text': 'Syngenta'},
#    {'indices': [70, 86], 'text': 'néonicotinoïdes'},
#    {'indices': [96, 105], 'text': 'abeilles'}]),
#  ('----------MadameVarda----------',
#   [{'indices': [12, 27], 'text': 'fondationHulot'},
#    {'indices': [55, 71], 'text': 'néonicotinoïdes'},
#    {'indices': [127, 140], 'text': 'ecoFeministe'}]),
#  ('----------jmleluc----------',
#   [{'indices': [30, 46], 'text': 'neonicotinoides'}]),
#  ('----------LuneauAurelie----------',
#   [{'indices': [0, 16], 'text': 'Neonicotinoides'},
#    {'indices': [26, 32], 'text': 'Hulot'},
#    {'indices': [77, 87], 'text': 'DCAeffets'}]),
#  ('----------RadioTeleSuisse----------',
#   [{'indices': [4, 20], 'text': 'néonicotinoïdes'},
#    {'indices': [83, 96], 'text': 'biodiversité'},
#    {'indices': [105, 114], 'text': '19h30RTS'}]),
#  ('----------alematraz----------',
#   [{'indices': [0, 12], 'text': 'pollinators'},
#    {'indices': [13, 18], 'text': 'bees'},
#    {'indices': [19, 35], 'text': 'neonicotinoides'},
#    {'indices': [36, 50], 'text': 'polinizadores'},
#    {'indices': [51, 58], 'text': 'abejas'},
#    {'indices': [59, 78], 'text': 'riesgosambientales'}]),
#  ('----------m_cambon----------',
#   [{'indices': [35, 41], 'text': 'Hulot'},
#    {'indices': [42, 50], 'text': 'Travert'},
#    {'indices': [51, 67], 'text': 'neonicotinoides'}]),
#  ('----------m_cambon----------',
#   [{'indices': [39, 55], 'text': 'neonicotinoides'},
#    {'indices': [56, 63], 'text': 'picnic'}]),
#  ('----------ptitoursblanc----------',
#   [{'indices': [78, 88], 'text': 'pesticide'},
#    {'indices': [89, 105], 'text': 'neonicotinoides'}]),
#  ('----------v_virtu----------',
#   [{'indices': [44, 51], 'text': 'Dégâts'},
#    {'indices': [56, 72], 'text': 'Néonicotinoïdes'},
#    {'indices': [81, 90], 'text': 'Abeilles'}]),
#  ('----------thi_loup----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'}]),
#  ('----------apivital----------',
#   [{'indices': [42, 58], 'text': 'néonicotinoïdes'},
#    {'indices': [96, 103], 'text': 'Varroa'}]),
#  ('----------apiberica----------',
#   [{'indices': [16, 32], 'text': 'neonicotinoides'},
#    {'indices': [53, 60], 'text': 'abejas'}]),
#  ('----------apivital----------',
#   [{'indices': [75, 91], 'text': 'néonicotinoïdes'},
#    {'indices': [121, 128], 'text': 'Varroa'}]),
#  ('----------apivital----------',
#   [{'indices': [27, 43], 'text': 'néonicotinoides'}]),
#  ('----------jojobles----------',
#   [{'indices': [49, 58], 'text': 'abeilles'},
#    {'indices': [93, 102], 'text': 'pétition'},
#    {'indices': [103, 119], 'text': 'néonicotinoïdes'}]),
#  ('----------ptitoursblanc----------',
#   [{'indices': [61, 68], 'text': 'nature'},
#    {'indices': [69, 85], 'text': 'neonicotinoides'},
#    {'indices': [86, 95], 'text': 'abeilles'}]),
#  ('----------voedselanders----------',
#   [{'indices': [5, 11], 'text': 'bijen'},
#    {'indices': [70, 86], 'text': 'neonicotinoides'}]),
#  ('----------thierrybeaucamp----------',
#   [{'indices': [0, 5], 'text': 'Bees'},
#    {'indices': [6, 15], 'text': 'Abeilles'},
#    {'indices': [16, 32], 'text': 'Néonicotinoïdes'}]),
#  ('----------RemDumDum----------',
#   [{'indices': [43, 59], 'text': 'neonicotinoides'}]),
#  ('----------RemDumDum----------',
#   [{'indices': [15, 31], 'text': 'neonicotinoides'},
#    {'indices': [50, 59], 'text': 'abeilles'}]),
#  ('----------RemDumDum----------',
#   [{'indices': [71, 87], 'text': 'neonicotinoides'}]),
#  ('----------laurapopedenman----------',
#   [{'indices': [28, 35], 'text': 'insect'},
#    {'indices': [43, 53], 'text': 'songbirds'},
#    {'indices': [54, 63], 'text': 'swallows'},
#    {'indices': [86, 102], 'text': 'neonicotinoides'}]),
#  ('----------jmleluc----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'}]),
#  ('----------FlavienMoreau----------',
#   [{'indices': [118, 134], 'text': 'neonicotinoides'}]),
#  ('----------palaisdecouvert----------',
#   [{'indices': [8, 13], 'text': 'Actu'},
#    {'indices': [14, 22], 'text': 'Science'},
#    {'indices': [27, 34], 'text': 'Oiseau'},
#    {'indices': [49, 58], 'text': 'Abeilles'},
#    {'indices': [62, 78], 'text': 'néonicotinoïdes'},
#    {'indices': [82, 86], 'text': 'Olm'},
#    {'indices': [90, 97], 'text': 'protée'}]),
#  ('----------Sophiecuisine----------',
#   [{'indices': [114, 120], 'text': 'glace'},
#    {'indices': [121, 137], 'text': 'néonicotinoïdes'}]),
#  ('----------marcottlyse----------',
#   [{'indices': [15, 25], 'text': 'pesticide'},
#    {'indices': [59, 75], 'text': 'néonicotinoïdes'}]),
#  ('----------io_r_us----------', []),
#  ('----------ginachron----------',
#   [{'indices': [30, 34], 'text': 'bee'},
#    {'indices': [45, 61], 'text': 'neonicotinoides'}]),
#  ('----------dingerjoe----------',
#   [{'indices': [0, 9], 'text': 'Abeilles'},
#    {'indices': [56, 72], 'text': 'néonicotinoïdes'}]),
#  ('----------VictorBledor----------',
#   [{'indices': [0, 16], 'text': 'Néonicotinoïdes'},
#    {'indices': [66, 74], 'text': 'fdsea28'}]),
#  ('----------Vetitude----------',
#   [{'indices': [55, 71], 'text': 'néonicotinoïdes'},
#    {'indices': [80, 89], 'text': 'abeilles'}]),
#  ('----------Polony_tv----------',
#   [{'indices': [85, 101], 'text': 'neonicotinoides'}]),
#  ('----------2Maria6925----------',
#   [{'indices': [58, 67], 'text': 'abeilles'},
#    {'indices': [68, 84], 'text': 'neonicotinoides'},
#    {'indices': [85, 99], 'text': 'environnement'},
#    {'indices': [100, 109], 'text': 'ecologie'}]),
#  ('----------balxHa----------',
#   [{'indices': [95, 111], 'text': 'neonicotinoides'}]),
#  ('----------QuestoyQueLotro----------',
#   [{'indices': [70, 86], 'text': 'neonicotinoides'},
#    {'indices': [87, 99], 'text': 'NuevoLaredo'},
#    {'indices': [100, 109], 'text': 'Ecologia'},
#    {'indices': [110, 121], 'text': 'Apicultura'},
#    {'indices': [122, 130], 'text': 'Yucatán'},
#    {'indices': [131, 138], 'text': 'Colima'}]),
#  ('----------balxHa----------',
#   [{'indices': [39, 55], 'text': 'neonicotinoides'}]),
#  ('----------upr59----------',
#   [{'indices': [46, 62], 'text': 'néonicotinoïdes'}])]

# %% [markdown]
# ## Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @NPolony: Nous le disions: il y a l'affichage et il y a les enjeux concrets face aux lobbys #neonicotinoides  https://t.co/z1IMWfOGCK vi\u2026",
#  "RT @Polony_tv: \"Les plus lucides se diront que #Macron avait promis de ne pas revenir sur cette interdiction des #neonicotinoides\" \u27a4https:/\u2026",
#  "RT @Polony_tv: Retrouvez la revue de presse de cette semaine par @NPolony \u27a4 https://t.co/fijynKtKlV #neonicotinoides #CongresVersailles #FM\u2026",
#  "RT @LaFakeAgricole: Alternatives aux #neonicotinoides :l'Anses autorise Froome,un #insecticide 100 % naturel,qui fait aussi #herbicide et a\u2026",
#  "Alternatives aux #neonicotinoides :l'Anses autorise Froome,un #insecticide 100 % naturel,qui fait aussi #herbicide\u2026 https://t.co/P0dCNrScMg"
# ]
# [
#  "NPolony",
#  "Polony_tv",
#  "Polony_tv",
#  "NPolony",
#  "LaFakeAgricole"
# ]
# [
#  "neonicotinoides",
#  "Macron",
#  "neonicotinoides",
#  "neonicotinoides",
#  "CongresVersailles"
# ]
# [
#  "RT",
#  "@NPolony:",
#  "Nous",
#  "le",
#  "disions:"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:20]) # top 10
    print()
# Out:
# [('RT', 978), ('les', 724), ('de', 548), ('et', 491), ('#néonicotinoïdes', 484), ('#neonicotinoides', 429), ('sur', 416), ('la', 346), ('➡️Je', 332), ('des', 328), ('en', 253), ('#abeilles', 182), ('!', 178), ('Les', 174), ('@_acouvreur:', 167), ('protège', 167), ('suis', 166), ('Agri', 166), ('Apiculteur', 166), ("➡️J'utilise", 166)]
#
# [('_acouvreur', 167), ('Polony_tv', 82), ('RemDumDum', 79), ('NPolony', 68), ('EricAndrieuEU', 47), ('lemondefr', 41), ('EU_Commission', 38), ('brunocrussol', 27), ('StTRAVERT', 27), ('JLMelenchon', 26), ('Anses_fr', 24), ('CREAF_ecologia', 21), ('PatrickLeHyaric', 19), ('CEHScienceNews', 19), ('thi_loup', 18), ('jeanpaulvinot', 18), ('M_Orphelin', 16), ('N_Hulot', 16), ('alexcarre49', 15), ('anyesway', 15)]
#
# [('néonicotinoïdes', 533), ('neonicotinoides', 505), ('abeilles', 270), ('nosémose', 166), ('varroa', 166), ('pétition', 116), ('Néonicotinoïdes', 81), ('Pesticides', 64), ('CongresVersailles', 62), ('pesticides', 61), ('Neonicotinoides', 59), ('Abeilles', 40), ('apiculteurs', 28), ('gouvernement', 26), ('abejas', 25), ('Hulot', 23), ('Macron', 22), ('abelles', 22), ('JEFTA', 20), ('sociétécivile', 18)]

# %% [markdown]
# ## Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:20])
# Out:
#         Word         | Count
# ****************************************
# RT                   |    978
# les                  |    724
# de                   |    548
# et                   |    491
# #néonicotinoïdes     |    484
# #neonicotinoides     |    429
# sur                  |    416
# la                   |    346
# ➡️Je                 |    332
# des                  |    328
# en                   |    253
# #abeilles            |    182
# !                    |    178
# Les                  |    174
# @_acouvreur:         |    167
# protège              |    167
# suis                 |    166
# Agri                 |    166
# Apiculteur           |    166
# ➡️J'utilise          |    166
#
#     Screen Name      | Count
# ****************************************
# _acouvreur           |    167
# Polony_tv            |     82
# RemDumDum            |     79
# NPolony              |     68
# EricAndrieuEU        |     47
# lemondefr            |     41
# EU_Commission        |     38
# brunocrussol         |     27
# StTRAVERT            |     27
# JLMelenchon          |     26
# Anses_fr             |     24
# CREAF_ecologia       |     21
# PatrickLeHyaric      |     19
# CEHScienceNews       |     19
# thi_loup             |     18
# jeanpaulvinot        |     18
# M_Orphelin           |     16
# N_Hulot              |     16
# alexcarre49          |     15
# anyesway             |     15
#
#       Hashtag        | Count
# ****************************************
# néonicotinoïdes      |    533
# neonicotinoides      |    505
# abeilles             |    270
# nosémose             |    166
# varroa               |    166
# pétition             |    116
# Néonicotinoïdes      |     81
# Pesticides           |     64
# CongresVersailles    |     62
# pesticides           |     61
# Neonicotinoides      |     59
# Abeilles             |     40
# apiculteurs          |     28
# gouvernement         |     26
# abejas               |     25
# Hulot                |     23
# Macron               |     22
# abelles              |     22
# JEFTA                |     20
# sociétécivile        |     18

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['retweeted_status']['id'],
             status['retweeted_status']['created_at'][:10]+' '+status['retweeted_status']['created_at'][-4:],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %%
statuses[0]#['text']
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jul 28 17:05:11 +0000 2017',
#  'entities': {'hashtags': [{'indices': [95, 111], 'text': 'neonicotinoides'}],
#   'symbols': [],
#   'urls': [{'display_url': 'polony.tv/focus/les-chan…',
#     'expanded_url': 'https://polony.tv/focus/les-chantiers-de-monsieur-hulot',
#     'indices': [113, 136],
#     'url': 'https://t.co/z1IMWfOGCK'}],
#   'user_mentions': [{'id': 837123698,
#     'id_str': '837123698',
#     'indices': [3, 11],
#     'name': 'Natacha Polony',
#     'screen_name': 'NPolony'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 890981471875420161,
#  'id_str': '890981471875420161',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'fr',
#  'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 187,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Mon Jun 26 10:02:02 +0000 2017',
#   'entities': {'hashtags': [{'indices': [82, 98], 'text': 'neonicotinoides'}],
#    'symbols': [],
#    'urls': [{'display_url': 'polony.tv/focus/les-chan…',
#      'expanded_url': 'https://polony.tv/focus/les-chantiers-de-monsieur-hulot',
#      'indices': [100, 123],
#      'url': 'https://t.co/z1IMWfOGCK'}],
#    'user_mentions': [{'id': 818864954141003780,
#      'id_str': '818864954141003780',
#      'indices': [128, 138],
#      'name': 'Polony Tv',
#      'screen_name': 'Polony_tv'}]},
#   'favorite_count': 216,
#   'favorited': False,
#   'geo': None,
#   'id': 879278571524673536,
#   'id_str': '879278571524673536',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'fr',
#   'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 187,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': "Nous le disions: il y a l'affichage et il y a les enjeux concrets face aux lobbys #neonicotinoides  https://t.co/z1IMWfOGCK via @Polony_tv",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Sep 21 06:10:15 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Journaliste, essayiste. @Polony_tv, @LCI, Les Terriens du dimanche.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 8,
#    'follow_request_sent': False,
#    'followers_count': 105632,
#    'following': False,
#    'friends_count': 302,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 837123698,
#    'id_str': '837123698',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'fr',
#    'listed_count': 808,
#    'location': '',
#    'name': 'Natacha Polony',
#    'notifications': False,
#    'profile_background_color': 'FAFAFA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/837123698/1498825610',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/880483638663663617/WiD3SL9m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/880483638663663617/WiD3SL9m_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'NPolony',
#    'statuses_count': 2074,
#    'time_zone': 'Athens',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 10800,
#    'verified': True}},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': "RT @NPolony: Nous le disions: il y a l'affichage et il y a les enjeux concrets face aux lobbys #neonicotinoides  https://t.co/z1IMWfOGCK vi…",
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Oct 30 18:45:12 +0000 2012',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'RCN',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 232,
#   'follow_request_sent': False,
#   'followers_count': 120,
#   'following': False,
#   'friends_count': 369,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 915241236,
#   'id_str': '915241236',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'fr',
#   'listed_count': 0,
#   'location': '',
#   'name': 'Pascal',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/915241236/1500569669',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/888079670905884672/DMydwbif_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/888079670905884672/DMydwbif_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'pascal_pm',
#   'statuses_count': 375,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %%
all_retweets = []
filtered_retweets = []
for t in retweets:
    if not t[2] in all_retweets:
        all_retweets.append(t[2])
        filtered_retweets.append((t[0],t[1],t[3],t[4]))

retweets = filtered_retweets

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, date, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", date, text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))
        else : print(row_template.format("", date, "")) 
        print('')

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[20:50])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#   66    | Sciences_Avenir | RT @Sciences_Avenir: Insecticides "tueurs d'abeill
#         | Mon Jun 26 2017 | es" : le gouvernement maintient l'interdiction des
#         |                 |  #néonicotinoïdes  https://t.co/sdsgDHd…
#
#   63    |   AFParchives   | RT @AFParchives: Une apicultrice en 1937 #Neonicot
#         | Mon Jun 26 2017 | inoides #AFP https://t.co/oFpCW3KmeL
#
#   36    |  EricAndrieuEU  | RT @EricAndrieuEU: #Néonicotinoïdes tueurs d'abeil
#         | Mon Jun 26 2017 | les: La position du gvt @EmmanuelMacron va ds le s
#         |                 | ens inverse de celle du Parlement europ…
#
#   32    | EstherBenbassa  | RT @EstherBenbassa: Deux études à grande échelle c
#         | Thu Jun 29 2017 | onfirment le rôle des #néonicotinoïdes dans la mor
#         |                 | talité accrue des #abeilles. https://t.…
#
#   31    |      AEGRW      | RT @AEGRW: "Comment va-t-on produire et exporter d
#         | Tue Jun 27 2017 | u #sucre sans #neonicotinoides ? Je vous pose la q
#         |                 | uestion !" @BFMTV @Olivier_Truchot #Hul…
#
#   30    |     Dalipas     | RT @Dalipas: Et si l'histoire des #Néonicotinoïdes
#         | Mon Jun 26 2017 |  était juste 1 coup monté pour détourner attention
#         |                 |  ou atténuer effet d'autres décisions?…
#
#   29    |    GP_Paris     | RT @GP_Paris: Rappel sur les #néonicotinoïdes ou #
#         | Mon Jun 26 2017 | neonics dits insecticides tueurs d'abeilles : http
#         |                 | s://t.co/3GpkajVclx via @libe #SaveTheB…
#
#   29    |     FPhyto      | RT @FPhyto: #Néonicotinoïdes: Les agriculteurs doi
#         | Tue Jun 27 2017 | vent s'expliquer, sans «affrontement», mais avec p
#         |                 | édagogie et fermeté https://t.co/605i5B…
#
#   28    |    jefstrouf    | RT @jefstrouf: #néonicotinoïdes Ce qui menace les
#         | Mon Jun 26 2017 | #abeilles menace l’Homme:  pas de retour en arrièr
#         |                 | e, le principe de précaution doit s’app…
#
#   28    |   WWF_Suisse    | RT @WWF_Suisse: Après les USA, Ségolène Royal au s
#         | Thu May 21 2015 | ecours des #abeilles: http://t.co/iOW4NojC4D #inse
#         |                 | cticides #néonicotinoïdes
#
#   25    |  brunocrussol   | RT @brunocrussol: Devant les atermoiements du #gou
#         | Sat Jul 15 2017 | vernement sur les interdictions des #néonicotinoïd
#         |                 | es, les #apiculteurs s'inquiètent🐝https…
#
#   25    |   Veillerette   | RT @Veillerette: #neonicotinoïdes 2 #études confir
#         | Fri Jun 30 2017 | ment leur impact délétère sur les #abeilles @genef
#         |                 | utures @N_Hulot  @EPhilippePM  https://…
#
#   24    |   M_Orphelin    | RT @M_Orphelin: De + en + de preuves : les #pestic
#         | Fri Jun 30 2017 | ides #néonicotinoïdes sont dangereux pour les #abe
#         |                 | illes ! En sortir, et vite ! https://t.…
#
#   22    |    HalteLa_     | RT @HalteLa_: #Neonicotinoides #pesticides \Nicola
#         | Mon Jun 26 2017 | s Hulot contre Twitter ce matin https://t.co/PGBEX
#         |                 | szVMh
#
#   21    | patrick_le_fur  | RT @patrick_le_fur: Les insecticides #néonicotinoï
#         | Mon Jun 26 2017 | des tueurs d’abeilles en passe d'être à nouveau au
#         |                 | torisés par le gouvernement ! @JJBourdi…
#
#   21    | UNAFapiculture  | RT @UNAFapiculture: Deux études à grande échelle c
#         | Thu Jun 29 2017 | onfirment les dégâts des #néonicotinoïdes sur les
#         |                 | abeilles #StopNeonics #BeeCoherent  htt…
