# %% [markdown]
# # Final project
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %%
import pickle
#import os
#from collections import Counter
#import json
#import datetime as dt
import twitter
import sqlite3

# %%
Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %%
#!pip install twitter

# %% [markdown]
# ## Authorizing an application to access Twitter account data

# %%
auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth, retry=True)

# %% [markdown]
# ## Collecting results

# %%
conn = sqlite3.connect('tweets.db')
c = conn.cursor()

# %%
# Create base
#------------------------------------------------------------
# Table: statuses
#------------------------------------------------------------
c.execute('''CREATE TABLE statuses(
        id                    Int NOT NULL ,
        coordinates           Varchar (250) ,
        created_at            Varchar (250) ,
        favorite_count        Int ,
        lang                  Varchar (25) ,
        place                 Varchar (2500) ,
        scopes                Varchar (2500) ,
        retweet_count         Int ,
        source                Varchar (2500) ,
        txt                   Varchar (250) ,
        withheld_in_countries Varchar (250) ,
        retweeted_status_id   Int ,
        in_reply_to_status_id Int ,
        in_reply_to_user_id   Int,
        quoted_status_id      Int ,
        user_id               Int ,
        PRIMARY KEY (id )
        );''')

#------------------------------------------------------------
# Table: users
#------------------------------------------------------------
c.execute('''CREATE TABLE users(
        id                    Int NOT NULL ,
        screen_name           Varchar (250) ,
        created_at            Varchar (100) ,
        description           Varchar (2500) ,
        favourites_count      Int ,
        followers_count       Int ,
        friends_count         Int ,
        lang                  Varchar (25) ,
        listed_count          Int ,
        location              Varchar (250) ,
        name                  Varchar (25) ,
        statuses_count        Int ,
        PRIMARY KEY (id )
        );''')

#------------------------------------------------------------
# Table: hashtags
#------------------------------------------------------------

#c.execute('''CREATE TABLE hashtags(
#        htg Varchar (140) NOT NULL ,
#        PRIMARY KEY (htg )
#        );''')


#------------------------------------------------------------
# Table: mentions
#------------------------------------------------------------

c.execute('''CREATE TABLE mentions(
        status_id Int NOT NULL ,
        user_id Int NOT NULL ,
        PRIMARY KEY (status_id ,user_id )
);''')


#------------------------------------------------------------
# Table: tags
#------------------------------------------------------------

c.execute('''CREATE TABLE tags(
        status_id Int NOT NULL ,
        htg    Varchar (140) NOT NULL ,
        PRIMARY KEY (status_id ,htg )
);''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-6-82b9b051fec4> in <module>()
#      21         user_id               Int ,
#      22         PRIMARY KEY (id )
# ---> 23         );''')
#      24
#      25 #------------------------------------------------------------
#
# OperationalError: table statuses already exists

# %%
def add_user(u,c):
    #Create the user entity and main attributes
    c.execute('''INSERT INTO users(id,screen_name,created_at,description,favourites_count,
            followers_count,friends_count,lang,listed_count,
            location,name,statuses_count)
    VALUES (?,?,?,?,?,?,?,?,?,?,?,?) ''', 
          (str(u['id']),u['screen_name'],u['created_at'],u['description'],str(u['favourites_count']),
            str(u['followers_count']),str(u['friends_count']),u['lang'],str(u['listed_count']),
              u['location'],u['name'],str(u['statuses_count'])))

# %%
def add_status(s,c):
    #Create the status entity and main attributes
    c.execute('''
    INSERT INTO 
        statuses(id,created_at,favorite_count,
        lang,retweet_count,source,txt)
    VALUES (?, ?,? ,?  ,? ,? ,?)''', (str(s['id']),s['created_at'],str(s['favorite_count']),
        s['lang'],
        str(s['retweet_count']),
        s['source'], 
        s['text']))
    
    #Facultative attributes (None if absent)
    for k in ['in_reply_to_status_id','place','coordinates','in_reply_to_user_id']:
        if s[k] is not None:
            v=(k, str(s[k]), str(s['id']))
            c.execute('''
            UPDATE statuses
            SET %s = ?
            WHERE id = ?''' % k, (str(s[k]), str(s['id'])))
    
    #Facultative attributes (not in s if absent)
    
    for k in ['scopes','withheld_in_countries','quoted_status_id']:
        if k in s :
            c.execute('''
            UPDATE statuses
            SET %s=?
            WHERE id=?'''% k,(str(s[k]),str(s['id'])))

    #Other entities
    for k in ['retweeted_status','user']:
        if k in s :
            c.execute('''
                UPDATE statuses
                SET %s_id=?
                WHERE id=?''' % k, (str(s[k]['id']),str(s['id'])))
            #Intégrer ce tweet !!
            #Intégrer ce user !!
            
            
    ###########################################USERS##############################################
    if (c.execute("SELECT * FROM users WHERE id=?", (str(s['user']['id']),)).fetchone())==None:
        u=twitter_api.users.show(id=str(s['user']['id']))
        add_user(u,c)
    #else MAJ user

    if not s['in_reply_to_user_id']==None:
        if (c.execute("SELECT * FROM users WHERE id=?", (str(s['in_reply_to_user_id']),)).fetchone())==None:
            u=twitter_api.users.show(id=str(s['in_reply_to_user_id']))
            add_user(u,c)
        #else MAJ user
        
    for u in s['entities']['user_mentions']:
        if (c.execute('''SELECT * FROM mentions 
                    WHERE status_id = ? AND user_id = ?''', (str(s['id']),str(u['id']))).fetchone())==None:
            #We do not register the multiple mentions of a user in a tweet
            c.execute('''INSERT INTO mentions(status_id ,user_id)
                        VALUES (?, ?)''', (str(s['id']),str(u['id'])))

            if (c.execute('''SELECT * FROM users WHERE id=?''', (str(u['id']),)).fetchone())==None:
                u=twitter_api.users.show(id=str(u['id']))
                add_user(u,c)       

    ################################# HASHTAGS #################################################
    for h in s['entities']['hashtags']:
        if (c.execute('''SELECT * FROM tags 
                    WHERE status_id=? AND htg = ?''',(str(s['id']),h['text'].lower())).fetchone())==None:
            #Ajouter le htg 
            c.execute('''INSERT INTO tags(status_id, htg) VALUES (?,?)''',(str(s['id']),h['text'].lower()))

# %%
htgs = ['#egalim','#egalimentation','#EtatsGenerauxdelAlimentation','#EGA']
w = ["états généraux de l'alimentation"]
nb = 100
lg='fr'

# %%
###Collection of data
#Compte @egalim

req=c.execute('''SELECT id FROM statuses ORDER by id DESC''').fetchone()

if req == None:
    sid=0
else : sid=req[0]
    
statuses=[]
for q in htgs :
    #search_results = twitter_api.search.tweets(q=q, count=nb,  result_type='recent', since_id=sid)
    #s = search_results['statuses']
    #l_nw_st=len(s)
    l_nw_st=100
    s=[]
    mid=10**20

    while l_nw_st==100:
        search_results = twitter_api.search.tweets(q=q, count=nb,  result_type='recent',  since_id=sid, max_id=mid)
        nw_st=search_results['statuses']
        l_nw_st=len(nw_st)
        s.extend(nw_st)
        if len(s)>0 : mid=s[-1]['id']-1   
    statuses.extend(s)

# %%
l_st=len(statuses)
print(l_st)
# Out:
# 377

# %%
[('{:-^100}'.format(s["user"]["screen_name"])+ '-'*5 + str(s['retweet_count'])+ '-'*2,s["text"],'') 
 for s in statuses]
# Out:
# [('----------------------------------------------AemicFR----------------------------------------------------1--',
#   'RT @ChambagriBzh: J.Jaouen "Il faut aider le consommateur à mieux choisir ses produits." #egabzh #egalim https://t.co/33qr7db8At',
#   ''),
#  ('---------------------------------------------luidgidu82--------------------------------------------------2--',
#   'RT @coordinationrur: #egalim – Atelier 14 - Bilan de la première réunion\n#desprixpasdesprimes #agriculture #investissement \nhttps://t.co/Ip…',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------1--',
#   'J.Jaouen "Il faut aider le consommateur à mieux choisir ses produits." #egabzh #egalim https://t.co/33qr7db8At',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------0--',
#   'Conclusion des #EGAbzh par J.Jaouen -Pdt CABzh- "il y a obligation de résultats suite à cette journée d\'échanges."… https://t.co/qrYC4xyTCa',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------0--',
#   'J.Jaouen "#Dialoguesocial #formation leviers fondamentaux pour relever nos #territoires." #Egabzh #egalim',
#   ''),
#  ('--------------------------------------------JoliffCarole-------------------------------------------------1--',
#   'RT @cnioncel18: Bravo @C_qui_le_Patron 👏😃 Le lien direct entre #agriculteurs &amp; #consommateurs #EGAlim https://t.co/3oqSYYyASt',
#   ''),
#  ('---------------------------------------------caudron62---------------------------------------------------1--',
#   "RT @coordinationrur: #egalim Atelier 6 - La CR privilégie des contrats de partenariat plutôt que l'export #agriculture #Alimentation https:…",
#   ''),
#  ('----------------------------------------------AemicFR----------------------------------------------------0--',
#   '"Il faut recréer de la confiance entre les acteurs", JP Girard, président de l\'Ania -convention #ANMF… https://t.co/0ywL4ydGaM',
#   ''),
#  ('---------------------------------------------tedourson---------------------------------------------------3--',
#   'RT @guillaumekasba: [ Auditions #EGAlim ]\n\n❓Où est passée la marge sur les produits alimentaires ❓\n\n⏭📺 https://t.co/bsdgg7c4d7 https://t.co…',
#   ''),
#  ('------------------------------------------Yggdras77224625------------------------------------------------8--',
#   "RT @ChambagriBzh: Suivez la contribution de la #Bretagne aux #egalim aujourd'hui sur #EGAbzh https://t.co/WSpon9wZYy",
#   ''),
#  ('-------------------------------------------ThierrySaviane------------------------------------------------3--',
#   'RT @guillaumekasba: [ Auditions #EGAlim ]\n\n❓Où est passée la marge sur les produits alimentaires ❓\n\n⏭📺 https://t.co/bsdgg7c4d7 https://t.co…',
#   ''),
#  ('----------------------------------------------Abrazo44---------------------------------------------------0--',
#   "#phytos #glyphosate #pollutions qualité de l'#eau #santé #alimentation #EGalim le lent changement #transition https://t.co/zNEQHb0HX1",
#   ''),
#  ('-------------------------------------------PSo_ActionAid-------------------------------------------------2--',
#   "25 sept @AssembleeNat : Réunion d'info sur #accaparementdeterre #agriculture et responsabilités françaises… https://t.co/J03P3hxQHi",
#   ''),
#  ('--------------------------------------------LBGroupeCom--------------------------------------------------0--',
#   'Animation et régie technique #EGAbzh assurés par LBGroupe pour la participation de la Bretagne aux #EGAlim à Pontiv… https://t.co/nrUA91WyW8',
#   ''),
#  ('--------------------------------------------cr_normandie-------------------------------------------------5--',
#   "RT @moreaujb23: François Lucas de la @coordinationrur a plaidé pour la création d'une exception agriculturelle #ComEco #Egalim #agriculture…",
#   ''),
#  ('--------------------------------------------GUEHERVILLE--------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('---------------------------------------------AgriAvenir--------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('----------------------------------------------Abrazo44---------------------------------------------------9--',
#   'RT @Cam_Zoriod: #egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N3…',
#   ''),
#  ('----------------------------------------------FDSEA38----------------------------------------------------0--',
#   '@FDSEA38 #Egalim #prix #consommateurs Obtenir un prix rémunérateur. Échanges entre agriculteurs, consommateurs, ass… https://t.co/qa9q08YKrX',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------0--',
#   "Strategie du @groupedaucy : s'adapter aux marchés, constamment en mutation, en diversifiant la #distribution… https://t.co/MLiLDwYKwi",
#   ''),
#  ('--------------------------------------------BMalabirade--------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('------------------------------------------EHFoundation237------------------------------------------------2--',
#   'RT @coordinationrur: #egalim – Atelier 14 - Bilan de la première réunion\n#desprixpasdesprimes #agriculture #investissement \nhttps://t.co/Ip…',
#   ''),
#  ('--------------------------------------------LeopoldineC--------------------------------------------------8--',
#   "RT @Agathe_CIWF: Avec @CIWF_FR aux #EGAlim pour defendre l'etiquetage des modes de production pour repondre aux attentes des consommateurs!…",
#   ''),
#  ('------------------------------------------coordinationrur------------------------------------------------2--',
#   '#egalim – Atelier 14 - Bilan de la première réunion\n#desprixpasdesprimes #agriculture #investissement… https://t.co/vb06o0aGyD',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------2--',
#   ".@IBB_BioBretagne : Initiative #bereizh, label #bio breton repond à l'attente du consommateur d'acheter… https://t.co/WdXbAmgTAi",
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------1--',
#   '.@hindsaoud "#Breizhalim porte aussi des ambitions #numeriques sur le #sourcing, en lien avec #savourezlabretagne." #egabzh #egalim',
#   ''),
#  ('--------------------------------------------Calisto2221--------------------------------------------------3--',
#   'RT @guillaumekasba: [ Auditions #EGAlim ]\n\n❓Où est passée la marge sur les produits alimentaires ❓\n\n⏭📺 https://t.co/bsdgg7c4d7 https://t.co…',
#   ''),
#  ('----------------------------------------------FDSEA56----------------------------------------------------5--',
#   'RT @groupedaucy: #Coop_Agri17 Stratégies filières client/agriculteur. Témoignage de Serge Le Bartz, président Groupe d’aucy.  #Egalim https…',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------3--',
#   "RT @Min_Agriculture: #EGalim Circuits courts, projets alimentaires territoriaux... Retour sur les sujets de l'atelier 2 https://t.co/y3onDI…",
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------0--',
#   'Consultation dans le @finistere_29 : #fluidité #traçabilité #proximité #prixjustes #equite #liensocial. #EGAbzh… https://t.co/Y0NBQAP7yM',
#   ''),
#  ('----------------------------------------------FDSEA56----------------------------------------------------7--',
#   "RT @FRSEA_Bretagne: #EGAlim @KThomazo Quand on se lève le matin pour produire et perdre de l'argent, un jour on décide d'arrêter... @JAMORB…",
#   ''),
#  ('--------------------------------------------Inra_BzhNdie-------------------------------------------------8--',
#   "RT @Agathe_CIWF: Avec @CIWF_FR aux #EGAlim pour defendre l'etiquetage des modes de production pour repondre aux attentes des consommateurs!…",
#   ''),
#  ('---------------------------------------------Actuagri_---------------------------------------------------0--',
#   '#egalim "On parle beaucoup des marchés et pas assez des charges des producteurs qui sont incompréhensibles"Thierry Roquefeuil @FNPLait',
#   ''),
#  ('-------------------------------------------RoblinThibaud-------------------------------------------------3--',
#   'RT @B_Peyrol: 1er atelier réussi ds le cadre de la consultation publique que ns organisons @Allierdpt #EGAlim - des prix rémunérateurs pr n…',
#   ''),
#  ('--------------------------------------------folomi4ever--------------------------------------------------3--',
#   'RT @B_Peyrol: 1er atelier réussi ds le cadre de la consultation publique que ns organisons @Allierdpt #EGAlim - des prix rémunérateurs pr n…',
#   ''),
#  ('--------------------------------------------PS_Morbihan--------------------------------------------------4--',
#   'RT @ChambagriBzh: Introduction par @regionbretagne des #egabzh. "Seuls 6% de la production sont en #ventedirecte" #egalim https://t.co/FvSn…',
#   ''),
#  ('--------------------------------------------hausnarrean--------------------------------------------------9--',
#   'RT @fnab_bio: #EGAlim 10 propositions des paysan-ne-s #bio pour la transition agri et alim des territoires. Objectif : 20% des terres agri…',
#   ''),
#  ('----------------------------------------------verosoz----------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('-------------------------------------------menierjeanrene------------------------------------------------4--',
#   'RT @ChambagriBzh: Introduction par @regionbretagne des #egabzh. "Seuls 6% de la production sont en #ventedirecte" #egalim https://t.co/FvSn…',
#   ''),
#  ('-------------------------------------------menierjeanrene------------------------------------------------5--',
#   'RT @groupedaucy: #Coop_Agri17 Stratégies filières client/agriculteur. Témoignage de Serge Le Bartz, président Groupe d’aucy.  #Egalim https…',
#   ''),
#  ('--------------------------------------------JPaulRiault--------------------------------------------------7--',
#   "RT @FRSEA_Bretagne: #EGAlim @KThomazo Quand on se lève le matin pour produire et perdre de l'argent, un jour on décide d'arrêter... @JAMORB…",
#   ''),
#  ('---------------------------------------------moreaujb23--------------------------------------------------3--',
#   'RT @B_Peyrol: 1er atelier réussi ds le cadre de la consultation publique que ns organisons @Allierdpt #EGAlim - des prix rémunérateurs pr n…',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------7--',
#   '#tableronde #EGAbzh : création de valeur ajoutée,zoom sur exemples en #bretagne répondants à la diversité des march… https://t.co/Y0CH7oCnq3',
#   ''),
#  ('--------------------------------------------JPaulRiault--------------------------------------------------4--',
#   'RT @ChambagriBzh: Introduction par @regionbretagne des #egabzh. "Seuls 6% de la production sont en #ventedirecte" #egalim https://t.co/FvSn…',
#   ''),
#  ('-----------------------------------------------_GCFT-----------------------------------------------------9--',
#   'RT @Cam_Zoriod: #egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N3…',
#   ''),
#  ('----------------------------------------------FDSEA56----------------------------------------------------4--',
#   'RT @ChambagriBzh: Introduction par @regionbretagne des #egabzh. "Seuls 6% de la production sont en #ventedirecte" #egalim https://t.co/FvSn…',
#   ''),
#  ('----------------------------------------------DGarbous---------------------------------------------------8--',
#   "RT @Agathe_CIWF: Avec @CIWF_FR aux #EGAlim pour defendre l'etiquetage des modes de production pour repondre aux attentes des consommateurs!…",
#   ''),
#  ('----------------------------------------------FDSEA56----------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('--------------------------------------------JPaulRiault--------------------------------------------------1--',
#   'RT @ChambagriBzh: "Obligé de changer de production #lait➡️#volaille et d\'#investir 1,2 millions d\'€." @KThomazo #egalim #egabzh https://t.c…',
#   ''),
#  ('------------------------------------------coordinationrur------------------------------------------------0--',
#   '#egalim Contractualisation et coûts de production au cœur des discussions #agriculture #alimentation\nhttps://t.co/yIkdZ7SceB',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------4--',
#   'Introduction par @regionbretagne des #egabzh. "Seuls 6% de la production sont en #ventedirecte" #egalim https://t.co/FvSnBSTwth',
#   ''),
#  ('----------------------------------------------Abrazo44---------------------------------------------------1--',
#   "RT @ChambagriBzh: #Egalim : la #Bretagne se réunit aujourd'hui à Pontivy. Contribuez et réagissez sur #EGAbzh",
#   ''),
#  ('----------------------------------------------B_Peyrol---------------------------------------------------3--',
#   '1er atelier réussi ds le cadre de la consultation publique que ns organisons @Allierdpt #EGAlim - des prix rémunéra… https://t.co/wVOVOoJPIB',
#   ''),
#  ('---------------------------------------------fanch_mrl---------------------------------------------------2--',
#   "RT @LoreneKloster: Propositions concrètes aujourd'hui pour progresser et apporter de la valeur ajoutée aux producteurs  #EGAbzh #EGAlim #Po…",
#   ''),
#  ('-------------------------------------------35520EnMarche-------------------------------------------------2--',
#   "RT @LoreneKloster: Propositions concrètes aujourd'hui pour progresser et apporter de la valeur ajoutée aux producteurs  #EGAbzh #EGAlim #Po…",
#   ''),
#  ('----------------------------------------------FRSEAFC----------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('------------------------------------------coordinationrur------------------------------------------------1--',
#   "#egalim Atelier 6 - La CR privilégie des contrats de partenariat plutôt que l'export #agriculture #Alimentation… https://t.co/28M09wkSlF",
#   ''),
#  ('-------------------------------------------guillaumekasba------------------------------------------------3--',
#   '[ Auditions #EGAlim ]\n\n❓Où est passée la marge sur les produits alimentaires ❓\n\n⏭📺 https://t.co/bsdgg7c4d7 https://t.co/WXl1lt4ttC',
#   ''),
#  ('------------------------------------------AlienorBertrand------------------------------------------------9--',
#   'RT @fnab_bio: #EGAlim 10 propositions des paysan-ne-s #bio pour la transition agri et alim des territoires. Objectif : 20% des terres agri…',
#   ''),
#  ('--------------------------------------------CDIVertdAzur-------------------------------------------------2--',
#   'RT @Inra_France: [#EGalim] Comportement, préférences alimentaires &amp; #santé : en savoir + sur les travaux #Inra #Didit. #Vidéo https://t.co/…',
#   ''),
#  ('--------------------------------------------CDIVertdAzur-------------------------------------------------3--',
#   "RT @Min_Agriculture: #EGalim Circuits courts, projets alimentaires territoriaux... Retour sur les sujets de l'atelier 2 https://t.co/y3onDI…",
#   ''),
#  ('-------------------------------------------DenierPasquier------------------------------------------------9--',
#   'RT @Cam_Zoriod: #egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N3…',
#   ''),
#  ('-------------------------------------------alexrichefort-------------------------------------------------1--',
#   "RT @DanoneFR: Rappel : les #EGAlim, c'est aussi une consultation en ligne à laquelle chacun peut participer :  https://t.co/PBG1KY4uup http…",
#   ''),
#  ('---------------------------------------------juliappro---------------------------------------------------0--',
#   '"robotisation, digitalisation... auront un impact positif sur l\'Agri si la valeur est répartie de manière juste"… https://t.co/BxlUOw4xdN',
#   ''),
#  ('---------------------------------------------Inra_Phase--------------------------------------------------8--',
#   "RT @Agathe_CIWF: Avec @CIWF_FR aux #EGAlim pour defendre l'etiquetage des modes de production pour repondre aux attentes des consommateurs!…",
#   ''),
#  ('--------------------------------------------smessaertluc-------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('-------------------------------------------BleuBlancCoeur------------------------------------------------8--',
#   "RT @ChambagriBzh: Suivez la contribution de la #Bretagne aux #egalim aujourd'hui sur #EGAbzh https://t.co/WSpon9wZYy",
#   ''),
#  ('--------------------------------------------perot_collas-------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('-------------------------------------------EGAlimentation------------------------------------------------1--',
#   "RT @GaelDavid_FGA: #EGalim devraient fixer un cap pour repositionner l'agriculture et les filières IAA 🇫🇷. Après 3 semaines d'ateliers, on…",
#   ''),
#  ('--------------------------------------------BenPerdreau--------------------------------------------------3--',
#   'RT @lacoopagricole: #Coop_Agri17 Michel Prugue: "Mais les #EGalim sont aussi une opportunité de dialoguer avec la société civile"',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------3--',
#   'Synthèse : 1 cadre qui moralise et rééquilibre les relations commerciales. Le rôle de la #loi est dabbord de protég… https://t.co/YZQSnn1Y7B',
#   ''),
#  ('---------------------------------------------EricMasset--------------------------------------------------4--',
#   'RT @lacoopagricole: #Coop_Agri17 Michel Prugue, Pdt @CoopdeFrance: "Le risque des #EGalim est d"ajouter de nouvelles contraintes, irrealisa…',
#   ''),
#  ('----------------------------------------------ReseauES---------------------------------------------------0--',
#   'RES-Actu n°31 : #fipronil #Minamata #egalim #BPA &amp; 1 invitation Villes &amp; Territoires sans #PeturbateursEndocriniens… https://t.co/0PaVeTpWmV',
#   ''),
#  ('------------------------------------------FNSEA_Nlle_Aqui------------------------------------------------3--',
#   "RT @henribiespere: Encore bcp de participants à l'atelier1 #EGalim et un débat instructif entre les parties. Le consensus sera compliqué ma…",
#   ''),
#  ('------------------------------------------FNSEA_Nlle_Aqui------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('-------------------------------------------blumel_rachel-------------------------------------------------1--',
#   'RT @lacoopagricole: #Coop_Agri17 M. Prugue: Nous sommes légitimes pour faire des propositions dans le cadre des #EGalim sur négos commercia…',
#   ''),
#  ('-------------------------------------------lacoopagricole------------------------------------------------0--',
#   '#Coop_Agri17 M. Prugue: "Nous espérons que les #EGalim déboucheront sur des propositions concrètes !"',
#   ''),
#  ('-------------------------------------------LesEchosEvents------------------------------------------------1--',
#   'RT @lacoopagricole: #Coop_Agri17 Retrouvez le détaille des propositions de @CoopdeFrance aux #EGalim :  https://t.co/pMiiHjO0xC https://t.c…',
#   ''),
#  ('-------------------------------------------lacoopagricole------------------------------------------------1--',
#   '#Coop_Agri17 Retrouvez le détaille des propositions de @CoopdeFrance aux #EGalim :  https://t.co/pMiiHjO0xC https://t.co/Ha3lh6HsDM',
#   ''),
#  ('-----------------------------------------------cyr081----------------------------------------------------10--',
#   "RT @FNSEA: RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l'agriculture…",
#   ''),
#  ('-----------------------------------------------FNSEA-----------------------------------------------------10--',
#   'RDV de travail constructif sur #PAC, #EGAlim, fiscalité, qui doit porter des ambitions économiques concrètes pour l… https://t.co/dQpRtXv1k7',
#   ''),
#  ('-------------------------------------------lacoopagricole------------------------------------------------1--',
#   '#Coop_Agri17 M. Prugue: Nous sommes légitimes pour faire des propositions dans le cadre des #EGalim sur négos comme… https://t.co/pRczaIHq7O',
#   ''),
#  ('--------------------------------------------AminaGaliano-------------------------------------------------0--',
#   '#Coop_Agri17 M.Prugue prsdt @CoopdeFrance propositions #EGalim notamment dans Relations commerciales et International',
#   ''),
#  ('-----------------------------------------------cyr081----------------------------------------------------4--',
#   'RT @lacoopagricole: #Coop_Agri17 Michel Prugue, Pdt @CoopdeFrance: "Le risque des #EGalim est d"ajouter de nouvelles contraintes, irrealisa…',
#   ''),
#  ('---------------------------------------------NMaria443---------------------------------------------------7--',
#   "RT @FRSEA_Bretagne: #EGAlim @KThomazo Quand on se lève le matin pour produire et perdre de l'argent, un jour on décide d'arrêter... @JAMORB…",
#   ''),
#  ('-----------------------------------------------EngyCH----------------------------------------------------3--',
#   'RT @lacoopagricole: #Coop_Agri17 Michel Prugue: "Mais les #EGalim sont aussi une opportunité de dialoguer avec la société civile"',
#   ''),
#  ('--------------------------------------------olivier_frey-------------------------------------------------4--',
#   'RT @lacoopagricole: #Coop_Agri17 Michel Prugue, Pdt @CoopdeFrance: "Le risque des #EGalim est d"ajouter de nouvelles contraintes, irrealisa…',
#   ''),
#  ('-------------------------------------------blumel_rachel-------------------------------------------------3--',
#   'RT @lacoopagricole: #Coop_Agri17 Michel Prugue: "Mais les #EGalim sont aussi une opportunité de dialoguer avec la société civile"',
#   ''),
#  ('-------------------------------------------blumel_rachel-------------------------------------------------4--',
#   'RT @lacoopagricole: #Coop_Agri17 Michel Prugue, Pdt @CoopdeFrance: "Le risque des #EGalim est d"ajouter de nouvelles contraintes, irrealisa…',
#   ''),
#  ('-------------------------------------------lacoopagricole------------------------------------------------2--',
#   "RT @LesEchosEvents: L'un des risques de ces #EGalim est de vouloir généraliser et normer. Soyons pragmatiques et réalistes- M. Prugue @Coop…",
#   ''),
#  ('-----------------------------------------------Looehn----------------------------------------------------9--',
#   'RT @Cam_Zoriod: #egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N3…',
#   ''),
#  ('-------------------------------------------lacoopagricole------------------------------------------------3--',
#   '#Coop_Agri17 Michel Prugue: "Mais les #EGalim sont aussi une opportunité de dialoguer avec la société civile"',
#   ''),
#  ('-------------------------------------------JobsTriskalia-------------------------------------------------11--',
#   'RT @lacoopagricole: #EGALIM https://t.co/x2QN8whO2P https://t.co/VySfDpfnqj',
#   ''),
#  ('-------------------------------------------blumel_rachel-------------------------------------------------2--',
#   "RT @LesEchosEvents: L'un des risques de ces #EGalim est de vouloir généraliser et normer. Soyons pragmatiques et réalistes- M. Prugue @Coop…",
#   ''),
#  ('-------------------------------------------FranceMarie47-------------------------------------------------7--',
#   "RT @FRSEA_Bretagne: #EGAlim @KThomazo Quand on se lève le matin pour produire et perdre de l'argent, un jour on décide d'arrêter... @JAMORB…",
#   ''),
#  ('-------------------------------------------lacoopagricole------------------------------------------------4--',
#   '#Coop_Agri17 Michel Prugue, Pdt @CoopdeFrance: "Le risque des #EGalim est d"ajouter de nouvelles contraintes, irrealisables techniquement"',
#   ''),
#  ('-----------------------------------------------EngyCH----------------------------------------------------2--',
#   'RT @CoopdeFrance: #EGAlim PARTAGEONS NOS POSITIONS ! Comment accompagner l’internationalisation de nos entreprises ? https://t.co/ih3pEAn2XG',
#   ''),
#  ('-------------------------------------------LesEchosEvents------------------------------------------------2--',
#   "L'un des risques de ces #EGalim est de vouloir généraliser et normer. Soyons pragmatiques et réalistes- M. Prugue @CoopdeFrance #coop_agri17",
#   ''),
#  ('-------------------------------------------LesEchosEvents------------------------------------------------3--',
#   'RT @lacoopagricole: #Coop_Agri17 Conclusion de cette matinée par Michel Prugue, qui détaille les propositions de @CoopdeFrance aux #EGalim…',
#   ''),
#  ('--------------------------------------------AminaGaliano-------------------------------------------------3--',
#   'RT @lacoopagricole: #Coop_Agri17 Conclusion de cette matinée par Michel Prugue, qui détaille les propositions de @CoopdeFrance aux #EGalim…',
#   ''),
#  ('--------------------------------------------BenPerdreau--------------------------------------------------3--',
#   'RT @lacoopagricole: #Coop_Agri17 Conclusion de cette matinée par Michel Prugue, qui détaille les propositions de @CoopdeFrance aux #EGalim…',
#   ''),
#  ('-------------------------------------------lacoopagricole------------------------------------------------3--',
#   '#Coop_Agri17 Conclusion de cette matinée par Michel Prugue, qui détaille les propositions de @CoopdeFrance aux… https://t.co/infqUCKqHs',
#   ''),
#  ('-------------------------------------------LoreneKloster-------------------------------------------------2--',
#   "Propositions concrètes aujourd'hui pour progresser et apporter de la valeur ajoutée aux producteurs  #EGAbzh… https://t.co/2cCOfbxfl1",
#   ''),
#  ('--------------------------------------------BrunoLeMaire-------------------------------------------------19--',
#   'Toujours aux côtés de nos agriculteurs : entretien ce matin avec @ChLambert_FNSEA, présidente de la @FNSEA.… https://t.co/2pxgOF4FnZ',
#   ''),
#  ('----------------------------------------------FNEasso----------------------------------------------------9--',
#   'RT @Cam_Zoriod: #egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N3…',
#   ''),
#  ('------------------------------------------alain_cardinaux------------------------------------------------1--',
#   'Baisse des coûts ou hausse des prix? @Dauvers70 relance le houleux débat sur les my de rendre les px + rémunérateur… https://t.co/2v3Xe9WwbW',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------1--',
#   'C Le Bihan "Le plus important pour le consommateur n\'est pas le #prix, c\'est l\'histoire et la #qualité du #produit.… https://t.co/nTVYnHr1oU',
#   ''),
#  ('-------------------------------------------LesEchosEvents------------------------------------------------3--',
#   'RT @olivier_frey: Retour sur les reco du think tank des Échos présentées par @Dauvers70 lors des #EGalim #Coop_Agri17 https://t.co/UbnNfKGu…',
#   ''),
#  ('-----------------------------------------------EngyCH----------------------------------------------------3--',
#   'RT @olivier_frey: Retour sur les reco du think tank des Échos présentées par @Dauvers70 lors des #EGalim #Coop_Agri17 https://t.co/UbnNfKGu…',
#   ''),
#  ('-----------------------------------------------cyr081----------------------------------------------------3--',
#   'RT @olivier_frey: Retour sur les reco du think tank des Échos présentées par @Dauvers70 lors des #EGalim #Coop_Agri17 https://t.co/UbnNfKGu…',
#   ''),
#  ('--------------------------------------------olivier_frey-------------------------------------------------3--',
#   'Retour sur les reco du think tank des Échos présentées par @Dauvers70 lors des #EGalim #Coop_Agri17 https://t.co/UbnNfKGurU',
#   ''),
#  ('--------------------------------------------AminaGaliano-------------------------------------------------0--',
#   '#Coop_Agri17 @Dauvers70 "Les recos 2017 Think Tank Agroalimentaire @LesEchos" aux #EGalim https://t.co/vcjyFwvVWi',
#   ''),
#  ('----------------------------------------------VOdille----------------------------------------------------3--',
#   "RT @Min_Agriculture: #EGalim Circuits courts, projets alimentaires territoriaux... Retour sur les sujets de l'atelier 2 https://t.co/y3onDI…",
#   ''),
#  ('---------------------------------------------Ludtheboss--------------------------------------------------9--',
#   'RT @fnab_bio: #EGAlim 10 propositions des paysan-ne-s #bio pour la transition agri et alim des territoires. Objectif : 20% des terres agri…',
#   ''),
#  ('---------------------------------------------cnioncel18--------------------------------------------------0--',
#   '#EGAlim #Coop_Agri17 🍅🍅 https://t.co/xOfz9jRirx',
#   ''),
#  ('--------------------------------------------theresemiket-------------------------------------------------9--',
#   'RT @Cam_Zoriod: #egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N3…',
#   ''),
#  ('------------------------------------------Min_Agriculture------------------------------------------------3--',
#   "#EGalim Circuits courts, projets alimentaires territoriaux... Retour sur les sujets de l'atelier 2… https://t.co/6eas46QZ8Q",
#   ''),
#  ('------------------------------------------_vanessapannier------------------------------------------------0--',
#   'Atelier 1 réunion 3 #EGalim beaucoup de travail pour mieux répondre aux attentes des consommateurs. https://t.co/ZXdA9XRKQC',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------41--',
#   "RT @sustain_food: #EGalim 40 initiatives qui démontrent que l'agriculture et l'alimentation durables sont déjà une réalité en France https:…",
#   ''),
#  ('----------------------------------------------LGABgde----------------------------------------------------8--',
#   "RT @Agathe_CIWF: Avec @CIWF_FR aux #EGAlim pour defendre l'etiquetage des modes de production pour repondre aux attentes des consommateurs!…",
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------0--',
#   '2ne table ronde #Egabzh sur les conditions de #commercialisation #distribution réglementation. #EGAlim https://t.co/gBS1esX3Xt',
#   ''),
#  ('---------------------------------------------marie_geay--------------------------------------------------9--',
#   'RT @Cam_Zoriod: #egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N3…',
#   ''),
#  ('--------------------------------------------perot_collas-------------------------------------------------3--',
#   "RT @henribiespere: Encore bcp de participants à l'atelier1 #EGalim et un débat instructif entre les parties. Le consensus sera compliqué ma…",
#   ''),
#  ('------------------------------------------LecouffeVincent------------------------------------------------0--',
#   'Strat de filières client/agriculteur. #fiersdecooperer avec Serge Le Bartz, président du Groupe d’aucy. #Egalim https://t.co/RCfjRdSH0s',
#   ''),
#  ('-------------------------------------------LesEchosEvents------------------------------------------------1--',
#   'RT @NicolasGerald1: #Coop_Agri17 Stratégies filières client/agriculteur. Témoignage de Serge Le Bartz, président Groupe d’aucy. #Egalim htt…',
#   ''),
#  ('---------------------------------------------ETafournel--------------------------------------------------4--',
#   'RT @FCDfrance: .#egalim sont 1 formidable opportunité pour créer la valeur et cesser de ns opposer les uns aux autres. @LSAconsommation @Ja…',
#   ''),
#  ('---------------------------------------------ETafournel--------------------------------------------------6--',
#   "RT @FCDfrance: Grâce #egalim, il faut promouvoir un réseau de #PME agroalim françaises de qualité.C'est grâce #PME que nait l'innovation! @…",
#   ''),
#  ('-------------------------------------------NicolasGerald1------------------------------------------------1--',
#   '#Coop_Agri17 Stratégies filières client/agriculteur. Témoignage de Serge Le Bartz, président Groupe d’aucy. #Egalim https://t.co/Y26SRgzSuT',
#   ''),
#  ('---------------------------------------------ETafournel--------------------------------------------------3--',
#   'RT @pgoetzmann: Longue interview @JacquesCreyssel , DG @FCDfrance . Tout y est dit et bien dit sur les enjeux. #EGAlim #fiscalité #numérisa…',
#   ''),
#  ('---------------------------------------------ETafournel--------------------------------------------------3--',
#   'RT @FCD_EU: 2nd part of #egalim have to underline that checks in the agri-food sector has never been that higher @JacquesCreyssel https://t…',
#   ''),
#  ('---------------------------------------------ETafournel--------------------------------------------------7--',
#   "RT @FCDfrance: 2nde partie des #egalim devra mettre en évidence que jamais le niv de sécurité, contrôle ds pduits alim n'a été aussi élevé…",
#   ''),
#  ('-------------------------------------------FRSEA_Bretagne------------------------------------------------3--',
#   'RT @ChambagriBzh: G.Emeriau "On devrait être capable de faire valoir notre #savoirfaire à la française à l\'étranger". #egabzh #egalim #made…',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------0--',
#   "Un équilibre offre↔️demande difficile sur les marchés mondiaux. Connexion plus forte de l'#UE au marché mondial… https://t.co/vNSA4RNECY",
#   ''),
#  ('--------------------------------------------Agathe_CIWF--------------------------------------------------9--',
#   'RT @Cam_Zoriod: #egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N3…',
#   ''),
#  ('---------------------------------------------Cam_Zoriod--------------------------------------------------8--',
#   "RT @Agathe_CIWF: Avec @CIWF_FR aux #EGAlim pour defendre l'etiquetage des modes de production pour repondre aux attentes des consommateurs!…",
#   ''),
#  ('----------------------------------------------CIWF_FR----------------------------------------------------8--',
#   "RT @Agathe_CIWF: Avec @CIWF_FR aux #EGAlim pour defendre l'etiquetage des modes de production pour repondre aux attentes des consommateurs!…",
#   ''),
#  ('--------------------------------------------Agathe_CIWF--------------------------------------------------8--',
#   "Avec @CIWF_FR aux #EGAlim pour defendre l'etiquetage des modes de production pour repondre aux attentes des consomm… https://t.co/rZkGw9ifgZ",
#   ''),
#  ('-------------------------------------------JollyVirginie-------------------------------------------------6--',
#   "RT @FCDfrance: Grâce #egalim, il faut promouvoir un réseau de #PME agroalim françaises de qualité.C'est grâce #PME que nait l'innovation! @…",
#   ''),
#  ('----------------------------------------------CIWF_FR----------------------------------------------------9--',
#   'RT @Cam_Zoriod: #egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N3…',
#   ''),
#  ('-------------------------------------------JollyVirginie-------------------------------------------------7--',
#   "RT @FCDfrance: 2nde partie des #egalim devra mettre en évidence que jamais le niv de sécurité, contrôle ds pduits alim n'a été aussi élevé…",
#   ''),
#  ('---------------------------------------------bioetlocal--------------------------------------------------9--',
#   'RT @fnab_bio: #EGAlim 10 propositions des paysan-ne-s #bio pour la transition agri et alim des territoires. Objectif : 20% des terres agri…',
#   ''),
#  ('-------------------------------------------LIndomptableFR------------------------------------------------3--',
#   'RT @ChambagriBzh: G.Emeriau "On devrait être capable de faire valoir notre #savoirfaire à la française à l\'étranger". #egabzh #egalim #made…',
#   ''),
#  ('------------------------------------------LeMadeInFrance_------------------------------------------------3--',
#   'RT @ChambagriBzh: G.Emeriau "On devrait être capable de faire valoir notre #savoirfaire à la française à l\'étranger". #egabzh #egalim #made…',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------3--',
#   'G.Emeriau "On devrait être capable de faire valoir notre #savoirfaire à la française à l\'étranger". #egabzh #egalim… https://t.co/TdE46OKAKP',
#   ''),
#  ('---------------------------------------------LeBuxAgri---------------------------------------------------5--',
#   'RT @groupedaucy: #Coop_Agri17 Stratégies filières client/agriculteur. Témoignage de Serge Le Bartz, président Groupe d’aucy.  #Egalim https…',
#   ''),
#  ('------------------------------------------CircuitsCulture------------------------------------------------5--',
#   'RT @groupedaucy: #Coop_Agri17 Stratégies filières client/agriculteur. Témoignage de Serge Le Bartz, président Groupe d’aucy.  #Egalim https…',
#   ''),
#  ('-------------------------------------------sophieborderes------------------------------------------------10--',
#   "RT @amo_thinktwice: [#EGAlim] Les cinq propositions de l'Agence Bio pour que la France maintienne son autosuffisance en produits bio @Flore…",
#   ''),
#  ('------------------------------------------ChLambert_FNSEA------------------------------------------------7--',
#   'RT @DGarbous: Atelier6-Réunion 3 des #EGalim : présentation de la #NouvelleAgriculture de @terrenacoop #SansOGM #SansAntibio avec les gamme…',
#   ''),
#  ('------------------------------------------_vanessapannier------------------------------------------------3--',
#   "RT @henribiespere: Encore bcp de participants à l'atelier1 #EGalim et un débat instructif entre les parties. Le consensus sera compliqué ma…",
#   ''),
#  ('-------------------------------------------durand9patrick------------------------------------------------11--',
#   'RT @lacoopagricole: #EGALIM https://t.co/x2QN8whO2P https://t.co/VySfDpfnqj',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------1--',
#   'https://t.co/A1lC0D3Hkl (@ChambagriBzh) ↔️ G.Emeriau (SystèmeU) "que fait-on des #volailles qui ont besoin de trait… https://t.co/gOLctxLyRq',
#   ''),
#  ('----------------------------------------------afaia_fr---------------------------------------------------4--',
#   "RT @afaia_fr: Etats Généraux de l'Alimentation #Egalim Défendez les #fertilisants durables avec Afaïa @afaia_fr   https://t.co/Z6zkoYzUkQ",
#   ''),
#  ('-------------------------------------------calmette_boris------------------------------------------------1--',
#   'RT @lacoopagricole: #EGALIM https://t.co/uITnDvG6Me https://t.co/Ycuhrk05rC',
#   ''),
#  ('----------------------------------------------gybloch----------------------------------------------------0--',
#   'Débats @LesEchosEvents. Se poser les bonnes questions sur les filières dans un contexte de crise agricole… https://t.co/lryKzbjNKq',
#   ''),
#  ('------------------------------------------alain_cardinaux------------------------------------------------1--',
#   'Le 1er allier des producteurs, c\'est la marque. C\'est elle qui tire la valeur", insiste C.Reclus, DG de @ARTERRIS11. #Coop_Agri17 #EGalim',
#   ''),
#  ('-------------------------------------------blumel_rachel-------------------------------------------------5--',
#   'RT @groupedaucy: #Coop_Agri17 Stratégies filières client/agriculteur. Témoignage de Serge Le Bartz, président Groupe d’aucy.  #Egalim https…',
#   ''),
#  ('--------------------------------------------groupedaucy--------------------------------------------------5--',
#   '#Coop_Agri17 Stratégies filières client/agriculteur. Témoignage de Serge Le Bartz, président Groupe d’aucy.… https://t.co/GbQ4jEGtgJ',
#   ''),
#  ('-------------------------------------------FrankGuehennec------------------------------------------------7--',
#   "RT @FRSEA_Bretagne: #EGAlim @KThomazo Quand on se lève le matin pour produire et perdre de l'argent, un jour on décide d'arrêter... @JAMORB…",
#   ''),
#  ('----------------------------------------------arnojoly---------------------------------------------------8--',
#   "RT @ChambagriBzh: Suivez la contribution de la #Bretagne aux #egalim aujourd'hui sur #EGAbzh https://t.co/WSpon9wZYy",
#   ''),
#  ('--------------------------------------------Inra_BzhNdie-------------------------------------------------2--',
#   'RT @Inra_France: [#EGalim] Aliments fermentés, #innovations &amp; trésors pr la #santé. Itw #vidéo SLortal @Inra_BzhNdie @INRA_CEPIA https://t.…',
#   ''),
#  ('----------------------------------------------jjoncour---------------------------------------------------2--',
#   "RT @guillaumegarot: Intervention #Coop_Agri17.  L'enjeu des #EGAlim : garantir une meilleure assiette au consommateur pour garantir un meil…",
#   ''),
#  ('-------------------------------------------guillaumegarot------------------------------------------------2--',
#   "Intervention #Coop_Agri17.  L'enjeu des #EGAlim : garantir une meilleure assiette au consommateur pour garantir un… https://t.co/adRxa1sUga",
#   ''),
#  ('-------------------------------------------plumedeschamps------------------------------------------------2--',
#   'RT @ChambagriBzh: O.Allain : ne pas attendre la régulation de Bruxelles pour réguler les prix. #egabzh #egalim https://t.co/0XTCrOSkLz',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------0--',
#   'JP Prigent (pdt #Sodiaal) "Ne parlons pas que de #prix, il faut renouveller les modèles économiques" #lait #egabzh… https://t.co/C0Kae49vcy',
#   ''),
#  ('----------------------------------------------dugocha----------------------------------------------------20--',
#   'RT @M_Orphelin: Atelier "Comment mieux rémunérer les agriculteurs?" des #EGAlim. Nous travaillons ce matin sur de nouveaux types de contrat…',
#   ''),
#  ('------------------------------------------UnionAgricole87------------------------------------------------2--',
#   'RT @CoopdeFrance: #EGAlim PARTAGEONS NOS POSITIONS ! Comment accompagner l’internationalisation de nos entreprises ? https://t.co/ih3pEAn2XG',
#   ''),
#  ('-------------------------------------------lacoopagricole------------------------------------------------1--',
#   '#EGALIM https://t.co/uITnDvG6Me https://t.co/Ycuhrk05rC',
#   ''),
#  ('---------------------------------------------GGavignet---------------------------------------------------9--',
#   'RT @fnab_bio: #EGAlim 10 propositions des paysan-ne-s #bio pour la transition agri et alim des territoires. Objectif : 20% des terres agri…',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------1--',
#   'G.Bocabeille : "La #GMS caractérise le produit alimentaire à son seul BAS #prix  C\'est 1 guerre de com fratricide !… https://t.co/tCPM2hf7uC',
#   ''),
#  ('---------------------------------------------CIHEAMIAMM--------------------------------------------------7--',
#   'RT @Inra_France: [#EGalim] Stratégies agricoles &amp; alimentaires: concilier #durabilité &amp; #nutrition @Inra_Phase @Inra_BzhNdie https://t.co/3…',
#   ''),
#  ('----------------------------------------------DanoneFR---------------------------------------------------1--',
#   "Rappel : les #EGAlim, c'est aussi une consultation en ligne à laquelle chacun peut participer :… https://t.co/E4qtVsG7LF",
#   ''),
#  ('---------------------------------------------CIHEAMIAMM--------------------------------------------------10--',
#   "RT @amo_thinktwice: [#EGAlim] Les cinq propositions de l'Agence Bio pour que la France maintienne son autosuffisance en produits bio @Flore…",
#   ''),
#  ('---------------------------------------------Cam_Zoriod--------------------------------------------------9--',
#   '#egalim avec @greenpeacefr @CIWF_FR @FNEasso sur la consommation de protéines animales : #moinsetmieux https://t.co/uMPI2N36JM',
#   ''),
#  ('--------------------------------------------antoinesauv--------------------------------------------------3--',
#   'RT @FCD_EU: 2nd part of #egalim have to underline that checks in the agri-food sector has never been that higher @JacquesCreyssel https://t…',
#   ''),
#  ('-------------------------------------------GaelDavid_FGA-------------------------------------------------1--',
#   "#EGalim devraient fixer un cap pour repositionner l'agriculture et les filières IAA 🇫🇷. Après 3 semaines d'ateliers, on ne voit pas ce cap",
#   ''),
#  ('--------------------------------------------CoopdeFrance-------------------------------------------------2--',
#   '#EGAlim PARTAGEONS NOS POSITIONS ! Comment accompagner l’internationalisation de nos entreprises ? https://t.co/ih3pEAn2XG',
#   ''),
#  ('--------------------------------------------terrenacoop--------------------------------------------------7--',
#   'RT @DGarbous: Atelier6-Réunion 3 des #EGalim : présentation de la #NouvelleAgriculture de @terrenacoop #SansOGM #SansAntibio avec les gamme…',
#   ''),
#  ('---------------------------------------------Cam_Zoriod--------------------------------------------------9--',
#   'RT @fnab_bio: #EGAlim 10 propositions des paysan-ne-s #bio pour la transition agri et alim des territoires. Objectif : 20% des terres agri…',
#   ''),
#  ('-----------------------------------------------mate0o----------------------------------------------------116--',
#   "RT @myricau: À écouter les débats, en tant que consommateur je vous engage fortement à dégager Bigard Groupe de votre panier d'achat #EGAlim",
#   ''),
#  ('--------------------------------------------williampel56-------------------------------------------------5--',
#   'RT @menierjeanrene: @FDSEA56 Conférence de presse #Egalim à pontivy https://t.co/6CXgvsz8Sg',
#   ''),
#  ('--------------------------------------------ChambagriBzh-------------------------------------------------3--',
#   '"Je vois des femmes et hommes qui ne se parlent et ne s\'ecoutent plus. J\'aimerai tous nous voir vivre de notre trav… https://t.co/Cs48NDMbg9',
#   ''),
#  ('--------------------------------------------didierlegac--------------------------------------------------5--',
#   "À Pontivy. États Généraux de l'Alimentation. Débats et témoignages. Pour des revenus plus justes pour les agriculte… https://t.co/vCYYRkQ1dR",
#   ''),
#  ('--------------------------------------------FleuryMichon-------------------------------------------------7--',
#   'RT @DGarbous: Atelier6-Réunion 3 des #EGalim : présentation de la #NouvelleAgriculture de @terrenacoop #SansOGM #SansAntibio avec les gamme…',
#   ''),
#  ('-------------------------------------------Ludovic_Degand------------------------------------------------9--',
# ...
#   'RT @AngiBreizh: [VIDEOS] Agriculture. Discussion tendue entre FDSEA et Scarmor à Pontivy #EGA https://t.co/Yc1DeYcQTg via @actufr',
#   ''),
#  ('--------------------------------------------MaLuherne56--------------------------------------------------7--',
#   'RT @AngiBreizh: [VIDEOS] Agriculture. Discussion tendue entre FDSEA et Scarmor à Pontivy #EGA https://t.co/Yc1DeYcQTg via @actufr',
#   ''),
#  ('----------------------------------------------FDSEA56----------------------------------------------------7--',
#   'RT @AngiBreizh: [VIDEOS] Agriculture. Discussion tendue entre FDSEA et Scarmor à Pontivy #EGA https://t.co/Yc1DeYcQTg via @actufr',
#   ''),
#  ('-------------------------------------------DamienPrevost-------------------------------------------------5--',
#   'RT @StTRAVERT: Rencontre au #MAA avec @PhilHoganEU #PAC gestion des risques, #EGA avenir de nos modèles agricoles. https://t.co/0UsGoEeIOO',
#   ''),
#  ('------------------------------------------ChristianHuygh1------------------------------------------------5--',
#   'RT @StTRAVERT: Rencontre au #MAA avec @PhilHoganEU #PAC gestion des risques, #EGA avenir de nos modèles agricoles. https://t.co/0UsGoEeIOO',
#   ''),
#  ('-------------------------------------------plumedeschamps------------------------------------------------5--',
#   'RT @StTRAVERT: Rencontre au #MAA avec @PhilHoganEU #PAC gestion des risques, #EGA avenir de nos modèles agricoles. https://t.co/0UsGoEeIOO',
#   ''),
#  ('-------------------------------------------boutiquesylvie------------------------------------------------5--',
#   'RT @StTRAVERT: Rencontre au #MAA avec @PhilHoganEU #PAC gestion des risques, #EGA avenir de nos modèles agricoles. https://t.co/0UsGoEeIOO',
#   ''),
#  ('---------------------------------------------StTRAVERT---------------------------------------------------5--',
#   'Rencontre au #MAA avec @PhilHoganEU #PAC gestion des risques, #EGA avenir de nos modèles agricoles. https://t.co/0UsGoEeIOO',
#   ''),
#  ('------------------------------------------Bhanuchowdary15------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('--------------------------------------------OfficialOMAs-------------------------------------------------2--',
#   'RT @oma_radio: LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/YCC7qjgof1  #RTM #EGA…',
#   ''),
#  ('--------------------------------------------Young_Spray--------------------------------------------------2--',
#   'RT @oma_radio: LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/YCC7qjgof1  #RTM #EGA…',
#   ''),
#  ('---------------------------------------------oma_radio---------------------------------------------------2--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/YCC7qjgof1  #RTM #EGA 🚿🎯',
#   ''),
#  ('--------------------------------------------Young_Spray--------------------------------------------------1--',
#   'RT @YoungMarv_: LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/iuFhCDnfHt #RTM #EGA…',
#   ''),
#  ('--------------------------------------------tommy_mallet-------------------------------------------------0--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/7QmCVvvIIP #RTM #EGA 🚿🎯',
#   ''),
#  ('---------------------------------------------CRavaudet---------------------------------------------------7--',
#   'RT @AngiBreizh: [VIDEOS] Agriculture. Discussion tendue entre FDSEA et Scarmor à Pontivy #EGA https://t.co/Yc1DeYcQTg via @actufr',
#   ''),
#  ('---------------------------------------------YoungMarv_--------------------------------------------------1--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/iuFhCDnfHt #RTM #EGA 🚿🎯',
#   ''),
#  ('-------------------------------------------DeepeeSection-------------------------------------------------1--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/UT5qe91eSl #RTM #EGA 🚿🎯',
#   ''),
#  ('--------------------------------------------Young_Spray--------------------------------------------------1--',
#   'RT @B4BMusic: LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/72V0EYv75N #RTM #EGA 💥💥',
#   ''),
#  ('------------------------------------------_vanessapannier------------------------------------------------0--',
#   'Engagement sur 2, 5 et 10 ans pour structurer les filières  et récolter le fruit de nos engagements #EGA  matinée de travail intense!!!',
#   ''),
#  ('-------------------------------------------francois_regis------------------------------------------------7--',
#   'RT @AngiBreizh: [VIDEOS] Agriculture. Discussion tendue entre FDSEA et Scarmor à Pontivy #EGA https://t.co/Yc1DeYcQTg via @actufr',
#   ''),
#  ('------------------------------------------harishkumarraj3------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('-------------------------------------------soizicperrault------------------------------------------------7--',
#   'RT @AngiBreizh: [VIDEOS] Agriculture. Discussion tendue entre FDSEA et Scarmor à Pontivy #EGA https://t.co/Yc1DeYcQTg via @actufr',
#   ''),
#  ('--------------------------------------------vararemo9999-------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('---------------------------------------------AngiBreizh--------------------------------------------------7--',
#   '[VIDEOS] Agriculture. Discussion tendue entre FDSEA et Scarmor à Pontivy #EGA https://t.co/Yc1DeYcQTg via @actufr',
#   ''),
#  ('--------------------------------------------sonia_leong--------------------------------------------------0--',
#   'Day 7 of the school run and I went for a Business/Boots EGA look #ootd #fashion #ega https://t.co/5QWvUx4pIp',
#   ''),
#  ('----------------------------------------------B4BMusic---------------------------------------------------1--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/72V0EYv75N #RTM #EGA 💥💥',
#   ''),
#  ('---------------------------------------------vamsi4422---------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('-------------------------------------------Lokesh51327197------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('-------------------------------------------Sardarmahesh99------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('----------------------------------------------RaviAKP----------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('----------------------------------------------SSKsays----------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('-------------------------------------------murali_kilari-------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('-------------------------------------------VenkyBaadhshah------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('---------------------------------------------bharath40---------------------------------------------------11--',
#   'RT @vinay_a9: As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#Jai…',
#   ''),
#  ('------------------------------------------AgrobioBretagne------------------------------------------------0--',
#   "Nos 10 propositions pour les #EGA pour de la France le 1er pays #bio d'Europe. https://t.co/pAGmbj514d @fnab_bio https://t.co/lBjRPV1CZL",
#   ''),
#  ('----------------------------------------------vinay_a9---------------------------------------------------11--',
#   'As there r no shows before 7:30Am in #Chennai \nBest option #Vettri 8AM 👌\n\n#Vettri 8Am,6:30,9:50Pm\n#Ega 12,3:30,7,10:45Pm\n#JaiLavaKusaOnSep21',
#   ''),
#  ('----------------------------------------------emezrich---------------------------------------------------0--',
#   "Aux Etats généraux de l'alimentation pour défense une agriculture et aquaculture diverse et de qualité #EGA #qualite https://t.co/Lf5kHpViAA",
#   ''),
#  ('--------------------------------------------mindpeterpan-------------------------------------------------0--',
#   '#ภาษีไปไหน #govspending by #EGA https://t.co/TaXtDeNRxe',
#   ''),
#  ('------------------------------------------gorrillasawnoff------------------------------------------------1--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/oNdURMLulg #RTM #EGA 🚿🎯',
#   ''),
#  ('----------------------------------------------DizlOTF----------------------------------------------------3--',
#   'RT @Young_Spray: LISTEN TO "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/PFxtuTgnik #RTM #EGA 🚿🏁',
#   ''),
#  ('-------------------------------------------LittyOnDaBeat-------------------------------------------------2--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/y2Q61K4ysr #RTM #EGA 🚿🎯',
#   ''),
#  ('--------------------------------------------Young_Spray--------------------------------------------------1--',
#   'RT @Tabzwilson: LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/EKNvNlMu4W #RTM #EGA…',
#   ''),
#  ('---------------------------------------------Tabzwilson--------------------------------------------------1--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/EKNvNlMu4W #RTM #EGA 🚿🎯',
#   ''),
#  ('-------------------------------------------Spyda_Official------------------------------------------------2--',
#   'RT @tularosaa_: Listen To "Miss Me With That" By @YOUNG_SPRAY Ft @PREZ_T &amp; Pre-Order Invisible Tears... https://t.co/WYwYWljb1T #RTM #EGA 🚿✨',
#   ''),
#  ('-------------------------------------------SneakyBeats82-------------------------------------------------4--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/B6H42rrWst #RTM #EGA 🚿🎯',
#   ''),
#  ('--------------------------------------------Official3xt--------------------------------------------------1--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/mXBNTq8wwX #RTM #EGA 🚿🎯',
#   ''),
#  ('--------------------------------------------Young_Spray--------------------------------------------------2--',
#   'RT @tularosaa_: Listen To "Miss Me With That" By @YOUNG_SPRAY Ft @PREZ_T &amp; Pre-Order Invisible Tears... https://t.co/WYwYWljb1T #RTM #EGA 🚿✨',
#   ''),
#  ('--------------------------------------------Young_Spray--------------------------------------------------1--',
#   'RT @SirDjCorey: "MISS ME WITH THAT" \n\nBY @YOUNG_SPRAY FT @PREZ_T \n\nPRE-ORDER \n\nINVISIBLE TEARS\n\nhttps://t.co/ETcHpHUWBn\n\n #RTM #EGA 🚿🎯',
#   ''),
#  ('--------------------------------------------Young_Spray--------------------------------------------------1--',
#   'RT @Zim_Zimer: Go Get @Young_Spray "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS https://t.co/g6I2GzweBV #RTM #EGA 🚿 https:/…',
#   ''),
#  ('--------------------------------------------Young_Spray--------------------------------------------------1--',
#   'RT @i_am_frass: LISTEN TO @Young_Spray  "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/jHI3MbACO9 #RTM #EGA 🚿🎯',
#   ''),
#  ('--------------------------------------------Young_Spray--------------------------------------------------1--',
#   'RT @MSoEazy: Go LISTEN TO @Young_Spray "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/MG8YdpMMfP #RTM #EGA 🚿🎯',
#   ''),
#  ('---------------------------------------------tularosaa_--------------------------------------------------2--',
#   'Listen To "Miss Me With That" By @YOUNG_SPRAY Ft @PREZ_T &amp; Pre-Order Invisible Tears... https://t.co/WYwYWljb1T #RTM #EGA 🚿✨',
#   ''),
#  ('--------------------------------------------Inchsection--------------------------------------------------1--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/OtsmC9Ios9 #RTM #EGA 🚿🎯',
#   ''),
#  ('------------------------------------------cameramansketch------------------------------------------------3--',
#   'RT @Young_Spray: LISTEN TO "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/PFxtuTgnik #RTM #EGA 🚿🎯🏁',
#   ''),
#  ('---------------------------------------------SirDjCorey--------------------------------------------------1--',
#   '"MISS ME WITH THAT" \n\nBY @YOUNG_SPRAY FT @PREZ_T \n\nPRE-ORDER \n\nINVISIBLE TEARS\n\nhttps://t.co/ETcHpHUWBn\n\n #RTM #EGA 🚿🎯',
#   ''),
#  ('---------------------------------------------MayhemSAS---------------------------------------------------3--',
#   'RT @Young_Spray: LISTEN TO "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/PFxtuTgnik #RTM #EGA 🚿🎯🏁',
#   ''),
#  ('-------------------------------------------MrBigzOfficial------------------------------------------------1--',
#   'LISTEN TO "MISS ME WITH THAT" BY @YOUNG_SPRAY FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/iKbC2J6wdF  #RTM #EGA 🚿🎯',
#   ''),
#  ('---------------------------------------------Zim_Zimer---------------------------------------------------1--',
#   'Go Get @Young_Spray "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS https://t.co/g6I2GzweBV #RTM #EGA 🚿 https://t.co/g6I2GzweBV',
#   ''),
#  ('---------------------------------------------i_am_frass--------------------------------------------------1--',
#   'LISTEN TO @Young_Spray  "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/jHI3MbACO9 #RTM #EGA 🚿🎯',
#   ''),
#  ('----------------------------------------------MSoEazy----------------------------------------------------1--',
#   'Go LISTEN TO @Young_Spray "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/MG8YdpMMfP #RTM #EGA 🚿🎯',
#   ''),
#  ('---------------------------------------------TazBunnett--------------------------------------------------0--',
#   'LISTEN TO "MISS ME WITH THAT" FT @PREZ_T AND PRE-ORDER INVISIBLE TEARS... https://t.co/5sxiooJk2u #RTM #EGA 🚿🎯',
#   ''),
#  ('-----------------------------------------------GusK16----------------------------------------------------1--',
#   'RT @H_Bomb009: Jacques Leglise Trophy at Ballybunion GC #R&amp;A #GB&amp;I #EGA #pure #linksgolf https://t.co/PIWdHA6mif',
#   '')]

# %% [markdown]
# c.execute('''DELETE FROM users WHERE id>1''')
# c.execute('''DELETE FROM statuses WHERE id>1''')
# c.execute('''DELETE FROM mentions WHERE status_id >1''')
# c.execute('''DELETE FROM tags WHERE status_id >1''')

# %%
for s in statuses:
    ls=len(c.execute('''SELECT * FROM statuses''').fetchall())
    lu=len(c.execute('''SELECT * FROM users''').fetchall())
    lh=len(c.execute('''SELECT * FROM tags''').fetchall())
    lm=len(c.execute('''SELECT * FROM mentions''').fetchall())
    print (ls,'  ',lu,'  ',lh,'  ',lm)
    #########################################STATUSES#############################################
    #main status
    if (c.execute("SELECT * FROM statuses WHERE id=?", (str(s['id']),)).fetchone())==None:
        add_status(s,c)
    
    #replied status
    if s['in_reply_to_status_id'] is not None:
        if (c.execute("SELECT * FROM statuses WHERE id=?", (str(s['in_reply_to_status_id']),)).fetchone())==None:
            r=twitter_api.statuses.show(id=s['in_reply_to_status_id'])
            add_status(r,c)        
                                           
    #quoted status
    if 'quoted_status_id' in s:
        if (c.execute("SELECT * FROM statuses WHERE id=?", (str(s['quoted_status_id']),)).fetchone())==None:
            q=twitter_api.statuses.show(id=s['quoted_status_id'])
            add_status(q,c)
# Out:
# 3175    1913    5447    4095
# 3176    1913    5449    4096
# 3177    1914    5453    4097
# 3178    1914    5455    4097
# 3179    1914    5456    4097
# 3180    1914    5461    4097
# 3181    1914    5464    4099
# 3182    1914    5467    4100
# 3183    1914    5468    4100
# 3184    1914    5469    4101
# 3185    1915    5472    4102
# 3186    1916    5473    4103
# 3188    1916    5482    4103
# 3189    1916    5484    4104
# 3190    1917    5486    4104
# 3191    1918    5489    4106
# 3193    1919    5491    4109
# 3194    1919    5493    4110
# 3195    1919    5495    4114
# 3196    1919    5498    4115
# 3197    1920    5499    4116
# 3198    1920    5501    4117
# 3199    1920    5505    4118
# 3200    1920    5506    4120
# 3201    1920    5510    4120
# 3202    1921    5512    4121
# 3203    1922    5518    4122
# 3204    1923    5519    4123
# 3205    1923    5521    4124
# 3206    1923    5522    4125
# 3207    1924    5529    4126
# 3208    1925    5530    4128
# 3209    1926    5531    4130
# 3210    1927    5532    4131
# 3211    1929    5533    4133
# 3212    1930    5534    4135
# 3213    1931    5537    4137
# 3214    1932    5539    4138
# 3215    1932    5541    4139
# 3216    1932    5544    4141
# 3217    1932    5546    4142
# 3218    1932    5547    4144
# 3219    1932    5548    4146
# 3220    1932    5551    4146
# 3221    1932    5554    4148
# 3222    1933    5556    4152
# 3223    1933    5559    4154
# 3224    1933    5560    4156
# 3225    1933    5562    4157
# 3226    1933    5567    4159
# 3227    1933    5570    4159
# 3228    1933    5573    4160
# 3229    1933    5576    4161
# 3230    1933    5577    4162
# 3231    1933    5579    4163
# 3232    1934    5581    4164
# 3233    1935    5583    4165
# 3234    1935    5586    4165
# 3235    1935    5587    4165
# 3236    1936    5589    4166
# 3237    1936    5594    4167
# 3238    1936    5595    4168
# 3239    1936    5597    4172
# 3240    1938    5598    4173
# 3241    1939    5598    4173
# 3242    1939    5599    4175
# 3243    1939    5601    4176
# 3244    1940    5604    4177
# 3245    1940    5606    4178
# 3246    1941    5607    4179
# 3247    1941    5609    4180
# 3248    1941    5610    4180
# 3249    1941    5612    4182
# 3250    1941    5617    4182
# 3251    1942    5618    4183
# 3252    1942    5620    4184
# 3253    1942    5622    4185
# 3254    1942    5624    4185
# 3255    1942    5626    4187
# 3256    1942    5628    4188
# 3257    1942    5630    4189
# 3258    1942    5632    4189
# 3259    1942    5634    4189
# 3260    1943    5636    4190
# 3261    1943    5638    4192
# 3262    1944    5639    4194
# 3263    1945    5641    4195
# 3264    1945    5643    4197
# 3265    1945    5645    4198
# 3266    1945    5647    4200
# 3267    1945    5648    4201
# 3268    1946    5650    4205
# 3269    1946    5652    4205
# 3270    1946    5653    4206
# 3271    1946    5654    4207
# 3272    1947    5655    4209
# 3273    1947    5657    4210
# 3274    1947    5658    4211
# 3275    1947    5660    4212
# 3276    1947    5662    4214
# 3277    1947    5664    4216
# 3278    1947    5666    4218
# 3279    1947    5667    4219
# 3280    1947    5668    4219
# 3280    1947    5668    4219
# 3281    1947    5670    4223
# 3282    1947    5670    4224
# 3283    1947    5673    4224
# 3284    1947    5675    4226
# 3285    1947    5677    4228
# 3286    1947    5679    4230
# 3287    1947    5681    4231
# 3288    1948    5683    4233
# 3289    1949    5684    4234
# 3290    1950    5686    4235
# 3292    1950    5689    4236
# 3293    1950    5691    4240
# 3294    1950    5692    4240
# 3295    1951    5693    4240
# 3296    1951    5694    4241
# 3297    1952    5695    4243
# 3298    1952    5699    4243
# 3299    1952    5701    4247
# 3300    1952    5702    4248
# 3301    1953    5704    4248
# 3302    1953    5706    4249
# 3303    1954    5707    4251
# 3304    1954    5709    4252
# 3305    1954    5711    4252
# 3306    1954    5713    4255
# 3307    1955    5714    4257
# 3308    1955    5715    4258
# 3309    1955    5718    4259
# 3310    1955    5719    4259
# 3311    1955    5721    4263
# 3312    1955    5722    4265
# 3313    1955    5723    4267
# 3314    1955    5724    4268
# 3315    1956    5726    4269
# 3316    1956    5728    4273
# 3317    1956    5729    4274
# 3318    1956    5731    4275
# 3319    1956    5734    4276
# 3320    1956    5737    4277
# 3321    1956    5740    4277
# 3322    1956    5742    4278
# 3323    1956    5744    4279
# 3324    1956    5745    4280
# 3325    1957    5749    4282
# 3326    1957    5750    4283
# 3327    1957    5751    4284
# 3328    1957    5752    4285
# 3329    1957    5754    4286
# 3330    1957    5755    4287
# 3331    1958    5755    4288
# 3332    1958    5757    4289
# 3333    1958    5759    4290
# 3334    1958    5760    4290
# 3335    1958    5761    4292
# 3336    1959    5764    4293
# 3337    1959    5768    4296
# 3338    1959    5770    4297
# 3339    1959    5772    4297
# 3340    1959    5774    4298
# 3341    1959    5778    4298
# 3342    1960    5779    4299
# 3343    1960    5780    4300
# 3344    1960    5781    4300
# 3345    1961    5783    4301
# 3346    1961    5785    4301
# 3347    1962    5788    4304
# 3348    1962    5789    4304
# 3349    1962    5790    4305
# 3350    1962    5792    4308
# 3351    1962    5793    4310
# 3352    1962    5794    4310
# 3353    1962    5795    4310
# 3354    1962    5799    4312
# 3355    1962    5801    4313
# 3356    1963    5802    4314
# 3357    1964    5803    4316
# 3358    1964    5803    4316
# 3359    1964    5803    4316
# 3360    1964    5807    4318
# 3361    1965    5809    4319
# 3362    1965    5811    4320
# 3363    1966    5812    4321
# 3364    1966    5817    4322
# 3365    1966    5819    4323
# 3366    1966    5820    4324
# 3367    1967    5821    4326
# 3368    1967    5823    4326
# 3369    1968    5827    4328
# 3370    1969    5828    4330
# 3371    1969    5829    4331

# %%
ls=len(c.execute('''SELECT * FROM statuses''').fetchall())
lu=len(c.execute('''SELECT * FROM users''').fetchall())
lh=len(c.execute('''SELECT * FROM tags''').fetchall())
lm=len(c.execute('''SELECT * FROM mentions''').fetchall())
print (ls,'  ',lu,'  ',lh,'  ',lm)

# %%
conn.commit()

# %% [markdown]
# ## Reste à faire :
# - fonctions update user et status
# - boucler l'ensemble pour stocker les données recherchée pour une connection
# - creer la fonction qui MAJ à chaque nouvelle connection

# %%
last=c.execute('''SELECT id FROM statuses ORDER by id DESC''')

# %%
last.fetchone()[0]

# %%
s=statuses[0]
rows=c.execute('''SELECT id FROM users WHERE id = ?''',(str(s['user']['id']),))

# %%
rows=c.execute('''SELECT * FROM users ''')

# %%
rows=c.execute('''SELECT * FROM statuses WHERE id == ? ''', ('909728156705320960',))

# %%
str(s['user']['id'])

# %%
print(rows.fetchone()==None)
print(len(rows.fetchall()))

# %%
rows=c.execute('''SELECT count(id) FROM statuses''')

for r in rows:
    print(r)

# %%
rows=c.execute('''SELECT count(*) FROM (SELECT DISTINCT user_id FROM statuses) as a''')
rows.fetchone()

# %%
rows=c.execute('''SELECT count(*) FROM statuses GROUP BY user_id''')
len(rows.fetchall())

# %%
rows=c.execute('''SELECT user_id FROM statuses''')

rows.fetchmany(10)
